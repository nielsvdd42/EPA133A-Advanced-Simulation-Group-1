# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import dist
from haversine import haversine

# %%
STD_THRESHOLD = 3
CLOSENESS_THRESHOLD = 0.2

# %%
df_rds = pd.read_csv("../data/raw/_roads.tsv", sep = "\t", low_memory=False)
df_rds
# Out:
#       road  lrp1       lat1       lon1    lrp2       lat2       lon2  \
# 0       N1  LRPS  23.706028  90.443333   LRPSa  23.702917  90.450417
# 1     N101  LRPS  23.454139  91.212861   LRPSa  23.461889  91.212000
# 2     N102  LRPS  23.478972  91.118194   LRPSa  23.481583  91.116777
# 3     N103  LRPS  23.957028  91.115528  LRP001  23.961917  91.113611
# 4     N104  LRPS  23.009667  91.399416   LRPSa  23.009278  91.395250
# ..     ...   ...        ...        ...     ...        ...        ...
# 880  Z8910  LRPS  22.674722  90.408889   LRPSa  22.675916  90.412556
# 881  Z8913  LRPS  22.396083  90.688666   LRPSa  22.393027  90.688944
# 882  Z8915  LRPS  22.589389  90.619472  LRP001  22.589694  90.623360
# 883  Z8916  LRPS  22.625499  90.661722   LRPSa  22.623888  90.664167
# 884  Z8943  LRPS  22.426444  90.849472   LRPSa  22.426416  90.846833
#
#     Unnamed: 7  Unnamed: 8  Unnamed: 9  ... Unnamed: 4035  Unnamed: 4036  \
# 0        LRPSb   23.702778   90.450472  ...      92.29825        LRP466c
# 1       LRP001   23.462944   91.211806  ...           NaN            NaN
# 2        LRPSb   23.486666   91.113361  ...           NaN            NaN
# 3      LRP001a   23.967666   91.111889  ...           NaN            NaN
# 4       LRP001   23.009306   91.389805  ...           NaN            NaN
# ..         ...         ...         ...  ...           ...            ...
# 880     LRP001   22.675583   90.417166  ...           NaN            NaN
# 881      LRPSb   22.392666   90.689083  ...           NaN            NaN
# 882    LRP001a   22.590027   90.631360  ...           NaN            NaN
# 883     LRP001   22.620305   90.668999  ...           NaN            NaN
# 884     LRP001   22.425444   90.839861  ...           NaN            NaN
#
#      Unnamed: 4037 Unnamed: 4038  Unnamed: 4039  Unnamed: 4040 Unnamed: 4041  \
# 0        20.864667     92.298194         LRP467      20.862972     92.298083
# 1              NaN           NaN            NaN            NaN           NaN
# 2              NaN           NaN            NaN            NaN           NaN
# 3              NaN           NaN            NaN            NaN           NaN
# 4              NaN           NaN            NaN            NaN           NaN
# ..             ...           ...            ...            ...           ...
# 880            NaN           NaN            NaN            NaN           NaN
# 881            NaN           NaN            NaN            NaN           NaN
# 882            NaN           NaN            NaN            NaN           NaN
# 883            NaN           NaN            NaN            NaN           NaN
# 884            NaN           NaN            NaN            NaN           NaN
#
#      Unnamed: 4042  Unnamed: 4043 Unnamed: 4044
# 0             LRPE      20.862917     92.298083
# 1              NaN            NaN           NaN
# 2              NaN            NaN           NaN
# 3              NaN            NaN           NaN
# 4              NaN            NaN           NaN
# ..             ...            ...           ...
# 880            NaN            NaN           NaN
# 881            NaN            NaN           NaN
# 882            NaN            NaN           NaN
# 883            NaN            NaN           NaN
# 884            NaN            NaN           NaN
#
# [885 rows x 4045 columns]

# %%
df_rds.head()
# Out:
#    road  lrp1       lat1       lon1    lrp2       lat2       lon2 Unnamed: 7  \
# 0    N1  LRPS  23.706028  90.443333   LRPSa  23.702917  90.450417      LRPSb
# 1  N101  LRPS  23.454139  91.212861   LRPSa  23.461889  91.212000     LRP001
# 2  N102  LRPS  23.478972  91.118194   LRPSa  23.481583  91.116777      LRPSb
# 3  N103  LRPS  23.957028  91.115528  LRP001  23.961917  91.113611    LRP001a
# 4  N104  LRPS  23.009667  91.399416   LRPSa  23.009278  91.395250     LRP001
#
#    Unnamed: 8  Unnamed: 9  ... Unnamed: 4035  Unnamed: 4036  Unnamed: 4037  \
# 0   23.702778   90.450472  ...      92.29825        LRP466c      20.864667
# 1   23.462944   91.211806  ...           NaN            NaN            NaN
# 2   23.486666   91.113361  ...           NaN            NaN            NaN
# 3   23.967666   91.111889  ...           NaN            NaN            NaN
# 4   23.009306   91.389805  ...           NaN            NaN            NaN
#
#   Unnamed: 4038  Unnamed: 4039  Unnamed: 4040 Unnamed: 4041  Unnamed: 4042  \
# 0     92.298194         LRP467      20.862972     92.298083           LRPE
# 1           NaN            NaN            NaN           NaN            NaN
# 2           NaN            NaN            NaN           NaN            NaN
# 3           NaN            NaN            NaN           NaN            NaN
# 4           NaN            NaN            NaN           NaN            NaN
#
#    Unnamed: 4043 Unnamed: 4044
# 0      20.862917     92.298083
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
#
# [5 rows x 4045 columns]

# %%
df_rds.tail()
# Out:
#       road  lrp1       lat1       lon1    lrp2       lat2       lon2  \
# 880  Z8910  LRPS  22.674722  90.408889   LRPSa  22.675916  90.412556
# 881  Z8913  LRPS  22.396083  90.688666   LRPSa  22.393027  90.688944
# 882  Z8915  LRPS  22.589389  90.619472  LRP001  22.589694  90.623360
# 883  Z8916  LRPS  22.625499  90.661722   LRPSa  22.623888  90.664167
# 884  Z8943  LRPS  22.426444  90.849472   LRPSa  22.426416  90.846833
#
#     Unnamed: 7  Unnamed: 8  Unnamed: 9  ... Unnamed: 4035  Unnamed: 4036  \
# 880     LRP001   22.675583   90.417166  ...           NaN            NaN
# 881      LRPSb   22.392666   90.689083  ...           NaN            NaN
# 882    LRP001a   22.590027   90.631360  ...           NaN            NaN
# 883     LRP001   22.620305   90.668999  ...           NaN            NaN
# 884     LRP001   22.425444   90.839861  ...           NaN            NaN
#
#      Unnamed: 4037 Unnamed: 4038  Unnamed: 4039  Unnamed: 4040 Unnamed: 4041  \
# 880            NaN           NaN            NaN            NaN           NaN
# 881            NaN           NaN            NaN            NaN           NaN
# 882            NaN           NaN            NaN            NaN           NaN
# 883            NaN           NaN            NaN            NaN           NaN
# 884            NaN           NaN            NaN            NaN           NaN
#
#      Unnamed: 4042  Unnamed: 4043 Unnamed: 4044
# 880            NaN            NaN           NaN
# 881            NaN            NaN           NaN
# 882            NaN            NaN           NaN
# 883            NaN            NaN           NaN
# 884            NaN            NaN           NaN
#
# [5 rows x 4045 columns]

# %%
all_data = []

for rd in df_rds.itertuples(index=False):
    rd_name = rd[0]

    for i in range(1, len(rd)-2, 3):
        lrp = rd[i]
        lat = rd[i+1]
        lon = rd[i+2]

        if pd.isna(lrp) and pd.isna(lat) and pd.isna(lon):
            continue

        all_data.append((rd_name, lrp, lat, lon))

df_all = pd.DataFrame(all_data, columns=["road", "LRP", "LAT", "LON"])

print(df_all)
# Out:
#         road      LRP        LAT        LON
# 0         N1     LRPS  23.706028  90.443333
# 1         N1    LRPSa  23.702917  90.450417
# 2         N1    LRPSb  23.702778  90.450472
# 3         N1   LRP001  23.702139  90.451972
# 4         N1   LRP002  23.697889  90.460583
# ...      ...      ...        ...        ...
# 52205  Z8943   LRP007  22.429499  90.785722
# 52206  Z8943   LRP008  22.430110  90.776333
# 52207  Z8943  LRP008a  22.430249  90.774888
# 52208  Z8943  LRP008b  22.430249  90.774860
# 52209  Z8943     LRPE  22.430166  90.768916
#
# [52210 rows x 4 columns]

# %%
df_all.isna().sum()
# Out:
# road    0
# LRP     0
# LAT     0
# LON     0
# dtype: int64

# %%
df_all.road.value_counts()
# df_rds_test = df_all[(df_all["road"] == "Z7504") |( df_all["road"] == "N101")]
# df_rds_test
# Out:
# road
# N1       1348
# N5       1235
# N2        897
# N7        540
# N8        522
#          ...
# R891        2
# Z7408       2
# N519        2
# N124        2
# R316        1
# Name: count, Length: 877, dtype: int64

# %%
df_rd1.plot(x="LON", y="LAT", title=f'{df_rd1.iloc[0].road}')
# Out:
# <Axes: title={'center': 'Z7504'}, xlabel='LON'>

# %%
df_rd1.describe()
# Out:
#              LAT        LON
# count  25.000000  25.000000
# mean   23.194345  89.169590
# std     0.023035   1.397787
# min    23.166306  82.460278
# 25%    23.175860  89.442944
# 50%    23.187639  89.448833
# 75%    23.209944  89.453028
# max    23.236722  89.460000

# %%
def calc_outliers(dataframe_road):
    dist_dict = {}
    outliers_road = []
    for i in range(0, len(dataframe_road) - 1, 1):
        point1 = dataframe_road.iloc[i]
        point2 = dataframe_road.iloc[i+1]
        coord1 = (point1.LAT, point1.LON)
        coord2 = (point2.LAT, point2.LON)
        distance = haversine(coord1, coord2)
        dist_dict[(point1.LRP, point2.LRP)] = distance
        median_road = 0 
        std_road = 0 
    
    # Safety Check: If data is too small to calculate stats, return early
        if len(dataframe_road) < 2:
            return outliers_road, median_road, std_road

        median_road = np.median(list(dist_dict.values()))
        std_road = np.std(list(dist_dict.values()))

    for (LRP1, LRP2), distance in dist_dict.items():
        if distance > median_road + STD_THRESHOLD * std_road:
            outliers_road.append((LRP1, LRP2, distance)) 
    return outliers_road, median_road, std_road

# outliers_r, median_r, std_r = calc_outliers(df_rd1)

# %%
def calc_lrp_outliers(outliers, std):
    lrp_outliers = []
    print(outliers)
    if outliers == []:
        return lrp_outliers
    if outliers[0][0] == 'LRPS':
        lrp1, lrp2, dist = outliers[0]
        if len(outliers) > 1 and outliers[1][0] == lrp2:
            lrp_outliers.append(lrp2)
        else:
            lrp_outliers.append(lrp1)
            outliers = outliers[1:]
        print(lrp_outliers)
    elif outliers[0][1] == 'LRPE':
        lrp_outliers.append(outliers[0][1])
        return lrp_outliers        

    for i in range(0, len(outliers) - 1, 1):
        lrp1, lrp2, dist = outliers[i]
        lrp2_2, lrp3, dist2 = outliers[i+1]
        if lrp2 == lrp2_2:
            print(f'De outlier is {lrp2}')
            lrp_outliers.append(lrp2)
        else:
            if abs(dist - dist2) < CLOSENESS_THRESHOLD * std:
                print(f'De outlier is {lrp2} maar ook {lrp2_2} is een outlier')
                lrp_outliers.append(lrp2)
                lrp_outliers.append(lrp2_2)
    return lrp_outliers

# %%
# # lrp_outliers
# lrp_outliers_r = calc_lrp_outliers(outliers_r)
# df_rd1_outliers = df_rd1[df_rd1["LRP"].isin(lrp_outliers_r)]
# df_rd1_outliers

# %%
# 1. Create the copy ONCE before the loop starts
# We will modify this dataframe cumulatively

def snap_point(lrp, df_to_fix, pos_idx, lrp_outliers):
    # USE LENGTH, NOT INDEX.MAX()
    # 'pos_idx' is 0, 1, 2... so max position is len() - 1
    max_pos = len(df_to_fix) - 1
    
    # -------------------------------------------------------
    # 1. Determine Neighbors & Mode based on POSITION
    # -------------------------------------------------------
    if pos_idx == 0:
        n1_pos = pos_idx + 1
        n2_pos = pos_idx + 2
        mode = 'extrapolate_backward' # Fixing Start

    elif pos_idx == max_pos:
        n1_pos = pos_idx - 1
        n2_pos = pos_idx - 2
        mode = 'extrapolate_forward'  # Fixing End

    else:
        n1_pos = pos_idx - 1
        n2_pos = pos_idx + 1
        mode = 'interpolate'          # Fixing Middle

    # -------------------------------------------------------
    # 2. Skip Bad Neighbors (Safety Check)
    # -------------------------------------------------------
    # Note: We read from df_to_fix (which might already have some fixes!)

    if n1_pos < 0 or n1_pos >= max_pos:
    # We reached the start or end of the road data without finding a valid neighbor
        return  # Stop looking to avoid the crash
    
    # Check Neighbor 1
    if df_to_fix.iloc[n1_pos]['LRP'] in lrp_outliers:
        step = 1 if n1_pos > pos_idx else -1
        n1_pos += step
    
    # Check Neighbor 2
    # Ensure n2_pos is still valid before checking
    if 0 <= n2_pos <= max_pos and df_to_fix.iloc[n2_pos]['LRP'] in lrp_outliers:
        step = 1 if n2_pos > pos_idx else -1
        n2_pos += step

    # Final Boundary Check
    if not (0 <= n1_pos <= max_pos) or not (0 <= n2_pos <= max_pos):
        print(f"Cannot fix {lrp}: Neighbors unavailable.")
        return

    # -------------------------------------------------------
    # 3. Calculate Logic (using iloc for positions)
    # -------------------------------------------------------
    p1 = df_to_fix.iloc[n1_pos]
    p2 = df_to_fix.iloc[n2_pos]
    curr_pt = df_to_fix.iloc[pos_idx]
    # print(f'{curr_pt} has neighbour {p1} and neighbour {p2}')

    # Calculate Expected Values
    if mode == 'interpolate':
        exp_lat = (p1['LAT'] + p2['LAT']) / 2.0
        exp_lon = (p1['LON'] + p2['LON']) / 2.0
        
    else: 
        # Both Extrapolations use the same vector logic: P1 + (Vector P2->P1)
        # P1 is the closer neighbor, P2 is the farther one.
        exp_lat = p1['LAT'] + (p1['LAT'] - p2['LAT'])
        exp_lon = p1['LON'] + (p1['LON'] - p2['LON'])

    # -------------------------------------------------------
    # 4. Apply Fix (Converting Position -> Label)
    # -------------------------------------------------------
    lat_diff = abs(curr_pt['LAT'] - exp_lat)
    lon_diff = abs(curr_pt['LON'] - exp_lon)

    # CRITICAL: We need the LABEL index (e.g., 1348) to write with .at[]
    real_label_index = df_to_fix.index[pos_idx]

    if lat_diff > lon_diff:
        print(f"Fixing {lrp} (Pos {pos_idx}): Snapped LAT to {exp_lat:.4f}")
        # Use real_label_index here!
        df_to_fix.at[real_label_index, 'LAT'] = exp_lat
    else:
        print(f"Fixing {lrp} (Pos {pos_idx}): Snapped LON to {exp_lon:.4f}")
        df_to_fix.at[real_label_index, 'LON'] = exp_lon


# --- MAIN LOOP ---
def fix_outliers(dataframe, lrp_outliers):
    df_cleaned = dataframe.copy()
    for outlier in lrp_outliers:
        print(outlier)
        # 1. Find Integer Position (0, 1, 2...)
        row_pos_array = np.where(dataframe['LRP'] == outlier)[0]
        if len(row_pos_array) > 0:
            row_pos = row_pos_array[0]
            # 2. Pass the CLEAN dataframe (df_cleaned) to be modified in place
            snap_point(outlier, df_cleaned, row_pos, lrp_outliers)
        else:
            print(f"Outlier {outlier} not found in dataframe.")
    return df_cleaned

# df_clean = fix_outliers(df_rd1, lrp_outliers_r)
# Plot the result
# df_cleaned.plot(x="LON", y="LAT", kind='scatter', title="Fixed Road")

# %%
# f, axes = plt.subplots(1,2, figsize=(12, 6), sharey=True)
# axes.flatten()
# axes[0].plot(df_rd1['LON'], df_rd1['LAT'], marker='o', label='Original N1')
# axes[0].set_title(f'Original {df_rd1.iloc[0].road}')
# axes[1].plot(df_clean['LON'], df_clean['LAT'],  label='Snapped N1')
# axes[1].set_title(f'Snapped {df_rd1.iloc[0].road}')

def check_lists(list1, list2):
    if list1 == (0,0, 0):
        return False
    print(list2)
    for i in range(0, len(list1)):
        print(list1[i])
        lrp1, lrp2, dist1 = list1[i]
        lrp1_2, lrp2_2, dist1_2 = list2[i]
        if lrp1 != lrp1_2 or lrp2 != lrp2_2:
            return False
    return True

# %%
def fix_road(dataframe_road):
    outliers_present = True
    df_rd1_copy = dataframe_road.copy()
    outliers_n, median_n, std_n = calc_outliers(df_rd1_copy)
    outliers_copy = [(0,0, 0), (0,0, 0)]
    iteration = 1
    while outliers_present:
        print(f'Started iteration {iteration}')
        outliers_n, median_n, std_n = calc_outliers(df_rd1_copy)
        lrp_outliers_n = calc_lrp_outliers(outliers_n, std_n)
        if len(outliers_n) == len(outliers_copy) and check_lists(outliers_copy, outliers_n):
            outliers_present = False
            print(f'Finished at iteration {iteration} as outliers are the same.')
            print(f'{outliers_n} and {outliers_copy}')
            print(f'{len(outliers_n)} ')
            break
        # outliers_n, median_n, std_n = calc_outliers(df_rd1_copy)
        # lrp_outliers_n = calc_lrp_outliers(outliers_n, std_n)
        if len(lrp_outliers_n) == 0:
            outliers_present = False
            break
        df_rd1_copy = fix_outliers(df_rd1_copy, lrp_outliers_n)
        outliers_copy = outliers_n.copy()
        iteration = iteration + 1
    return df_rd1_copy
    
print(f'Finished!')
# Out:
# Finished!

# %%
# print(outliers_n, std_n, median_n)

# %%
# f, axes = plt.subplots(1,2, figsize=(12, 6), sharey=True)
# axes.flatten()
# axes[0].plot(df_rd1['LON'], df_rd1['LAT'], marker='o', label='Original N1')
# axes[0].set_title(f'Original {df_rd1.iloc[0].road}')
# axes[1].plot(df_rd1_copy['LON'], df_rd1_copy ['LAT'],  label='Snapped N1')
# axes[1].set_title(f'Snapped {df_rd1.iloc[0].road}')

# %%
df_all.road.value_counts()
# Out:
# road
# N1       1348
# N5       1235
# N2        897
# N7        540
# N8        522
#          ...
# R891        2
# Z7408       2
# N519        2
# N124        2
# R316        1
# Name: count, Length: 877, dtype: int64

# %%
df_all_fixed = df_all.copy()
# df_all_fixed = df_rds_test.copy()
for road in df_all_fixed['road'].unique():
    print(f'Processing {road}...')
    df_road = df_all[df_all['road'] == road]
    if len(df_road) < 2:
        print(f'Skipping {road} as it has less than 2 points.')
        continue    
    df_fixed_road = fix_road(df_road)
    df_all_fixed.update(df_fixed_road)
    # df_all_fixed.loc[df_fixed_road.index, df_fixed_road.columns] = df_fixed_road
# Out:
# Processing N1...
# Started iteration 1
# [('LRP027', 'LRP027a', 111.84824949348993), ('LRP027a', 'LRP028', 111.0931563552762), ('LRP064', 'LRP065', 111.47715734515256), ('LRP065', 'LRP066', 111.10189753970427), ('LRP107', 'LRP108', 112.00885901900824), ('LRP108', 'LRP108a', 110.85878398839243), ('LRP230b', 'LRP230c', 38.91827808173692), ('LRP230c', 'LRP231', 39.49613835055684), ('LRP323', 'LRP323a', 110.69470240938722), ('LRP324', 'LRP324a', 112.08456918919227), ('LRP331c', 'LRP332', 111.18272646011935), ('LRP332', 'LRP333', 112.16504868589224), ('LRP391', 'LRP391a', 103.39328221435402), ('LRP391a', 'LRP391b', 103.63281970344522), ('LRP395a', 'LRP395b', 103.54128418106178), ('LRP395b', 'LRP395c', 103.57047493461667)]
# De outlier is LRP027a
# De outlier is LRP028 maar ook LRP064 is een outlier
# De outlier is LRP065
# De outlier is LRP066 maar ook LRP107 is een outlier
# De outlier is LRP108
# De outlier is LRP230c
# De outlier is LRP323a maar ook LRP324 is een outlier
# De outlier is LRP324a maar ook LRP331c is een outlier
# De outlier is LRP332
# De outlier is LRP391a
# De outlier is LRP391b maar ook LRP395a is een outlier
# De outlier is LRP395b
# LRP027a
# Fixing LRP027a (Pos 69): Snapped LAT to 23.5861
# LRP028
# Fixing LRP028 (Pos 70): Snapped LAT to 23.5861
# LRP064
# Fixing LRP064 (Pos 153): Snapped LON to 90.9532
# LRP065
# Fixing LRP065 (Pos 154): Snapped LAT to 23.5005
# LRP066
# Fixing LRP066 (Pos 155): Snapped LON to 90.9596
# LRP107
# Fixing LRP107 (Pos 232): Snapped LAT to 23.3423
# LRP108
# Fixing LRP108 (Pos 233): Snapped LAT to 23.3423
# LRP230c
# Fixing LRP230c (Pos 553): Snapped LAT to 22.4058
# LRP323a
# Fixing LRP323a (Pos 792): Snapped LAT to 21.8710
# LRP324
# Fixing LRP324 (Pos 793): Snapped LAT to 21.8705
# LRP324a
# Fixing LRP324a (Pos 794): Snapped LAT to 21.8663
# LRP331c
# Fixing LRP331c (Pos 816): Snapped LAT to 21.7987
# LRP332
# Fixing LRP332 (Pos 817): Snapped LAT to 21.7987
# LRP391a
# Fixing LRP391a (Pos 993): Snapped LON to 92.0571
# LRP391b
# Fixing LRP391b (Pos 994): Snapped LAT to 21.4075
# LRP395a
# Fixing LRP395a (Pos 1015): Snapped LAT to 21.3785
# LRP395b
# Fixing LRP395b (Pos 1016): Snapped LON to 92.0706
# Started iteration 2
# [('LRP224b', 'LRP225', 27.125845116647483), ('LRP225', 'LRP226', 27.743799565331084), ('LRP234a', 'LRP234b', 22.223573981856408), ('LRP234b', 'LRP235', 23.038998591457002), ('LRP235b', 'LRP244b', 7.107528003651441), ('LRP321', 'LRP321a', 5.62264556585013), ('LRP321a', 'LRP321b', 4.949506744591913)]
# De outlier is LRP225
# De outlier is LRP234b
# De outlier is LRP321a
# LRP225
# Fixing LRP225 (Pos 538): Snapped LON to 91.7334
# LRP234b
# Fixing LRP234b (Pos 567): Snapped LAT to 22.3728
# LRP321a
# Fixing LRP321a (Pos 787): Snapped LAT to 21.8939
# Started iteration 3
# [('LRP039', 'LRP039a', 1.724000310522732), ('LRP039a', 'LRP040', 1.8248547453305783), ('LRP099b', 'LRP100', 1.399876303017012), ('LRP100', 'LRP101', 2.692921783995135), ('LRP149', 'LRP150', 1.3874299963580772), ('LRP174a', 'LRP174b', 2.0231111032536577), ('LRP221', 'LRP221a', 2.2404385020121387), ('LRP221a', 'LRP221b', 1.36457489872132), ('LRP235b', 'LRP244b', 7.107528003651441), ('LRP454', 'LRP454a', 1.546503120910267), ('LRP454a', 'LRP454b', 1.9764867569306264)]
# De outlier is LRP039a
# De outlier is LRP100
# De outlier is LRP221a
# De outlier is LRP454a
# LRP039a
# Fixing LRP039a (Pos 108): Snapped LAT to 23.5322
# LRP100
# Fixing LRP100 (Pos 216): Snapped LAT to 23.3975
# LRP221a
# Fixing LRP221a (Pos 529): Snapped LAT to 22.4815
# LRP454a
# Fixing LRP454a (Pos 1276): Snapped LAT to 20.9502
# Started iteration 4
# [('LRP149', 'LRP150', 1.3874299963580772), ('LRP174', 'LRP174a', 1.304374198044875), ('LRP174a', 'LRP174b', 2.0231111032536577), ('LRP235b', 'LRP244b', 7.107528003651441)]
# De outlier is LRP174a
# LRP174a
# Fixing LRP174a (Pos 386): Snapped LAT to 22.8628
# Started iteration 5
# [('LRP149', 'LRP150', 1.3874299963580772), ('LRP235b', 'LRP244b', 7.107528003651441)]
# Processing N101...
# Started iteration 1
# []
# Processing N102...
# Started iteration 1
# [('LRP063b', 'LRP064', 223.06986056861743), ('LRP064', 'LRP064a', 222.12454351533535), ('LRP073', 'LRP073a', 96.62227572568078), ('LRP073a', 'LRP073b', 96.71494558052152)]
# De outlier is LRP064
# De outlier is LRP073a
# LRP064
# Fixing LRP064 (Pos 178): Snapped LAT to 23.8991
# LRP073a
# Fixing LRP073a (Pos 201): Snapped LAT to 23.9706
# Started iteration 2
# [('LRP050b', 'LRP050c', 37.05571773829668), ('LRP050c', 'LRP051', 37.12376915859726), ('LRP054', 'LRP055', 14.965874417688934), ('LRP055', 'LRP055a', 14.79128445178832)]
# De outlier is LRP050c
# De outlier is LRP055
# [('LRP050b', 'LRP050c', 37.05571773829668), ('LRP050c', 'LRP051', 37.12376915859726), ('LRP054', 'LRP055', 14.965874417688934), ('LRP055', 'LRP055a', 14.79128445178832)]
# ('LRP063b', 'LRP064', 223.06986056861743)
# LRP050c
# Fixing LRP050c (Pos 141): Snapped LAT to 23.7936
# LRP055
# Fixing LRP055 (Pos 151): Snapped LON to 91.1544
# Started iteration 3
# [('LRP016', 'LRP017', 9.22559910836038), ('LRP017', 'LRP017a', 10.497373242791303)]
# De outlier is LRP017
# LRP017
# Fixing LRP017 (Pos 31): Snapped LON to 91.0221
# Started iteration 4
# [('LRP011b', 'LRP012', 1.8624594679928108), ('LRP013', 'LRP014', 1.7934508302864443), ('LRP038c', 'LRP038d', 1.5848726929478143), ('LRP038d', 'LRP039', 1.8625442685514502), ('LRP044c', 'LRP044d', 1.710387230772968), ('LRP046a', 'LRP046b', 1.8655613613404776)]
# De outlier is LRP012 maar ook LRP013 is een outlier
# De outlier is LRP038d
# LRP012
# Fixing LRP012 (Pos 25): Snapped LON to 91.0484
# LRP013
# Fixing LRP013 (Pos 26): Snapped LAT to 23.5635
# LRP038d
# Fixing LRP038d (Pos 105): Snapped LAT to 23.7163
# Started iteration 5
# [('LRP011b', 'LRP012', 1.979170376266478), ('LRP013', 'LRP014', 2.3137829564766634), ('LRP044b', 'LRP044c', 1.5077050210051286), ('LRP044c', 'LRP044d', 1.710387230772968), ('LRP046a', 'LRP046b', 1.8655613613404776)]
# De outlier is LRP044c
# LRP044c
# Fixing LRP044c (Pos 124): Snapped LON to 91.0995
# Started iteration 6
# [('LRP011b', 'LRP012', 1.979170376266478), ('LRP013', 'LRP014', 2.3137829564766634), ('LRP046', 'LRP046a', 1.4589613940914463), ('LRP046a', 'LRP046b', 1.8655613613404776)]
# De outlier is LRP046a
# LRP046a
# Fixing LRP046a (Pos 129): Snapped LAT to 23.7677
# Started iteration 7
# [('LRP011b', 'LRP012', 1.979170376266478), ('LRP013', 'LRP014', 2.3137829564766634)]
# Processing N103...
# Started iteration 1
# []
# Processing N104...
# Started iteration 1
# [('LRP010', 'LRP010a', 2.459375473537201), ('LRP049b', 'LRP049c', 2.8723448367517634), ('LRP049c', 'LRPE', 3.104267924061507)]
# De outlier is LRP049c
# LRP049c
# Fixing LRP049c (Pos 123): Snapped LAT to 22.8268
# Started iteration 2
# [('LRP010', 'LRP010a', 2.459375473537201)]
# Processing N105...
# Started iteration 1
# [('LRP031d', 'LRP032', 1.6051564645899528)]
# Processing N106...
# Started iteration 1
# [('LRP036e', 'LRP036f', 1.1556064979292286)]
# Processing N107...
# Started iteration 1
# []
# Processing N108...
# Started iteration 1
# [('LRP003', 'LRP004', 0.9816620889865965), ('LRP004', 'LRP004a', 0.9422151666710038), ('LRP009', 'LRP010', 0.9523454000124866), ('LRP017', 'LRP018', 0.9343074780756176)]
# De outlier is LRP004
# De outlier is LRP004a maar ook LRP009 is een outlier
# De outlier is LRP010 maar ook LRP017 is een outlier
# LRP004
# Fixing LRP004 (Pos 13): Snapped LAT to 22.1172
# LRP004a
# Fixing LRP004a (Pos 14): Snapped LON to 92.1081
# LRP009
# Fixing LRP009 (Pos 32): Snapped LON to 92.1534
# LRP010
# Fixing LRP010 (Pos 33): Snapped LON to 92.1534
# LRP017
# Fixing LRP017 (Pos 71): Snapped LAT to 22.1749
# Started iteration 2
# [('LRP003', 'LRP004', 1.03265453970103)]
# Processing N109...
# Started iteration 1
# []
# Processing N110...
# Started iteration 1
# []
# Processing N111...
# Started iteration 1
# [('LRP012a', 'LRPE', 111.27848101356476)]
# LRPE
# Fixing LRPE (Pos 44): Snapped LAT to 22.2852
# Started iteration 2
# [('LRP012', 'LRP012a', 1.5654553308249508), ('LRP012a', 'LRPE', 1.5632629408096355)]
# De outlier is LRP012a
# LRP012a
# Fixing LRP012a (Pos 43): Snapped LON to 91.7919
# Started iteration 3
# [('LRP012', 'LRP012a', 1.5632081844569672), ('LRP012a', 'LRPE', 1.56320823702747)]
# De outlier is LRP012a
# [('LRP012', 'LRP012a', 1.5632081844569672), ('LRP012a', 'LRPE', 1.56320823702747)]
# ('LRP012', 'LRP012a', 1.5654553308249508)
# ('LRP012a', 'LRPE', 1.5632629408096355)
# Finished at iteration 3 as outliers are the same.
# [('LRP012', 'LRP012a', 1.5632081844569672), ('LRP012a', 'LRPE', 1.56320823702747)] and [('LRP012', 'LRP012a', 1.5654553308249508), ('LRP012a', 'LRPE', 1.5632629408096355)]
# 2
# Processing N112...
# Started iteration 1
# []
# Processing N119...
# Started iteration 1
# []
# Processing N120...
# Started iteration 1
# [('LRP016', 'LRP017', 1.2522599683500348)]
# Processing N123...
# Started iteration 1
# []
# Processing N124...
# Started iteration 1
# []
# Processing N125...
# Started iteration 1
# []
# Processing N126...
# Started iteration 1
# []
# Processing N127...
# Started iteration 1
# []
# Processing N128...
# Started iteration 1
# []
# Processing N129...
# Started iteration 1
# []
# Processing N2...
# Started iteration 1
# [('LRP019a', 'LRP019b', 222.6095386220969), ('LRP019b', 'LRP020', 222.18638115555137), ('LRP020a', 'LRP021', 110.98532440944466), ('LRP021', 'LRP021a', 111.37445770574921), ('LRP042', 'LRP042a', 333.6161312644664), ('LRP042a', 'LRP042b', 333.3011526178789), ('LRP113a', 'LRP113b', 333.60068611522087), ('LRP113b', 'LRP114', 333.0942286918626), ('LRP174a', 'LRP174b', 111.17963527273969), ('LRP174b', 'LRP174c', 111.41749453714608), ('LRP180', 'LRP180a', 222.32839161804665), ('LRP180a', 'LRP180b', 222.40560546371), ('LRP228d', 'LRP229', 222.3839909336706), ('LRP229', 'LRP229a', 222.49215122927012)]
# De outlier is LRP019b
# De outlier is LRP021
# De outlier is LRP042a
# De outlier is LRP042b maar ook LRP113a is een outlier
# De outlier is LRP113b
# De outlier is LRP174b
# De outlier is LRP180a
# De outlier is LRP180b maar ook LRP228d is een outlier
# De outlier is LRP229
# LRP019b
# Fixing LRP019b (Pos 39): Snapped LAT to 23.8362
# LRP021
# Fixing LRP021 (Pos 42): Snapped LAT to 23.8438
# LRP042a
# Fixing LRP042a (Pos 97): Snapped LAT to 23.9725
# LRP042b
# Fixing LRP042b (Pos 98): Snapped LAT to 23.9725
# LRP113a
# Fixing LRP113a (Pos 309): Snapped LAT to 24.1276
# LRP113b
# Fixing LRP113b (Pos 310): Snapped LAT to 24.1276
# LRP174b
# Fixing LRP174b (Pos 557): Snapped LAT to 24.5224
# LRP180a
# Fixing LRP180a (Pos 589): Snapped LAT to 24.5729
# LRP180b
# Fixing LRP180b (Pos 590): Snapped LAT to 24.5729
# LRP228d
# Fixing LRP228d (Pos 736): Snapped LON to 91.8762
# LRP229
# Fixing LRP229 (Pos 737): Snapped LAT to 24.8782
# Started iteration 2
# [('LRP039a', 'LRP039b', 28.400424488557384), ('LRP039b', 'LRP040', 28.837328463595604), ('LRP084a', 'LRP085', 42.682488117399224), ('LRP085', 'LRP085a', 42.61858506337071), ('LRP128', 'LRP128a', 51.983749351186106), ('LRP128a', 'LRP128b', 51.597693576040115), ('LRP166a', 'LRP166b', 33.746073703767514), ('LRP166b', 'LRP166c', 33.718419546717556)]
# De outlier is LRP039b
# De outlier is LRP085
# De outlier is LRP128a
# De outlier is LRP166b
# LRP039b
# Fixing LRP039b (Pos 89): Snapped LON to 90.7130
# LRP085
# Fixing LRP085 (Pos 229): Snapped LAT to 24.0483
# LRP128a
# Fixing LRP128a (Pos 369): Snapped LAT to 24.2408
# LRP166b
# Fixing LRP166b (Pos 508): Snapped LON to 91.5721
# Started iteration 3
# [('LRP040a', 'LRP040b', 1.5320270332820907), ('LRP040b', 'LRP041', 1.8059418484757674), ('LRP121a', 'LRP122', 2.270276933805946), ('LRP158a', 'LRP159', 1.918612476023921), ('LRP162a', 'LRP162b', 1.549467795816031), ('LRP162b', 'LRP162c', 2.0017786689286106), ('LRP164e', 'LRP165', 5.050595453965868), ('LRP165', 'LRP165a', 5.126724251311697), ('LRP205', 'LRP205a', 2.012318857348398), ('LRP211', 'LRP211a', 1.5371042073012946), ('LRP211a', 'LRP211b', 1.462617390156336), ('LRP261', 'LRP261a', 1.5242664175578466), ('LRP261a', 'LRP261b', 2.090788967760401), ('LRP271a', 'LRP271b', 1.9247291561821043), ('LRP273', 'LRP273a', 1.5826898094792683)]
# De outlier is LRP040b
# De outlier is LRP162b
# De outlier is LRP165
# De outlier is LRP211a
# De outlier is LRP211b maar ook LRP261 is een outlier
# De outlier is LRP261a
# LRP040b
# Fixing LRP040b (Pos 92): Snapped LON to 90.7180
# LRP162b
# Fixing LRP162b (Pos 485): Snapped LAT to 24.4187
# LRP165
# Fixing LRP165 (Pos 501): Snapped LON to 91.5702
# LRP211a
# Fixing LRP211a (Pos 688): Snapped LON to 91.7833
# LRP211b
# Fixing LRP211b (Pos 689): Snapped LAT to 24.7681
# LRP261
# Fixing LRP261 (Pos 821): Snapped LON to 92.0999
# LRP261a
# Fixing LRP261a (Pos 822): Snapped LAT to 25.0515
# Started iteration 4
# [('LRP121', 'LRP121a', 1.2740700445353343), ('LRP121a', 'LRP122', 2.270276933805946), ('LRP158', 'LRP158a', 1.1830196101336772), ('LRP158a', 'LRP159', 1.918612476023921), ('LRP204', 'LRP205', 1.3099410256690858), ('LRP205', 'LRP205a', 2.012318857348398), ('LRP271a', 'LRP271b', 1.9247291561821043), ('LRP273', 'LRP273a', 1.5826898094792683)]
# De outlier is LRP121a
# De outlier is LRP158a
# De outlier is LRP205
# LRP121a
# Fixing LRP121a (Pos 341): Snapped LAT to 24.1845
# LRP158a
# Fixing LRP158a (Pos 470): Snapped LAT to 24.3870
# LRP205
# Fixing LRP205 (Pos 672): Snapped LAT to 24.7189
# Started iteration 5
# [('LRP271', 'LRP271a', 1.1461503328454816), ('LRP271a', 'LRP271b', 1.9247291561821043), ('LRP273', 'LRP273a', 1.5826898094792683)]
# De outlier is LRP271a
# LRP271a
# Fixing LRP271a (Pos 851): Snapped LAT to 25.1354
# Started iteration 6
# [('LRP273', 'LRP273a', 1.5826898094792683)]
# Processing N203...
# Started iteration 1
# []
# Processing N204...
# Started iteration 1
# [('LRP017a', 'LRP017b', 14.614787853254668), ('LRP017b', 'LRP017c', 14.85687673615763), ('LRP019', 'LRP020', 16.11864977457653), ('LRP020', 'LRP021', 17.623116176381362)]
# De outlier is LRP017b
# De outlier is LRP020
# LRP017b
# Fixing LRP017b (Pos 41): Snapped LAT to 24.1338
# LRP020
# Fixing LRP020 (Pos 51): Snapped LAT to 24.1521
# Started iteration 2
# [('LRP032', 'LRP033', 1.2133439833253414)]
# Processing N205...
# Started iteration 1
# []
# Processing N206...
# Started iteration 1
# []
# Processing N207...
# Started iteration 1
# [('LRP040', 'LRP040a', 111.51323331943489), ('LRP040a', 'LRP040b', 110.93868948059563)]
# De outlier is LRP040a
# [('LRP040', 'LRP040a', 111.51323331943489), ('LRP040a', 'LRP040b', 110.93868948059563)]
# (0, 0, 0)
# LRP040a
# Fixing LRP040a (Pos 108): Snapped LAT to 24.4476
# Started iteration 2
# [('LRP043c', 'LRP044', 37.81258766605473), ('LRP044', 'LRP045', 36.08737211834939)]
# De outlier is LRP044
# [('LRP043c', 'LRP044', 37.81258766605473), ('LRP044', 'LRP045', 36.08737211834939)]
# ('LRP040', 'LRP040a', 111.51323331943489)
# LRP044
# Fixing LRP044 (Pos 119): Snapped LAT to 24.4814
# Started iteration 3
# [('LRP030b', 'LRP030c', 1.9609350198016287), ('LRP030c', 'LRP031', 1.6884536467266424), ('LRP033', 'LRP033a', 1.7333113209419533), ('LRP033a', 'LRP033b', 2.205638562234088)]
# De outlier is LRP030c
# De outlier is LRP031 maar ook LRP033 is een outlier
# De outlier is LRP033a
# LRP030c
# Fixing LRP030c (Pos 82): Snapped LON to 91.7496
# LRP031
# Fixing LRP031 (Pos 83): Snapped LAT to 24.3634
# LRP033
# Fixing LRP033 (Pos 88): Snapped LAT to 24.3841
# LRP033a
# Fixing LRP033a (Pos 89): Snapped LAT to 24.3841
# Started iteration 4
# []
# Processing N208...
# Started iteration 1
# [('LRP049a', 'LRP049b', 3.688068757942916), ('LRP049b', 'LRP050', 4.5253531350115095)]
# De outlier is LRP049b
# [('LRP049a', 'LRP049b', 3.688068757942916), ('LRP049b', 'LRP050', 4.5253531350115095)]
# (0, 0, 0)
# LRP049b
# Fixing LRP049b (Pos 161): Snapped LAT to 24.8073
# Started iteration 2
# [('LRP050', 'LRP051', 1.3410066660990947)]
# Processing N209...
# Started iteration 1
# []
# Processing N210...
# Started iteration 1
# []
# Processing N211...
# Started iteration 1
# []
# Processing N212...
# Started iteration 1
# []
# Processing N213...
# Started iteration 1
# []
# Processing N3...
# Started iteration 1
# []
# Processing N302...
# Started iteration 1
# []
# Processing N303...
# Started iteration 1
# []
# Processing N309...
# Started iteration 1
# []
# Processing N4...
# Started iteration 1
# [('LRP067b', 'LRP068', 110.75028245845296), ('LRP068', 'LRP068a', 111.5194109777118), ('LRP069b', 'LRP070', 33.72187763128284), ('LRP070', 'LRP071', 33.81720109317344)]
# De outlier is LRP068
# De outlier is LRP070
# LRP068
# Fixing LRP068 (Pos 166): Snapped LAT to 24.3013
# LRP070
# Fixing LRP070 (Pos 172): Snapped LON to 89.9245
# Started iteration 2
# [('LRP048', 'LRP048a', 9.881254070347167), ('LRP048a', 'LRP048b', 10.166746600731443)]
# De outlier is LRP048a
# LRP048a
# Fixing LRP048a (Pos 109): Snapped LON to 90.0157
# Started iteration 3
# [('LRP014', 'LRP014a', 1.8861842246511336), ('LRP022', 'LRP022a', 1.9866782030969976), ('LRP071c', 'LRP071d', 1.597005143330199), ('LRP071d', 'LRP072', 2.1097066536411844), ('LRP085b', 'LRP086', 1.738405195137859), ('LRP086', 'LRP086a', 1.7710581239829621), ('LRP137', 'LRP137a', 2.561422408101463)]
# De outlier is LRP071d
# De outlier is LRP086
# LRP071d
# Fixing LRP071d (Pos 177): Snapped LAT to 24.3347
# LRP086
# Fixing LRP086 (Pos 221): Snapped LON to 89.9888
# Started iteration 4
# [('LRP014', 'LRP014a', 1.8861842246511336), ('LRP022', 'LRP022a', 1.9866782030969976), ('LRP092a', 'LRP093', 1.5817855101423441), ('LRP137', 'LRP137a', 2.561422408101463)]
# Processing N401...
# Started iteration 1
# [('LRP003a', 'LRP003b', 1.7157247654627257), ('LRP043', 'LRP044', 2.6584350209307925)]
# [('LRP003a', 'LRP003b', 1.7157247654627257), ('LRP043', 'LRP044', 2.6584350209307925)]
# (0, 0, 0)
# Processing N402...
# Started iteration 1
# [('LRP007a', 'LRP007b', 1.6216777420619652), ('LRP007b', 'LRP007c', 1.6541120842682115), ('LRP012a', 'LRP012b', 1.7094667475621064), ('LRP015b', 'LRP015c', 1.6186597624829715)]
# De outlier is LRP007b
# De outlier is LRP007c maar ook LRP012a is een outlier
# LRP007b
# Fixing LRP007b (Pos 22): Snapped LON to 90.1676
# LRP007c
# Fixing LRP007c (Pos 23): Snapped LAT to 25.0368
# LRP012a
# Fixing LRP012a (Pos 36): Snapped LON to 90.1828
# Started iteration 2
# [('LRP015b', 'LRP015c', 1.6186597624829715)]
# Processing N403...
# Started iteration 1
# []
# Processing N404...
# Started iteration 1
# []
# Processing N405...
# Started iteration 1
# []
# Processing N406...
# Started iteration 1
# []
# Processing N407...
# Started iteration 1
# []
# Processing N408...
# Started iteration 1
# []
# Processing N5...
# Started iteration 1
# [('LRP522', 'LRP523', 332.6248194216862), ('LRP523', 'LRP524', 334.5428537001211)]
# De outlier is LRP523
# [('LRP522', 'LRP523', 332.6248194216862), ('LRP523', 'LRP524', 334.5428537001211)]
# (0, 0, 0)
# LRP523
# Fixing LRP523 (Pos 1232): Snapped LAT to 26.6246
# Started iteration 2
# [('LRP078a', 'LRP098a', 19.522229084355263), ('LRP251', 'LRP252', 2.8021459435747613), ('LRP513', 'LRP514', 2.3337271958850154)]
# Processing N501...
# Started iteration 1
# [('LRP010', 'LRP011', 2.657863154795039)]
# Processing N502...
# Started iteration 1
# [('LRP026', 'LRP026a', 22.283944868739574), ('LRP026a', 'LRP027', 21.707432365081072)]
# De outlier is LRP026a
# [('LRP026', 'LRP026a', 22.283944868739574), ('LRP026a', 'LRP027', 21.707432365081072)]
# (0, 0, 0)
# LRP026a
# Fixing LRP026a (Pos 41): Snapped LON to 89.2441
# Started iteration 2
# [('LRP017', 'LRP018', 2.7069983547320335), ('LRP026', 'LRP026a', 2.3310814607728343), ('LRP036', 'LRP036a', 1.8370105535345072)]
# Processing N503...
# Started iteration 1
# []
# Processing N504...
# Started iteration 1
# []
# Processing N505...
# Started iteration 1
# []
# Processing N506...
# Started iteration 1
# [('LRP033', 'LRP033a', 1.6066941183357957), ('LRP034', 'LRP034a', 2.196381759485309), ('LRP045', 'LRP045a', 1.8691204386054554)]
# Processing N507...
# Started iteration 1
# [('LRP001', 'LRP002', 110.93279288473279), ('LRP002b', 'LRP002c', 111.31294864528647)]
# De outlier is LRP002 maar ook LRP002b is een outlier
# [('LRP001', 'LRP002', 110.93279288473279), ('LRP002b', 'LRP002c', 111.31294864528647)]
# (0, 0, 0)
# LRP002
# Fixing LRP002 (Pos 2): Snapped LAT to 24.9176
# LRP002b
# Fixing LRP002b (Pos 4): Snapped LAT to 24.9150
# Started iteration 2
# [('LRP001', 'LRP002', 55.46669508657908), ('LRP002', 'LRP002a', 55.46013931842487), ('LRP002a', 'LRP002b', 55.7551887055363), ('LRP002b', 'LRP002c', 55.75296302752066)]
# De outlier is LRP002
# De outlier is LRP002a
# De outlier is LRP002b
# LRP002
# Fixing LRP002 (Pos 2): Snapped LAT to 24.6669
# LRP002a
# Fixing LRP002a (Pos 3): Snapped LAT to 24.4162
# LRP002b
# Fixing LRP002b (Pos 4): Snapped LAT to 24.5403
# Started iteration 3
# [('LRP001', 'LRP002', 27.597363535524604), ('LRP002', 'LRP002a', 27.876006609205728), ('LRP002a', 'LRP002b', 13.805184549977014), ('LRP002b', 'LRP002c', 14.087825493052783)]
# De outlier is LRP002
# De outlier is LRP002a
# De outlier is LRP002b
# [('LRP001', 'LRP002', 27.597363535524604), ('LRP002', 'LRP002a', 27.876006609205728), ('LRP002a', 'LRP002b', 13.805184549977014), ('LRP002b', 'LRP002c', 14.087825493052783)]
# ('LRP001', 'LRP002', 55.46669508657908)
# ('LRP002', 'LRP002a', 55.46013931842487)
# ('LRP002a', 'LRP002b', 55.7551887055363)
# ('LRP002b', 'LRP002c', 55.75296302752066)
# Finished at iteration 3 as outliers are the same.
# [('LRP001', 'LRP002', 27.597363535524604), ('LRP002', 'LRP002a', 27.876006609205728), ('LRP002a', 'LRP002b', 13.805184549977014), ('LRP002b', 'LRP002c', 14.087825493052783)] and [('LRP001', 'LRP002', 55.46669508657908), ('LRP002', 'LRP002a', 55.46013931842487), ('LRP002a', 'LRP002b', 55.7551887055363), ('LRP002b', 'LRP002c', 55.75296302752066)]
# 4
# Processing N508...
# Started iteration 1
# []
# Processing N509...
# Started iteration 1
# [('LRP039a', 'LRP040', 1.7181427097434754), ('LRP094a', 'LRP095', 1.896128880086036)]
# [('LRP039a', 'LRP040', 1.7181427097434754), ('LRP094a', 'LRP095', 1.896128880086036)]
# (0, 0, 0)
# Processing N510...
# Started iteration 1
# []
# Processing N511...
# Started iteration 1
# [('LRP006', 'LRP007', 102.33709811119296), ('LRP007', 'LRP008', 100.99425672671063)]
# De outlier is LRP007
# [('LRP006', 'LRP007', 102.33709811119296), ('LRP007', 'LRP008', 100.99425672671063)]
# (0, 0, 0)
# LRP007
# Fixing LRP007 (Pos 18): Snapped LON to 90.3168
# Started iteration 2
# []
# Processing N513...
# Started iteration 1
# [('LRP002', 'LRP005a', 3.6669807524075138)]
# Processing N514...
# Started iteration 1
# []
# Processing N515...
# Started iteration 1
# [('LRP001a', 'LRP002', 1.435615664524108)]
# Processing N516...
# Started iteration 1
# []
# Processing N517...
# Started iteration 1
# [('LRP004b', 'LRP005', 0.9540872927481078)]
# Processing N518...
# Started iteration 1
# []
# Processing N519...
# Started iteration 1
# []
# Processing N520...
# Started iteration 1
# []
# Processing N540...
# Started iteration 1
# []
# Processing N6...
# Started iteration 1
# [('LRP108a', 'LRP109', 100.41319406329679), ('LRP112', 'LRP112a', 101.42460358429379), ('LRP217', 'LRP217a', 111.1734550735622), ('LRP217a', 'LRP217b', 111.93026518619112), ('LRP230b', 'LRPE', 67.33899075121712)]
# De outlier is LRP109 maar ook LRP112 is een outlier
# De outlier is LRP217a
# LRP109
# Fixing LRP109 (Pos 212): Snapped LON to 89.4316
# LRP112
# Fixing LRP112 (Pos 216): Snapped LON to 89.4084
# LRP217a
# Fixing LRP217a (Pos 407): Snapped LAT to 24.7302
# Started iteration 2
# [('LRP108a', 'LRP109', 49.78128469390697), ('LRP109', 'LRP110', 49.78318883903287), ('LRP111a', 'LRP112', 51.036888229793014), ('LRP112', 'LRP112a', 51.03508107239378), ('LRP230b', 'LRPE', 67.33899075121712)]
# De outlier is LRP109
# De outlier is LRP112
# [('LRP108a', 'LRP109', 49.78128469390697), ('LRP109', 'LRP110', 49.78318883903287), ('LRP111a', 'LRP112', 51.036888229793014), ('LRP112', 'LRP112a', 51.03508107239378), ('LRP230b', 'LRPE', 67.33899075121712)]
# ('LRP108a', 'LRP109', 100.41319406329679)
# ('LRP112', 'LRP112a', 101.42460358429379)
# LRP109
# Fixing LRP109 (Pos 212): Snapped LAT to 24.3931
# LRP112
# Fixing LRP112 (Pos 216): Snapped LAT to 24.3777
# Started iteration 3
# [('LRP108a', 'LRP109', 49.78128469390697), ('LRP109', 'LRP110', 49.78318883903287), ('LRP111a', 'LRP112', 51.034431416632124), ('LRP112', 'LRP112a', 51.036124317971094), ('LRP230b', 'LRPE', 67.33899075121712)]
# De outlier is LRP109
# De outlier is LRP112
# [('LRP108a', 'LRP109', 49.78128469390697), ('LRP109', 'LRP110', 49.78318883903287), ('LRP111a', 'LRP112', 51.034431416632124), ('LRP112', 'LRP112a', 51.036124317971094), ('LRP230b', 'LRPE', 67.33899075121712)]
# ('LRP108a', 'LRP109', 49.78128469390697)
# ('LRP109', 'LRP110', 49.78318883903287)
# ('LRP111a', 'LRP112', 51.036888229793014)
# ('LRP112', 'LRP112a', 51.03508107239378)
# ('LRP230b', 'LRPE', 67.33899075121712)
# Finished at iteration 3 as outliers are the same.
# [('LRP108a', 'LRP109', 49.78128469390697), ('LRP109', 'LRP110', 49.78318883903287), ('LRP111a', 'LRP112', 51.034431416632124), ('LRP112', 'LRP112a', 51.036124317971094), ('LRP230b', 'LRPE', 67.33899075121712)] and [('LRP108a', 'LRP109', 49.78128469390697), ('LRP109', 'LRP110', 49.78318883903287), ('LRP111a', 'LRP112', 51.036888229793014), ('LRP112', 'LRP112a', 51.03508107239378), ('LRP230b', 'LRPE', 67.33899075121712)]
# 5
# Processing N602...
# Started iteration 1
# []
# Processing N603...
# Started iteration 1
# [('LRP003', 'LRP003a', 0.723686327847079), ('LRP012b', 'LRP013', 0.868976631554427)]
# [('LRP003', 'LRP003a', 0.723686327847079), ('LRP012b', 'LRP013', 0.868976631554427)]
# (0, 0, 0)
# Processing N604...
# Started iteration 1
# [('LRP003a', 'LRP003b', 1.518265765923268), ('LRP003b', 'LRP003c', 1.6341347443063499)]
# De outlier is LRP003b
# [('LRP003a', 'LRP003b', 1.518265765923268), ('LRP003b', 'LRP003c', 1.6341347443063499)]
# (0, 0, 0)
# LRP003b
# Fixing LRP003b (Pos 16): Snapped LON to 89.2332
# Started iteration 2
# []
# Processing N605...
# Started iteration 1
# []
# Processing N7...
# Started iteration 1
# [('LRP190', 'LRP190a', 111.07473998021659), ('LRP190a', 'LRP190b', 111.21052815305156)]
# De outlier is LRP190a
# [('LRP190', 'LRP190a', 111.07473998021659), ('LRP190a', 'LRP190b', 111.21052815305156)]
# (0, 0, 0)
# LRP190a
# Fixing LRP190a (Pos 440): Snapped LAT to 22.9768
# Started iteration 2
# [('LRP115b', 'LRP116', 3.629245041704819), ('LRP116', 'LRP117', 4.704931590538794), ('LRP131', 'LRP131a', 2.105521971069285), ('LRP131a', 'LRP132', 3.0854902642131847), ('LRP176', 'LRP177', 3.0153745958011795), ('LRP177', 'LRP178', 3.990318324136116)]
# De outlier is LRP116
# De outlier is LRP131a
# De outlier is LRP132 maar ook LRP176 is een outlier
# De outlier is LRP177
# LRP116
# Fixing LRP116 (Pos 285): Snapped LAT to 23.4373
# LRP131a
# Fixing LRP131a (Pos 322): Snapped LAT to 23.3004
# LRP132
# Fixing LRP132 (Pos 323): Snapped LON to 89.1529
# LRP176
# Fixing LRP176 (Pos 412): Snapped LAT to 23.0488
# LRP177
# Fixing LRP177 (Pos 413): Snapped LAT to 23.0488
# Started iteration 3
# [('LRP119a', 'LRP119b', 1.6759478831283476), ('LRP119b', 'LRP119c', 1.692748602271995), ('LRP176', 'LRP177', 1.4722928275321314), ('LRP177', 'LRP178', 2.2117717393455565)]
# De outlier is LRP119b
# De outlier is LRP177
# LRP119b
# Fixing LRP119b (Pos 291): Snapped LON to 89.1345
# LRP177
# Fixing LRP177 (Pos 413): Snapped LON to 89.3872
# Started iteration 4
# []
# Processing N701...
# Started iteration 1
# []
# Processing N702...
# Started iteration 1
# [('LRP020b', 'LRP021', 8.36371646275009), ('LRP021', 'LRP022', 9.243741269510526)]
# De outlier is LRP021
# [('LRP020b', 'LRP021', 8.36371646275009), ('LRP021', 'LRP022', 9.243741269510526)]
# (0, 0, 0)
# LRP021
# Fixing LRP021 (Pos 40): Snapped LON to 89.3012
# Started iteration 2
# [('LRP012a', 'LRP013', 1.874839059463563), ('LRP030', 'LRP030a', 1.9368165782132798), ('LRP033', 'LRP033a', 2.388746644987438)]
# De outlier is LRP013 maar ook LRP030 is een outlier
# LRP013
# Fixing LRP013 (Pos 28): Snapped LAT to 23.2687
# LRP030
# Fixing LRP030 (Pos 58): Snapped LAT to 23.3742
# Started iteration 3
# [('LRP033', 'LRP033a', 2.388746644987438)]
# Processing N703...
# Started iteration 1
# [('LRP002a', 'LRP002b', 0.9026073052958488)]
# Processing N704...
# Started iteration 1
# [('LRP002a', 'LRP003', 2.1540508011933452), ('LRP070a', 'LRP071a', 1.8140225771400502), ('LRP075c', 'LRP076', 1.9296667603570068), ('LRP076', 'LRP076a', 1.7849767571651034)]
# De outlier is LRP076
# LRP076
# Fixing LRP076 (Pos 162): Snapped LAT to 24.0797
# Started iteration 2
# [('LRP002a', 'LRP003', 2.1540508011933452), ('LRP070a', 'LRP071a', 1.8140225771400502)]
# Processing N705...
# Started iteration 1
# [('LRP003', 'LRP004', 2.3491984453995935)]
# Processing N706...
# Started iteration 1
# []
# Processing N707...
# Started iteration 1
# [('LRP006', 'LRP007', 111.95981779609906)]
# Processing N708...
# Started iteration 1
# []
# Processing N709...
# Started iteration 1
# [('LRP021a', 'LRP021b', 1.481146038807606), ('LRP021b', 'LRP021c', 1.7285834928317978), ('LRP022a', 'LRP022b', 1.3539170108756406)]
# De outlier is LRP021b
# LRP021b
# Fixing LRP021b (Pos 67): Snapped LON to 89.5665
# Started iteration 2
# [('LRP022a', 'LRP022b', 1.3539170108756406)]
# Processing N710...
# Started iteration 1
# []
# Processing N711...
# Started iteration 1
# []
# Processing N712...
# Started iteration 1
# [('LRP002b', 'LRP002c', 1.9069181192749096)]
# Processing N715...
# Started iteration 1
# [('LRP009', 'LRPE', 1.895365958084627)]
# LRPE
# Fixing LRPE (Pos 27): Snapped LON to 88.9723
# Started iteration 2
# []
# Processing N8...
# Started iteration 1
# [('LRPS', 'LRP001', 110.24993030974692), ('LRP001', 'LRP001a', 111.21052523017767), ('LRP010b', 'LRP010c', 52.262679134600916), ('LRP010c', 'LRP010d', 52.80318706119352)]
# ['LRP001']
# De outlier is LRP001
# De outlier is LRP010c
# LRP001
# Fixing LRP001 (Pos 1): Snapped LAT to 23.6978
# LRP001
# Fixing LRP001 (Pos 1): Snapped LON to 90.4349
# LRP010c
# Fixing LRP010c (Pos 34): Snapped LON to 90.3538
# Started iteration 2
# [('LRP034a', 'LRP044a', 10.092354149659577), ('LRP047', 'LRP048', 2.6665076388350766), ('LRP155', 'LRP155a', 2.0848650826161816), ('LRP159', 'LRP159a', 2.302145771497473)]
# [('LRP034a', 'LRP044a', 10.092354149659577), ('LRP047', 'LRP048', 2.6665076388350766), ('LRP155', 'LRP155a', 2.0848650826161816), ('LRP159', 'LRP159a', 2.302145771497473)]
# ('LRPS', 'LRP001', 110.24993030974692)
# Processing N801...
# Started iteration 1
# [('LRP002', 'LRP002a', 0.99381221763867)]
# Processing N802...
# Started iteration 1
# []
# Processing N803...
# Started iteration 1
# []
# Processing N804...
# Started iteration 1
# [('LRP014', 'LRP015', 1.6510275970257788), ('LRP021b', 'LRP022', 1.6906621476938535)]
# De outlier is LRP015 maar ook LRP021b is een outlier
# [('LRP014', 'LRP015', 1.6510275970257788), ('LRP021b', 'LRP022', 1.6906621476938535)]
# (0, 0, 0)
# LRP015
# Fixing LRP015 (Pos 37): Snapped LON to 89.9047
# LRP021b
# Fixing LRP021b (Pos 52): Snapped LON to 89.8583
# Started iteration 2
# [('LRP014', 'LRP015', 1.5011153585199422)]
# Processing N805...
# Started iteration 1
# [('LRP013d', 'LRP014', 18.560352677482495), ('LRP014', 'LRP014a', 18.04028704881884), ('LRP088', 'LRP088a', 5.091517991118669), ('LRP088a', 'LRP088b', 5.125371984124799)]
# De outlier is LRP014
# De outlier is LRP088a
# LRP014
# Fixing LRP014 (Pos 53): Snapped LAT to 23.3417
# LRP088a
# Fixing LRP088a (Pos 255): Snapped LON to 89.7639
# Started iteration 2
# [('LRP036', 'LRP036a', 1.4101929764384586), ('LRP036a', 'LRP037', 1.2417632229780504), ('LRP098b', 'LRP099', 1.8523125222394232), ('LRP101', 'LRP101a', 1.251922192522542)]
# De outlier is LRP036a
# [('LRP036', 'LRP036a', 1.4101929764384586), ('LRP036a', 'LRP037', 1.2417632229780504), ('LRP098b', 'LRP099', 1.8523125222394232), ('LRP101', 'LRP101a', 1.251922192522542)]
# ('LRP013d', 'LRP014', 18.560352677482495)
# LRP036a
# Fixing LRP036a (Pos 123): Snapped LAT to 23.2192
# Started iteration 3
# [('LRP098b', 'LRP099', 1.8523125222394232), ('LRP101', 'LRP101a', 1.251922192522542)]
# Processing N806...
# Started iteration 1
# [('LRP005', 'LRP005a', 5.705465034380372), ('LRP005a', 'LRP006', 4.7328784241437925), ('LRP007d', 'LRP008', 3.458341975628861)]
# De outlier is LRP005a
# LRP005a
# Fixing LRP005a (Pos 14): Snapped LON to 89.6640
# Started iteration 2
# [('LRP007d', 'LRP008', 3.458341975628861), ('LRP009', 'LRP010', 2.409809352234142)]
# Processing N808...
# Started iteration 1
# []
# Processing N809...
# Started iteration 1
# [('LRP016a', 'LRP025a', 7.932998206814306), ('LRP041b', 'LRP057a', 16.700869244700353)]
# [('LRP016a', 'LRP025a', 7.932998206814306), ('LRP041b', 'LRP057a', 16.700869244700353)]
# (0, 0, 0)
# Processing R110...
# Started iteration 1
# [('LRP008', 'LRP008a', 2.3698632056908235)]
# Processing R111...
# Started iteration 1
# []
# Processing R112...
# Started iteration 1
# []
# Processing R113...
# Started iteration 1
# []
# Processing R114...
# Started iteration 1
# []
# Processing R120...
# Started iteration 1
# []
# Processing R140...
# Started iteration 1
# [('LRP014b', 'LRP015', 102.78664950430765), ('LRP015', 'LRP016', 101.36818401842058), ('LRP030', 'LRP030a', 102.38450845566122), ('LRP030a', 'LRP030c', 101.68675035464236), ('LRP032a', 'LRP032b', 101.48988089286627), ('LRP032b', 'LRP032c', 100.71022800741241), ('LRP034', 'LRP034a', 101.97902535661775), ('LRP034a', 'LRP035', 102.7994158314334), ('LRP053a', 'LRP054', 102.0139974705407), ('LRP054', 'LRP054a', 101.42638286106231), ('LRP094', 'LRP095', 204.4199111740549), ('LRP095', 'LRP095a', 204.76702292394864), ('LRP130', 'LRP130a', 101.99047730105788), ('LRP130a', 'LRP130b', 102.4146050127466)]
# De outlier is LRP015
# De outlier is LRP016 maar ook LRP030 is een outlier
# De outlier is LRP030a
# De outlier is LRP030c maar ook LRP032a is een outlier
# De outlier is LRP032b
# De outlier is LRP032c maar ook LRP034 is een outlier
# De outlier is LRP034a
# De outlier is LRP035 maar ook LRP053a is een outlier
# De outlier is LRP054
# De outlier is LRP095
# De outlier is LRP130a
# LRP015
# Fixing LRP015 (Pos 35): Snapped LON to 91.1202
# LRP016
# Fixing LRP016 (Pos 36): Snapped LON to 91.1202
# LRP030
# Fixing LRP030 (Pos 60): Snapped LON to 91.0115
# LRP030a
# Fixing LRP030a (Pos 61): Snapped LON to 91.0106
# LRP030c
# Fixing LRP030c (Pos 62): Snapped LON to 91.0083
# LRP032a
# Fixing LRP032a (Pos 68): Snapped LON to 90.9951
# LRP032b
# Fixing LRP032b (Pos 69): Snapped LON to 90.9867
# LRP032c
# Fixing LRP032c (Pos 70): Snapped LON to 90.9886
# LRP034
# Fixing LRP034 (Pos 73): Snapped LAT to 23.2536
# LRP034a
# Fixing LRP034a (Pos 74): Snapped LON to 90.9703
# LRP035
# Fixing LRP035 (Pos 75): Snapped LON to 90.9682
# LRP053a
# Fixing LRP053a (Pos 124): Snapped LON to 90.7923
# LRP054
# Fixing LRP054 (Pos 125): Snapped LON to 90.7923
# LRP095
# Fixing LRP095 (Pos 218): Snapped LON to 90.7651
# LRP130a
# Fixing LRP130a (Pos 295): Snapped LON to 91.0296
# Started iteration 2
# [('LRP078b', 'LRP079', 18.33807525446146), ('LRP079', 'LRP079a', 18.634509132214756)]
# De outlier is LRP079
# LRP079
# Fixing LRP079 (Pos 183): Snapped LAT to 23.1437
# Started iteration 3
# [('LRP052b', 'LRP052c', 1.9781088398059017), ('LRP054a', 'LRP055', 1.7510256085591176), ('LRP055a', 'LRP056', 1.779289952252161), ('LRP073', 'LRP074', 1.8047088497658061), ('LRP129', 'LRP130', 2.6815141971298275), ('LRP132', 'LRP132a', 1.9854336208873702)]
# De outlier is LRP055 maar ook LRP055a is een outlier
# De outlier is LRP056 maar ook LRP073 is een outlier
# LRP055
# Fixing LRP055 (Pos 127): Snapped LON to 90.7776
# LRP055a
# Fixing LRP055a (Pos 128): Snapped LON to 90.7750
# LRP056
# Fixing LRP056 (Pos 129): Snapped LON to 90.7682
# LRP073
# Fixing LRP073 (Pos 170): Snapped LAT to 23.1804
# Started iteration 4
# [('LRP052b', 'LRP052c', 1.9781088398059017), ('LRP129', 'LRP130', 2.6815141971298275), ('LRP132', 'LRP132a', 1.9854336208873702)]
# Processing R141...
# Started iteration 1
# [('LRP007', 'LRP008', 1.5532246042216529), ('LRP018', 'LRP018a', 2.0408633572197643)]
# [('LRP007', 'LRP008', 1.5532246042216529), ('LRP018', 'LRP018a', 2.0408633572197643)]
# (0, 0, 0)
# Processing R142...
# Started iteration 1
# []
# Processing R143...
# Started iteration 1
# [('LRP020', 'LRP020a', 4.276233568034632), ('LRP020a', 'LRP020b', 3.6724887892809948)]
# De outlier is LRP020a
# [('LRP020', 'LRP020a', 4.276233568034632), ('LRP020a', 'LRP020b', 3.6724887892809948)]
# (0, 0, 0)
# LRP020a
# Fixing LRP020a (Pos 46): Snapped LAT to 22.9379
# Started iteration 2
# []
# Processing R144...
# Started iteration 1
# []
# Processing R145...
# Started iteration 1
# []
# Processing R147...
# Started iteration 1
# []
# Processing R151...
# Started iteration 1
# [('LRP024a', 'LRP024b', 111.21361649014462), ('LRP024b', 'LRP025', 110.53424753556801)]
# De outlier is LRP024b
# [('LRP024a', 'LRP024b', 111.21361649014462), ('LRP024b', 'LRP025', 110.53424753556801)]
# (0, 0, 0)
# LRP024b
# Fixing LRP024b (Pos 82): Snapped LAT to 22.8677
# Started iteration 2
# [('LRP031d', 'LRP032', 22.214264662250805), ('LRP032', 'LRP032a', 22.182817801460814)]
# De outlier is LRP032
# [('LRP031d', 'LRP032', 22.214264662250805), ('LRP032', 'LRP032a', 22.182817801460814)]
# ('LRP024a', 'LRP024b', 111.21361649014462)
# LRP032
# Fixing LRP032 (Pos 102): Snapped LON to 91.7182
# Started iteration 3
# []
# Processing R152...
# Started iteration 1
# [('LRP027', 'LRP028', 1.583454651440565)]
# Processing R160...
# Started iteration 1
# [('LRP090d', 'LRP091', 111.86854009476183), ('LRP091', 'LRP091a', 111.1271341897548)]
# De outlier is LRP091
# [('LRP090d', 'LRP091', 111.86854009476183), ('LRP091', 'LRP091a', 111.1271341897548)]
# (0, 0, 0)
# LRP091
# Fixing LRP091 (Pos 227): Snapped LAT to 23.1104
# Started iteration 2
# [('LRP044b', 'LRP044c', 1.674232395238622), ('LRP044c', 'LRP045', 2.0030270485291517), ('LRP046', 'LRP046a', 1.7397448262859003), ('LRP092d', 'LRP092e', 1.6966322010324213), ('LRP092e', 'LRP093', 1.6906518489718751), ('LRP093', 'LRPE', 1.75632112544988)]
# De outlier is LRP044c
# De outlier is LRP046a maar ook LRP092d is een outlier
# De outlier is LRP092e
# De outlier is LRP093
# LRP044c
# Fixing LRP044c (Pos 124): Snapped LAT to 22.8505
# LRP046a
# Fixing LRP046a (Pos 127): Snapped LON to 91.8439
# LRP092d
# Fixing LRP092d (Pos 234): Snapped LAT to 23.1150
# LRP092e
# Fixing LRP092e (Pos 235): Snapped LON to 91.9865
# LRP093
# Fixing LRP093 (Pos 236): Snapped LAT to 23.1195
# Started iteration 3
# [('LRP045', 'LRP046', 1.3945693340347578), ('LRP091b', 'LRP092', 1.241466488023984), ('LRP093', 'LRPE', 1.3883601333351974)]
# Processing R161...
# Started iteration 1
# [('LRP022b', 'LRP022c', 1.8970483230596844), ('LRP063a', 'LRP063b', 1.5537724562819866), ('LRP063b', 'LRP064', 1.58543563164435), ('LRP064a', 'LRPE', 2.153707580621446)]
# De outlier is LRP063b
# LRP063b
# Fixing LRP063b (Pos 185): Snapped LON to 92.2175
# Started iteration 2
# [('LRP022a', 'LRP022b', 1.2947542075525704), ('LRP022b', 'LRP022c', 1.8970483230596844), ('LRP064a', 'LRPE', 2.153707580621446)]
# De outlier is LRP022b
# LRP022b
# Fixing LRP022b (Pos 42): Snapped LON to 92.1328
# Started iteration 3
# [('LRP031', 'LRP032', 1.2468762755252667), ('LRP064a', 'LRPE', 2.153707580621446)]
# Processing R162...
# Started iteration 1
# [('LRP056a', 'LRP057', 2.4363072546294076)]
# Processing R163...
# Started iteration 1
# [('LRP025c', 'LRP025d', 5.556736135609236), ('LRP025d', 'LRP025e', 5.559859597874143)]
# De outlier is LRP025d
# [('LRP025c', 'LRP025d', 5.556736135609236), ('LRP025d', 'LRP025e', 5.559859597874143)]
# (0, 0, 0)
# LRP025d
# Fixing LRP025d (Pos 65): Snapped LAT to 22.4670
# Started iteration 2
# [('LRP017', 'LRP018', 1.7342539588857988)]
# Processing R164...
# Started iteration 1
# []
# Processing R170...
# Started iteration 1
# [('LRP041b', 'LRP042', 1.0941994169261646), ('LRP047', 'LRP047a', 1.3299473174830008), ('LRP047a', 'LRP047b', 1.8872717955179736)]
# De outlier is LRP047a
# LRP047a
# Fixing LRP047a (Pos 163): Snapped LAT to 21.9810
# Started iteration 2
# [('LRP041b', 'LRP042', 1.0941994169261646), ('LRP053', 'LRP054', 1.0066073627604026), ('LRP055', 'LRP056', 1.0519338170522066), ('LRP065a', 'LRP066', 1.0162168673959981)]
# De outlier is LRP054 maar ook LRP055 is een outlier
# De outlier is LRP056 maar ook LRP065a is een outlier
# LRP054
# Fixing LRP054 (Pos 181): Snapped LAT to 21.9256
# LRP055
# Fixing LRP055 (Pos 185): Snapped LAT to 21.9059
# LRP056
# Fixing LRP056 (Pos 186): Snapped LAT to 21.9059
# LRP065a
# Fixing LRP065a (Pos 213): Snapped LAT to 21.8263
# Started iteration 3
# [('LRP041a', 'LRP041b', 1.004213270016223), ('LRP041b', 'LRP042', 1.0941994169261646), ('LRP060', 'LRP061', 0.9969729603966154)]
# De outlier is LRP041b
# LRP041b
# Fixing LRP041b (Pos 143): Snapped LON to 91.9443
# Started iteration 4
# [('LRP060', 'LRP061', 0.9969729603966154)]
# Processing R171...
# Started iteration 1
# [('LRP001a', 'LRP008a', 7.302294079432231)]
# Processing R172...
# Started iteration 1
# []
# Processing R180...
# Started iteration 1
# []
# Processing R201...
# Started iteration 1
# []
# Processing R202...
# Started iteration 1
# [('LRP008', 'LRP008a', 18.63890644506137), ('LRP008a', 'LRP009', 18.437256484263987)]
# De outlier is LRP008a
# [('LRP008', 'LRP008a', 18.63890644506137), ('LRP008a', 'LRP009', 18.437256484263987)]
# (0, 0, 0)
# LRP008a
# Fixing LRP008a (Pos 16): Snapped LAT to 23.7756
# Started iteration 2
# []
# Processing R203...
# Started iteration 1
# [('LRP075', 'LRP075a', 101.09050097804227)]
# Processing R210...
# Started iteration 1
# []
# Processing R211...
# Started iteration 1
# [('LRP032', 'LRP033', 3.21360978597548), ('LRP033', 'LRP033a', 3.771393069626228)]
# De outlier is LRP033
# [('LRP032', 'LRP033', 3.21360978597548), ('LRP033', 'LRP033a', 3.771393069626228)]
# (0, 0, 0)
# LRP033
# Fixing LRP033 (Pos 80): Snapped LAT to 24.2379
# Started iteration 2
# [('LRP033', 'LRP033', 3.4887067240490666), ('LRP033', 'LRP033a', 3.771393069626228)]
# De outlier is LRP033
# [('LRP033', 'LRP033', 3.4887067240490666), ('LRP033', 'LRP033a', 3.771393069626228)]
# ('LRP032', 'LRP033', 3.21360978597548)
# LRP033
# Fixing LRP033 (Pos 80): Snapped LON to 90.6999
# Started iteration 3
# [('LRP033', 'LRP033', 3.490809435269758), ('LRP033', 'LRP033a', 3.771393069626228)]
# De outlier is LRP033
# [('LRP033', 'LRP033', 3.490809435269758), ('LRP033', 'LRP033a', 3.771393069626228)]
# ('LRP033', 'LRP033', 3.4887067240490666)
# ('LRP033', 'LRP033a', 3.771393069626228)
# Finished at iteration 3 as outliers are the same.
# [('LRP033', 'LRP033', 3.490809435269758), ('LRP033', 'LRP033a', 3.771393069626228)] and [('LRP033', 'LRP033', 3.4887067240490666), ('LRP033', 'LRP033a', 3.771393069626228)]
# 2
# Processing R212...
# Started iteration 1
# [('LRP002', 'LRP002a', 1.9200429413618771), ('LRP002a', 'LRP003', 1.6728057899571156)]
# De outlier is LRP002a
# [('LRP002', 'LRP002a', 1.9200429413618771), ('LRP002a', 'LRP003', 1.6728057899571156)]
# (0, 0, 0)
# LRP002a
# Fixing LRP002a (Pos 4): Snapped LON to 90.7334
# Started iteration 2
# [('LRP008c', 'LRP008d', 1.3186786842701974)]
# Processing R220...
# Started iteration 1
# [('LRP024', 'LRP024a', 1.758133403150583), ('LRP024a', 'LRP025', 1.8772384985879664)]
# De outlier is LRP024a
# [('LRP024', 'LRP024a', 1.758133403150583), ('LRP024a', 'LRP025', 1.8772384985879664)]
# (0, 0, 0)
# LRP024a
# Fixing LRP024a (Pos 63): Snapped LAT to 24.2283
# Started iteration 2
# []
# Processing R221...
# Started iteration 1
# [('LRPSa', 'LRPSb', 15.160771599156396), ('LRPSb', 'LRP001', 15.578826826088568)]
# De outlier is LRPSb
# [('LRPSa', 'LRPSb', 15.160771599156396), ('LRPSb', 'LRP001', 15.578826826088568)]
# (0, 0, 0)
# LRPSb
# Fixing LRPSb (Pos 2): Snapped LAT to 24.3913
# Started iteration 2
# [('LRPSa', 'LRPSb', 3.0535570529048246), ('LRPSb', 'LRP001', 4.102446799112398)]
# De outlier is LRPSb
# [('LRPSa', 'LRPSb', 3.0535570529048246), ('LRPSb', 'LRP001', 4.102446799112398)]
# ('LRPSa', 'LRPSb', 15.160771599156396)
# ('LRPSb', 'LRP001', 15.578826826088568)
# Finished at iteration 2 as outliers are the same.
# [('LRPSa', 'LRPSb', 3.0535570529048246), ('LRPSb', 'LRP001', 4.102446799112398)] and [('LRPSa', 'LRPSb', 15.160771599156396), ('LRPSb', 'LRP001', 15.578826826088568)]
# 2
# Processing R222...
# Started iteration 1
# []
# Processing R240...
# Started iteration 1
# [('LRP021', 'LRP021a', 1.412584267158744), ('LRP039', 'LRP039a', 2.084971394550989)]
# [('LRP021', 'LRP021a', 1.412584267158744), ('LRP039', 'LRP039a', 2.084971394550989)]
# (0, 0, 0)
# Processing R241...
# Started iteration 1
# [('LRP013', 'LRP013a', 2.193648131768279)]
# Processing R247...
# Started iteration 1
# []
# Processing R248...
# Started iteration 1
# []
# Processing R249...
# Started iteration 1
# []
# Processing R250...
# Started iteration 1
# [('LRP042b', 'LRP043', 100.7985314767689), ('LRP043', 'LRP043a', 101.20662644971024)]
# De outlier is LRP043
# [('LRP042b', 'LRP043', 100.7985314767689), ('LRP043', 'LRP043a', 101.20662644971024)]
# (0, 0, 0)
# LRP043
# Fixing LRP043 (Pos 88): Snapped LON to 92.2372
# Started iteration 2
# [('LRP015b', 'LRP016', 1.734932495738087), ('LRP025', 'LRP025a', 1.5974749412776779)]
# [('LRP015b', 'LRP016', 1.734932495738087), ('LRP025', 'LRP025a', 1.5974749412776779)]
# ('LRP042b', 'LRP043', 100.7985314767689)
# Processing R251...
# Started iteration 1
# []
# Processing R280...
# Started iteration 1
# [('LRP004', 'LRP004a', 101.715099169081), ('LRP004a', 'LRP005', 100.76962377773658), ('LRP032a', 'LRP032b', 92.68418292928331), ('LRP032b', 'LRP033', 92.51766186764034)]
# De outlier is LRP004a
# De outlier is LRP032b
# LRP004a
# Fixing LRP004a (Pos 13): Snapped LON to 91.8286
# LRP032b
# Fixing LRP032b (Pos 81): Snapped LAT to 24.9327
# Started iteration 2
# [('LRP059', 'LRP060', 4.163456271539182), ('LRP060', 'LRP061', 3.447163847035128)]
# De outlier is LRP060
# LRP060
# Fixing LRP060 (Pos 131): Snapped LON to 91.3823
# Started iteration 3
# []
# Processing R281...
# Started iteration 1
# [('LRP017a', 'LRP018', 100.54334752980944), ('LRP018a', 'LRP019', 102.12540809882864), ('LRP081b', 'LRP082', 101.13216713885757), ('LRP082', 'LRP082a', 100.41475396950173)]
# De outlier is LRP018 maar ook LRP018a is een outlier
# De outlier is LRP019 maar ook LRP081b is een outlier
# De outlier is LRP082
# LRP018
# Fixing LRP018 (Pos 52): Snapped LON to 92.0076
# LRP018a
# Fixing LRP018a (Pos 53): Snapped LON to 92.0085
# LRP019
# Fixing LRP019 (Pos 54): Snapped LON to 92.0125
# LRP081b
# Fixing LRP081b (Pos 240): Snapped LON to 92.1710
# LRP082
# Fixing LRP082 (Pos 241): Snapped LON to 92.1710
# Started iteration 2
# [('LRP058b', 'LRP059', 36.8893611907693), ('LRP059', 'LRP059a', 37.06835744786554)]
# De outlier is LRP059
# LRP059
# Fixing LRP059 (Pos 166): Snapped LAT to 24.7716
# Started iteration 3
# [('LRP036b', 'LRP036c', 4.936518912393393), ('LRP036c', 'LRP037', 5.259483470129498), ('LRP076a', 'LRP076b', 2.011692917695646)]
# De outlier is LRP036c
# LRP036c
# Fixing LRP036c (Pos 106): Snapped LON to 92.1322
# Started iteration 4
# [('LRP032a', 'LRP032b', 1.678333155120911), ('LRP032b', 'LRP032c', 1.870052380470048), ('LRP034a', 'LRP034b', 1.7599909608072277), ('LRP034b', 'LRP034c', 1.8643311292930245), ('LRP047', 'LRP047a', 1.636683703529677), ('LRP047a', 'LRP047b', 1.7861670100131086), ('LRP072', 'LRP072a', 1.5030688289528702), ('LRP076a', 'LRP076b', 2.011692917695646), ('LRP076b', 'LRP076c', 1.9130259962910454)]
# De outlier is LRP032b
# De outlier is LRP034b
# De outlier is LRP047a
# De outlier is LRP076b
# LRP032b
# Fixing LRP032b (Pos 93): Snapped LAT to 24.5928
# LRP034b
# Fixing LRP034b (Pos 100): Snapped LAT to 24.6013
# LRP047a
# Fixing LRP047a (Pos 137): Snapped LON to 92.1837
# LRP076b
# Fixing LRP076b (Pos 224): Snapped LAT to 24.8804
# Started iteration 5
# [('LRP072', 'LRP072a', 1.5030688289528702)]
# Processing R282...
# Started iteration 1
# [('LRP010b', 'LRP010c', 2.2041529360011194), ('LRP015a', 'LRP015b', 1.7755396554833605), ('LRP015b', 'LRP015c', 1.9293866092311378)]
# De outlier is LRP015b
# LRP015b
# Fixing LRP015b (Pos 58): Snapped LAT to 24.5333
# Started iteration 2
# [('LRP010a', 'LRP010b', 1.2948744298964308), ('LRP010b', 'LRP010c', 2.2041529360011194)]
# De outlier is LRP010b
# LRP010b
# Fixing LRP010b (Pos 36): Snapped LAT to 24.5466
# Started iteration 3
# [('LRP005', 'LRP006', 1.002823372980025)]
# Processing R283...
# Started iteration 1
# []
# Processing R301...
# Started iteration 1
# [('LRPS', 'LRPSa', 111.4582339418567), ('LRPSa', 'LRP001', 110.93619492409832)]
# ['LRPSa']
# De outlier is LRPSa
# [('LRPS', 'LRPSa', 111.4582339418567), ('LRPSa', 'LRP001', 110.93619492409832)]
# (0, 0, 0)
# LRPSa
# Fixing LRPSa (Pos 1): Snapped LAT to 23.8951
# LRPSa
# Fixing LRPSa (Pos 1): Snapped LON to 90.4056
# Started iteration 2
# [('LRP022a', 'LRP023', 4.004468464027098), ('LRP023', 'LRP023a', 3.404304139909825)]
# De outlier is LRP023
# [('LRP022a', 'LRP023', 4.004468464027098), ('LRP023', 'LRP023a', 3.404304139909825)]
# ('LRPS', 'LRPSa', 111.4582339418567)
# LRP023
# Fixing LRP023 (Pos 50): Snapped LAT to 23.9376
# Started iteration 3
# []
# Processing R302...
# Started iteration 1
# []
# Processing R303...
# Started iteration 1
# []
# Processing R310...
# Started iteration 1
# [('LRP003a', 'LRP003b', 2.8343496858787107), ('LRP020a', 'LRP028a', 7.231475564216187)]
# [('LRP003a', 'LRP003b', 2.8343496858787107), ('LRP020a', 'LRP028a', 7.231475564216187)]
# (0, 0, 0)
# Processing R311...
# Started iteration 1
# [('LRP001', 'LRP002', 110.20682765109977)]
# Processing R312...
# Started iteration 1
# [('LRP005c', 'LRP006', 1.8207078849598528), ('LRP006', 'LRP006a', 1.939423294477361)]
# De outlier is LRP006
# [('LRP005c', 'LRP006', 1.8207078849598528), ('LRP006', 'LRP006a', 1.939423294477361)]
# (0, 0, 0)
# LRP006
# Fixing LRP006 (Pos 14): Snapped LAT to 24.1001
# Started iteration 2
# []
# Processing R313...
# Started iteration 1
# [('LRP035d', 'LRP036', 111.20126325610532), ('LRP036', 'LRP036a', 111.06921946193772)]
# De outlier is LRP036
# [('LRP035d', 'LRP036', 111.20126325610532), ('LRP036', 'LRP036a', 111.06921946193772)]
# (0, 0, 0)
# LRP036
# Fixing LRP036 (Pos 78): Snapped LAT to 24.1101
# Started iteration 2
# ...
# ('LRP006', 'LRP007', 1.0158537261919411)
# LRP007a
# Fixing LRP007a (Pos 16): Snapped LON to 90.2612
# LRP012b
# Fixing LRP012b (Pos 29): Snapped LON to 90.2115
# LRP013
# Fixing LRP013 (Pos 30): Snapped LON to 90.2064
# LRP014
# Fixing LRP014 (Pos 31): Snapped LON to 90.2035
# Started iteration 5
# [('LRPS', 'LRPSa', 0.9142457108360149)]
# ['LRPS']
# LRPS
# Fixing LRPS (Pos 0): Snapped LON to 90.3122
# Started iteration 6
# []
# Processing Z8034...
# Started iteration 1
# [('LRP007b', 'LRP008a', 1.3727525403859107), ('LRP023', 'LRP023a', 1.3847335833988594), ('LRP023a', 'LRP023b', 2.1176125222240523)]
# De outlier is LRP008a maar ook LRP023 is een outlier
# De outlier is LRP023a
# LRP008a
# Fixing LRP008a (Pos 17): Snapped LON to 90.3522
# LRP023
# Fixing LRP023 (Pos 65): Snapped LON to 90.4088
# LRP023a
# Fixing LRP023a (Pos 66): Snapped LON to 90.4088
# Started iteration 2
# []
# Processing Z8035...
# Started iteration 1
# [('LRP014a', 'LRP021a', 3.199272036022508)]
# Processing Z8037...
# Started iteration 1
# [('LRPS', 'LRP001', 0.9590838127076373), ('LRP001', 'LRP002', 0.9823089144750893), ('LRP005a', 'LRP006', 0.8685919030000274)]
# ['LRP001']
# De outlier is LRP001
# LRP001
# Fixing LRP001 (Pos 1): Snapped LAT to 22.7030
# LRP001
# Fixing LRP001 (Pos 1): Snapped LON to 90.3442
# Started iteration 2
# [('LRPS', 'LRP001', 0.9683798460170402), ('LRP001', 'LRP002', 0.9683662848095904), ('LRP005a', 'LRP006', 0.8685919030000274)]
# ['LRP001']
# De outlier is LRP001
# [('LRPS', 'LRP001', 0.9683798460170402), ('LRP001', 'LRP002', 0.9683662848095904), ('LRP005a', 'LRP006', 0.8685919030000274)]
# ('LRPS', 'LRP001', 0.9590838127076373)
# ('LRP001', 'LRP002', 0.9823089144750893)
# ('LRP005a', 'LRP006', 0.8685919030000274)
# Finished at iteration 2 as outliers are the same.
# [('LRPS', 'LRP001', 0.9683798460170402), ('LRP001', 'LRP002', 0.9683662848095904), ('LRP005a', 'LRP006', 0.8685919030000274)] and [('LRPS', 'LRP001', 0.9590838127076373), ('LRP001', 'LRP002', 0.9823089144750893), ('LRP005a', 'LRP006', 0.8685919030000274)]
# 3
# Processing Z8038...
# Started iteration 1
# []
# Processing Z8040...
# Started iteration 1
# [('LRP009a', 'LRP026a', 3.045713148686651)]
# Processing Z8043...
# Started iteration 1
# [('LRP001a', 'LRP004a', 3.884120824151263), ('LRP021c', 'LRP030a', 6.327389426495004)]
# [('LRP001a', 'LRP004a', 3.884120824151263), ('LRP021c', 'LRP030a', 6.327389426495004)]
# (0, 0, 0)
# Processing Z8044...
# Started iteration 1
# [('LRP011c', 'LRP013a', 1.7859089000438084)]
# Processing Z8047...
# Started iteration 1
# []
# Processing Z8048...
# Started iteration 1
# []
# Processing Z8049...
# Started iteration 1
# []
# Processing Z8051...
# Started iteration 1
# []
# Processing Z8052...
# Started iteration 1
# [('LRP005a', 'LRP006a', 1.3503239042572643), ('LRP021c', 'LRP022', 1.335855087805897)]
# De outlier is LRP006a maar ook LRP021c is een outlier
# [('LRP005a', 'LRP006a', 1.3503239042572643), ('LRP021c', 'LRP022', 1.335855087805897)]
# (0, 0, 0)
# LRP006a
# Fixing LRP006a (Pos 19): Snapped LON to 90.1588
# LRP021c
# Fixing LRP021c (Pos 57): Snapped LON to 90.2777
# Started iteration 2
# [('LRP019a', 'LRP021', 1.3088215013317213)]
# Processing Z8053...
# Started iteration 1
# []
# Processing Z8054...
# Started iteration 1
# [('LRPS', 'LRPSa', 6.913266974127969), ('LRPSa', 'LRPSb', 6.83335488564628)]
# ['LRPSa']
# De outlier is LRPSa
# [('LRPS', 'LRPSa', 6.913266974127969), ('LRPSa', 'LRPSb', 6.83335488564628)]
# (0, 0, 0)
# LRPSa
# Fixing LRPSa (Pos 1): Snapped LON to 90.2698
# LRPSa
# Fixing LRPSa (Pos 1): Snapped LAT to 22.6362
# Started iteration 2
# []
# Processing Z8055...
# Started iteration 1
# []
# Processing Z8056...
# Started iteration 1
# [('LRP005', 'LRP005a', 556.0402724957677), ('LRP005a', 'LRP006', 556.6447716808319)]
# De outlier is LRP005a
# [('LRP005', 'LRP005a', 556.0402724957677), ('LRP005a', 'LRP006', 556.6447716808319)]
# (0, 0, 0)
# LRP005a
# Fixing LRP005a (Pos 17): Snapped LAT to 22.6424
# Started iteration 2
# [('LRP009a', 'LRP009b', 11.321788543324262), ('LRP009b', 'LRP010', 10.937700251057665)]
# De outlier is LRP009b
# [('LRP009a', 'LRP009b', 11.321788543324262), ('LRP009b', 'LRP010', 10.937700251057665)]
# ('LRP005', 'LRP005a', 556.0402724957677)
# LRP009b
# Fixing LRP009b (Pos 26): Snapped LAT to 22.6232
# Started iteration 3
# [('LRP005a', 'LRP006', 1.6245837856903778), ('LRP013', 'LRP013a', 1.9679240340223094), ('LRP013c', 'LRP014', 1.6871030463105763), ('LRP014', 'LRP014a', 1.8078281224024841)]
# De outlier is LRP014
# LRP014
# Fixing LRP014 (Pos 39): Snapped LON to 90.2642
# Started iteration 4
# [('LRP005a', 'LRP006', 1.6245837856903778), ('LRP013', 'LRP013a', 1.9679240340223094)]
# Processing Z8057...
# Started iteration 1
# []
# Processing Z8058...
# Started iteration 1
# [('LRP005a', 'LRP005b', 1.6436728127748292), ('LRP005b', 'LRP005c', 1.7110373245084955)]
# De outlier is LRP005b
# [('LRP005a', 'LRP005b', 1.6436728127748292), ('LRP005b', 'LRP005c', 1.7110373245084955)]
# (0, 0, 0)
# LRP005b
# Fixing LRP005b (Pos 18): Snapped LON to 90.2497
# Started iteration 2
# [('LRP003', 'LRP003a', 0.7982415471067238), ('LRP004', 'LRP004a', 0.7972659190224257)]
# De outlier is LRP003a maar ook LRP004 is een outlier
# [('LRP003', 'LRP003a', 0.7982415471067238), ('LRP004', 'LRP004a', 0.7972659190224257)]
# ('LRP005a', 'LRP005b', 1.6436728127748292)
# LRP003a
# Fixing LRP003a (Pos 13): Snapped LON to 90.2591
# LRP004
# Fixing LRP004 (Pos 14): Snapped LON to 90.2591
# Started iteration 3
# [('LRP004', 'LRP004a', 0.872080358914137)]
# Processing Z8059...
# Started iteration 1
# []
# Processing Z8062...
# Started iteration 1
# [('LRP002b', 'LRP002c', 2.2543012299526093)]
# Processing Z8065...
# Started iteration 1
# [('LRP004a', 'LRP004b', 101.68961787412591), ('LRP004b', 'LRP004c', 102.17134464796695)]
# De outlier is LRP004b
# [('LRP004a', 'LRP004b', 101.68961787412591), ('LRP004b', 'LRP004c', 102.17134464796695)]
# (0, 0, 0)
# LRP004b
# Fixing LRP004b (Pos 8): Snapped LON to 90.3268
# Started iteration 2
# [('LRP009', 'LRP009a', 1.649079869670564)]
# Processing Z8067...
# Started iteration 1
# []
# Processing Z8121...
# Started iteration 1
# [('LRP016a', 'LRP020a', 3.670343848774306)]
# Processing Z8201...
# Started iteration 1
# []
# Processing Z8203...
# Started iteration 1
# [('LRPS', 'LRP006a', 6.130934392306162)]
# ['LRPS']
# LRPS
# Fixing LRPS (Pos 0): Snapped LAT to 23.6147
# Started iteration 2
# [('LRPS', 'LRP006a', 1.216331752024142)]
# ['LRPS']
# [('LRPS', 'LRP006a', 1.216331752024142)]
# ('LRPS', 'LRP006a', 6.130934392306162)
# Finished at iteration 2 as outliers are the same.
# [('LRPS', 'LRP006a', 1.216331752024142)] and [('LRPS', 'LRP006a', 6.130934392306162)]
# 1
# Processing Z8204...
# Started iteration 1
# [('LRP005c', 'LRP005d', 1.706880480899629)]
# Processing Z8205...
# Started iteration 1
# [('LRP001', 'LRP002', 204.1999239889181), ('LRP002', 'LRP003', 203.6010370930919)]
# De outlier is LRP002
# [('LRP001', 'LRP002', 204.1999239889181), ('LRP002', 'LRP003', 203.6010370930919)]
# (0, 0, 0)
# LRP002
# Fixing LRP002 (Pos 4): Snapped LON to 90.1740
# Started iteration 2
# []
# Processing Z8206...
# Started iteration 1
# []
# Processing Z8207...
# Started iteration 1
# []
# Processing Z8208...
# Started iteration 1
# []
# Processing Z8209...
# Started iteration 1
# []
# Processing Z8401...
# Started iteration 1
# []
# Processing Z8402...
# Started iteration 1
# []
# Processing Z8404...
# Started iteration 1
# [('LRP010b', 'LRP010c', 1.9210706881727482), ('LRP010c', 'LRP011', 1.9596609862894907)]
# De outlier is LRP010c
# [('LRP010b', 'LRP010c', 1.9210706881727482), ('LRP010c', 'LRP011', 1.9596609862894907)]
# (0, 0, 0)
# LRP010c
# Fixing LRP010c (Pos 28): Snapped LAT to 23.4176
# Started iteration 2
# [('LRP008b', 'LRP009', 1.2584449362429129)]
# Processing Z8408...
# Started iteration 1
# []
# Processing Z8412...
# Started iteration 1
# []
# Processing Z8414...
# Started iteration 1
# []
# Processing Z8416...
# Started iteration 1
# []
# Processing Z8419...
# Started iteration 1
# [('LRP002', 'LRP002a', 1.5564108681417672)]
# Processing Z8420...
# Started iteration 1
# []
# Processing Z8429...
# Started iteration 1
# []
# Processing Z8430...
# Started iteration 1
# [('LRP006a', 'LRP006b', 3.5891273912293435), ('LRP006b', 'LRP007', 3.044015116960275)]
# De outlier is LRP006b
# [('LRP006a', 'LRP006b', 3.5891273912293435), ('LRP006b', 'LRP007', 3.044015116960275)]
# (0, 0, 0)
# LRP006b
# Fixing LRP006b (Pos 26): Snapped LAT to 22.9407
# Started iteration 2
# [('LRP003', 'LRP003a', 2.138609633889562), ('LRP014', 'LRP014a', 2.060272807464061)]
# De outlier is LRP003a maar ook LRP014 is een outlier
# [('LRP003', 'LRP003a', 2.138609633889562), ('LRP014', 'LRP014a', 2.060272807464061)]
# ('LRP006a', 'LRP006b', 3.5891273912293435)
# LRP003a
# Fixing LRP003a (Pos 16): Snapped LAT to 22.9096
# LRP014
# Fixing LRP014 (Pos 45): Snapped LON to 89.9608
# Started iteration 3
# [('LRP014', 'LRP014a', 2.0050868629246485)]
# Processing Z8504...
# Started iteration 1
# []
# Processing Z8507...
# Started iteration 1
# []
# Processing Z8601...
# Started iteration 1
# [('LRPSa', 'LRPSb', 204.46873257534344), ('LRPSb', 'LRP001', 203.8203234409264)]
# De outlier is LRPSb
# [('LRPSa', 'LRPSb', 204.46873257534344), ('LRPSb', 'LRP001', 203.8203234409264)]
# (0, 0, 0)
# LRPSb
# Fixing LRPSb (Pos 2): Snapped LON to 90.3903
# Started iteration 2
# []
# Processing Z8602...
# Started iteration 1
# [('LRP004', 'LRP004a', 222.47362622468097), ('LRP004a', 'LRP004b', 222.38089820208924)]
# De outlier is LRP004a
# [('LRP004', 'LRP004a', 222.47362622468097), ('LRP004a', 'LRP004b', 222.38089820208924)]
# (0, 0, 0)
# LRP004a
# Fixing LRP004a (Pos 14): Snapped LAT to 23.2502
# Started iteration 2
# []
# Processing Z8603...
# Started iteration 1
# [('LRP013e', 'LRP013f', 204.5720242272196), ('LRP013f', 'LRP013g', 204.7295309222715)]
# De outlier is LRP013f
# [('LRP013e', 'LRP013f', 204.5720242272196), ('LRP013f', 'LRP013g', 204.7295309222715)]
# (0, 0, 0)
# LRP013f
# Fixing LRP013f (Pos 43): Snapped LON to 90.1663
# Started iteration 2
# [('LRP013f', 'LRP013f', 204.65046751607622), ('LRP013f', 'LRP013g', 204.7295309222715)]
# De outlier is LRP013f
# [('LRP013f', 'LRP013f', 204.65046751607622), ('LRP013f', 'LRP013g', 204.7295309222715)]
# ('LRP013e', 'LRP013f', 204.5720242272196)
# LRP013f
# Fixing LRP013f (Pos 43): Snapped LAT to 23.0694
# Started iteration 3
# [('LRP013f', 'LRP013f', 204.65075706765464), ('LRP013f', 'LRP013g', 204.7295309222715)]
# De outlier is LRP013f
# [('LRP013f', 'LRP013f', 204.65075706765464), ('LRP013f', 'LRP013g', 204.7295309222715)]
# ('LRP013f', 'LRP013f', 204.65046751607622)
# ('LRP013f', 'LRP013g', 204.7295309222715)
# Finished at iteration 3 as outliers are the same.
# [('LRP013f', 'LRP013f', 204.65075706765464), ('LRP013f', 'LRP013g', 204.7295309222715)] and [('LRP013f', 'LRP013f', 204.65046751607622), ('LRP013f', 'LRP013g', 204.7295309222715)]
# 2
# Processing Z8604...
# Started iteration 1
# [('LRPS', 'LRP001', 102.85093500242614)]
# ['LRPS']
# LRPS
# Fixing LRPS (Pos 0): Snapped LON to 90.2193
# Started iteration 2
# []
# Processing Z8605...
# Started iteration 1
# []
# Processing Z8606...
# Started iteration 1
# []
# Processing Z8607...
# Started iteration 1
# [('LRP008c', 'LRP008d', 111.19511757341348), ('LRP008d', 'LRP008e', 111.1055261449401)]
# De outlier is LRP008d
# [('LRP008c', 'LRP008d', 111.19511757341348), ('LRP008d', 'LRP008e', 111.1055261449401)]
# (0, 0, 0)
# LRP008d
# Fixing LRP008d (Pos 30): Snapped LAT to 23.2846
# Started iteration 2
# [('LRP005a', 'LRP005b', 1.791316736775572)]
# Processing Z8611...
# Started iteration 1
# []
# Processing Z8699...
# Started iteration 1
# []
# Processing Z8701...
# Started iteration 1
# []
# Processing Z8702...
# Started iteration 1
# [('LRP012a', 'LRP013a', 1.3190036291459382)]
# Processing Z8703...
# Started iteration 1
# []
# Processing Z8704...
# Started iteration 1
# [('LRP007', 'LRP008', 0.9110246311501735)]
# Processing Z8705...
# Started iteration 1
# [('LRP003c', 'LRP004', 0.7398264749340084), ('LRP009c', 'LRP010', 0.7462106114337005)]
# De outlier is LRP004 maar ook LRP009c is een outlier
# [('LRP003c', 'LRP004', 0.7398264749340084), ('LRP009c', 'LRP010', 0.7462106114337005)]
# (0, 0, 0)
# LRP004
# Fixing LRP004 (Pos 16): Snapped LAT to 22.4630
# LRP009c
# Fixing LRP009c (Pos 46): Snapped LAT to 22.4222
# Started iteration 2
# []
# Processing Z8706...
# Started iteration 1
# [('LRP005a', 'LRP005b', 0.8615283212039536)]
# Processing Z8708...
# Started iteration 1
# [('LRP066a', 'LRP067', 6.948999476328237), ('LRP067', 'LRP067a', 6.545923105842647)]
# De outlier is LRP067
# [('LRP066a', 'LRP067', 6.948999476328237), ('LRP067', 'LRP067a', 6.545923105842647)]
# (0, 0, 0)
# LRP067
# Fixing LRP067 (Pos 224): Snapped LON to 89.9949
# Started iteration 2
# [('LRP011a', 'LRP012', 1.7113627163474987), ('LRP012', 'LRP012a', 2.041708465708247), ('LRP070b', 'LRP071', 1.6801149307948298), ('LRP071', 'LRP072', 2.17772747310911), ('LRP072', 'LRP072a', 1.6991155449315596), ('LRP072a', 'LRP073', 1.8479646961043887)]
# De outlier is LRP012
# De outlier is LRP071
# De outlier is LRP072
# De outlier is LRP072a
# LRP012
# Fixing LRP012 (Pos 45): Snapped LAT to 22.4826
# LRP071
# Fixing LRP071 (Pos 234): Snapped LON to 89.9892
# LRP072
# Fixing LRP072 (Pos 235): Snapped LAT to 22.0623
# LRP072a
# Fixing LRP072a (Pos 236): Snapped LON to 89.9834
# Started iteration 3
# [('LRP071', 'LRP072', 1.2661387139786477)]
# Processing Z8709...
# Started iteration 1
# [('LRP002a', 'LRP002b', 0.5862652835485763)]
# Processing Z8713...
# Started iteration 1
# [('LRP010', 'LRP011', 0.9921007350681607)]
# Processing Z8716...
# Started iteration 1
# [('LRPSb', 'LRP001', 0.9945249606508985)]
# Processing Z8717...
# Started iteration 1
# [('LRP001', 'LRP001a', 63.047546105364766), ('LRP001a', 'LRP001b', 62.56893263872062)]
# De outlier is LRP001a
# [('LRP001', 'LRP001a', 63.047546105364766), ('LRP001a', 'LRP001b', 62.56893263872062)]
# (0, 0, 0)
# LRP001a
# Fixing LRP001a (Pos 4): Snapped LAT to 22.5720
# Started iteration 2
# [('LRP011a', 'LRPE', 1.1817844216105517)]
# LRPE
# Fixing LRPE (Pos 42): Snapped LON to 90.0743
# Started iteration 3
# []
# Processing Z8740...
# Started iteration 1
# [('LRP004a', 'LRP004b', 0.43487114760151785), ('LRP005b', 'LRP005c', 0.5915714562108724), ('LRP007b', 'LRP007c', 0.512190352534209), ('LRP008c', 'LRP008d', 0.4367360273444948)]
# Processing Z8750...
# Started iteration 1
# []
# Processing Z8803...
# Started iteration 1
# []
# Processing Z8804...
# Started iteration 1
# [('LRP007', 'LRP008', 1.8320384685354414)]
# Processing Z8806...
# Started iteration 1
# [('LRP032a', 'LRP033', 2.611065683929509), ('LRP054', 'LRP055', 5.627394889993024), ('LRP055', 'LRP055a', 5.545318170503691)]
# De outlier is LRP055
# LRP055
# Fixing LRP055 (Pos 127): Snapped LAT to 22.2096
# Started iteration 2
# [('LRP003a', 'LRP003b', 1.9332944240253178), ('LRP032a', 'LRP033', 2.611065683929509), ('LRP034', 'LRP035', 1.606385357823159), ('LRP037', 'LRP038', 1.6594742640574698)]
# De outlier is LRP035 maar ook LRP037 is een outlier
# LRP035
# Fixing LRP035 (Pos 91): Snapped LAT to 22.3392
# LRP037
# Fixing LRP037 (Pos 94): Snapped LAT to 22.3145
# Started iteration 3
# [('LRP003a', 'LRP003b', 1.9332944240253178), ('LRP032a', 'LRP033', 2.611065683929509)]
# Processing Z8810...
# Started iteration 1
# [('LRP053', 'LRP054', 1.9874601293518273)]
# Processing Z8814...
# Started iteration 1
# [('LRP022c', 'LRP022d', 18.514014438092502), ('LRP022d', 'LRP022e', 18.725975536156728)]
# De outlier is LRP022d
# [('LRP022c', 'LRP022d', 18.514014438092502), ('LRP022d', 'LRP022e', 18.725975536156728)]
# (0, 0, 0)
# LRP022d
# Fixing LRP022d (Pos 58): Snapped LAT to 22.2859
# Started iteration 2
# []
# Processing Z8815...
# Started iteration 1
# []
# Processing Z8905...
# Started iteration 1
# [('LRP003c', 'LRP010a', 7.8504498130292575)]
# Processing Z8909...
# Started iteration 1
# []
# Processing Z8910...
# Started iteration 1
# [('LRP019a', 'LRP019b', 2.835471309023134)]
# Processing Z8913...
# Started iteration 1
# []
# Processing Z8915...
# Started iteration 1
# []
# Processing Z8916...
# Started iteration 1
# [('LRP002a', 'LRP003', 111.28287684345192), ('LRP003', 'LRP003a', 110.86567903493616)]
# De outlier is LRP003
# [('LRP002a', 'LRP003', 111.28287684345192), ('LRP003', 'LRP003a', 110.86567903493616)]
# (0, 0, 0)
# LRP003
# Fixing LRP003 (Pos 5): Snapped LAT to 22.6163
# Started iteration 2
# []
# Processing Z8943...
# Started iteration 1
# [('LRP001', 'LRP001a', 111.08080871416037), ('LRP001a', 'LRP002', 111.01876008279525)]
# De outlier is LRP001a
# [('LRP001', 'LRP001a', 111.08080871416037), ('LRP001a', 'LRP002', 111.01876008279525)]
# (0, 0, 0)
# LRP001a
# Fixing LRP001a (Pos 3): Snapped LAT to 22.4252
# Started iteration 2
# []

# %%
road_kut = 'Z1618'
f, axes = plt.subplots(1,2, figsize=(12, 6), sharey=True)
df_all_fixed["road"] == road_kut
axes.flatten()
axes[0].plot(df_all[df_all["road"] == road_kut]['LON'], df_all[df_all["road"] == road_kut]['LAT'], label='Original N1')
axes[0].set_title(f'Original {df_all.iloc[0].road}')
axes[1].plot(df_all_fixed[df_all_fixed["road"] == road_kut]['LON'], df_all_fixed[df_all_fixed["road"] == road_kut]['LAT'],  label='Snapped N1')
axes[1].set_title(f'Snapped {df_all_fixed[df_all_fixed["road"] == road_kut].iloc[0].road}')
# Out:
# Text(0.5, 1.0, 'Snapped Z1618')

# %%
f, axes = plt.subplots(1,2, figsize=(12, 6), sharey=True)

for road_name, road_group in df_all.groupby('road'):
    # We use a single color (e.g., 'blue') so they look uniform, 
    # or remove the color argument to let matplotlib assign random colors to each road.
    axes[0].plot(road_group['LON'], road_group['LAT'], color='blue', alpha=0.7) 

axes[0].set_title('Original Roads')


# 2. Plot Snapped / Fixed Roads
for road_name, road_group in df_all_fixed.groupby('road'):
    if road_name == 'Z1030':
        axes[1].plot(road_group['LON'], road_group['LAT'], color='green', alpha=0.7)
    else:
        axes[1].plot(road_group['LON'], road_group['LAT'], color='orange', alpha=0.7)


axes[1].set_title('Snapped Roads')

plt.show()

# %%
road_kut = 'Z1030'
df_all_fixed[df_all_fixed["road"] == road_kut]
df_all_fixed[df_all_fixed["road"] == road_kut].plot(x="LON", y="LAT", title=f'{df_all_fixed[df_all_fixed["road"] == road_kut].iloc[0].road}')
# Out:
# <Axes: title={'center': 'Z1030'}, xlabel='LON'>

# %%
df_all[df_all["road"] == road_kut]
df_all[df_all["road"] == road_kut].plot(x="LON", y="LAT", title=f'{df_all[df_all["road"] == road_kut].iloc[0].road}')
# Out:
# <Axes: title={'center': 'Z1030'}, xlabel='LON'>

# %%
df_fixed_kut =fix_road(df_all[df_all["road"] == road_kut])
df_fixed_kut.plot(x="LON", y="LAT")

outliers, mdn, std = calc_outliers(df_fixed_kut)
calc_lrp_outliers(outliers, std)
# Out:
# Started iteration 1
# [('LRP062a', 'LRPE', 444.7865033897107)]
# LRPE
# Fixing LRPE (Pos 153): Snapped LAT to 24.8352
# Started iteration 2
# [('LRP002b', 'LRP002c', 16.673085520389392), ('LRP002c', 'LRP003', 16.75382117958041)]
# De outlier is LRP002c
# LRP002c
# Fixing LRP002c (Pos 7): Snapped LAT to 24.4864
# Started iteration 3
# [('LRP023', 'LRP024', 2.0584000007591516), ('LRP026', 'LRP026a', 3.2792533810924596), ('LRP026a', 'LRP026b', 3.514928627435352), ('LRP053a', 'LRP053b', 1.9553113756538858)]
# De outlier is LRP026a
# LRP026a
# Fixing LRP026a (Pos 54): Snapped LON to 88.4196
# Started iteration 4
# [('LRP023', 'LRP024', 2.0584000007591516), ('LRP053a', 'LRP053b', 1.9553113756538858)]
# [('LRP023', 'LRP024', 2.0584000007591516), ('LRP053a', 'LRP053b', 1.9553113756538858)]
# []

# %%
df_to_convert = df_all_fixed.copy()

# 1. Create a sequential ID for each point group within a road (1, 2, 3...)
df_to_convert['point_id'] = df_to_convert.groupby('road').cumcount() + 1

# 2. Pivot the DataFrame
df_wide = df_to_convert.pivot(index='road', columns='point_id', values=['LRP', 'LAT', 'LON'])

# 3. Create the correct column sequence (LRP_1, LAT_1, LON_1, LRP_2...)
max_points = df_to_convert['point_id'].max()
multi_cols = [(col, i) for i in range(1, max_points + 1) for col in ['LRP', 'LAT', 'LON']]
new_col_names = [f"{col}_{i}" for i in range(1, max_points + 1) for col in ['LRP', 'LAT', 'LON']]

# 4. Reorder and flatten the columns, then reset the index
df_wide = df_wide[multi_cols] 
df_wide.columns = new_col_names
df_wide = df_wide.reset_index()

# Clean up the temporary column we added to df_all
df_to_convert = df_to_convert.drop(columns=['point_id'])

print(df_wide)
# Out:
#       road LRP_1      LAT_1      LON_1   LRP_2      LAT_2      LON_2    LRP_3  \
# 0       N1  LRPS  23.706028  90.443333   LRPSa  23.702917  90.450417    LRPSb
# 1     N101  LRPS  23.454139  91.212861   LRPSa  23.461889     91.212   LRP001
# 2     N102  LRPS  23.478972  91.118194   LRPSa  23.481583  91.116777    LRPSb
# 3     N103  LRPS  23.957028  91.115528  LRP001  23.961917  91.113611  LRP001a
# 4     N104  LRPS  23.009667  91.399416   LRPSa  23.009278   91.39525   LRP001
# ..     ...   ...        ...        ...     ...        ...        ...      ...
# 872  Z8910  LRPS  22.674722  90.408889   LRPSa  22.675916  90.412556   LRP001
# 873  Z8913  LRPS  22.396083  90.688666   LRPSa  22.393027  90.688944    LRPSb
# 874  Z8915  LRPS  22.589389  90.619472  LRP001  22.589694   90.62336  LRP001a
# 875  Z8916  LRPS  22.625499  90.661722   LRPSa  22.623888  90.664167   LRP001
# 876  Z8943  LRPS  22.426444  90.849472   LRPSa  22.426416  90.846833   LRP001
#
#          LAT_3      LON_3  ...  LON_1345 LRP_1346   LAT_1346   LON_1346  \
# 0    23.702778  90.450472  ...  92.29825  LRP466c  20.864667  92.298194
# 1    23.462944  91.211806  ...       NaN      NaN        NaN        NaN
# 2    23.486666  91.113361  ...       NaN      NaN        NaN        NaN
# 3    23.967666  91.111889  ...       NaN      NaN        NaN        NaN
# 4    23.009306  91.389805  ...       NaN      NaN        NaN        NaN
# ..         ...        ...  ...       ...      ...        ...        ...
# 872  22.675583  90.417166  ...       NaN      NaN        NaN        NaN
# 873  22.392666  90.689083  ...       NaN      NaN        NaN        NaN
# 874  22.590027   90.63136  ...       NaN      NaN        NaN        NaN
# 875  22.620305  90.668999  ...       NaN      NaN        NaN        NaN
# 876  22.425444  90.839861  ...       NaN      NaN        NaN        NaN
#
#     LRP_1347   LAT_1347   LON_1347 LRP_1348   LAT_1348   LON_1348
# 0     LRP467  20.862972  92.298083     LRPE  20.862917  92.298083
# 1        NaN        NaN        NaN      NaN        NaN        NaN
# 2        NaN        NaN        NaN      NaN        NaN        NaN
# 3        NaN        NaN        NaN      NaN        NaN        NaN
# 4        NaN        NaN        NaN      NaN        NaN        NaN
# ..       ...        ...        ...      ...        ...        ...
# 872      NaN        NaN        NaN      NaN        NaN        NaN
# 873      NaN        NaN        NaN      NaN        NaN        NaN
# 874      NaN        NaN        NaN      NaN        NaN        NaN
# 875      NaN        NaN        NaN      NaN        NaN        NaN
# 876      NaN        NaN        NaN      NaN        NaN        NaN
#
# [877 rows x 4045 columns]

# %%
# df_wide.to_csv( "../data/processed/_roads.tsv", sep='\t', index=False)

# %%
# def snap_point(lrp, df_rd, index):
#     max_index = df_rd.index.max()
#     df_rd_copy = df_rd.copy()
#     print(max_index)

#     if index == 0:
#         n1_idx = index + 1
#         n2_idx = index + 2
#         mode = 'extrapolate_backward'

#     elif index == max_index:
#         n1_idx = index - 1
#         n2_idx = index - 2
#         mode = 'extrapolate_forward'

#     else:
#         n1_idx = index - 1
#         n2_idx = index + 1
#         mode = 'interpolate'

#     if df_rd.iloc[n1_idx]['LRP'] in lrp_outliers:
#         # If n1 is bad, shift it further away by 1
#         step = 1 if n1_idx > index else -1
#         n1_idx += step 
    
#     # Check Neighbor 2 (Only if still in bounds)
#     if 0 <= n2_idx <= max_index and df_rd.iloc[n2_idx]['LRP'] in lrp_outliers:
#         step = 1 if n2_idx > index else -1
#         n2_idx += step

#     # Final Boundary Safety Check (if skipping pushed us off the map)
#     if not (0 <= n1_idx <= max_index) or not (0 <= n2_idx <= max_index):
#         print(f"Cannot fix Index {index}: Neighbors unavailable or invalid.")
#         return

#     p1 = df_rd.iloc[n1_idx]
#     p2 = df_rd.iloc[n2_idx]
#     curr_pt = df_rd.iloc[index]

#     if mode == 'interpolate':
#         # Average of neighbors (The Sandwich Method)
#         exp_lat = (p1['LAT'] + p2['LAT']) / 2.0
#         exp_lon = (p1['LON'] + p2['LON']) / 2.0
        
#     elif mode == 'extrapolate_backward':
#         # Predict 0 using the slope of 2 -> 1
#         # Logic: Expected = P1 + (P1 - P2)
#         exp_lat = p1['LAT'] + (p1['LAT'] - p2['LAT'])
#         exp_lon = p1['LON'] + (p1['LON'] - p2['LON'])
        
#     elif mode == 'extrapolate_forward':
#         # Predict End using the slope of (End-2) -> (End-1)
#         # Logic: Expected = P1 + (P1 - P2)  (Since P1 is closer to target than P2)
#         exp_lat = p1['LAT'] + (p1['LAT'] - p2['LAT'])
#         exp_lon = p1['LON'] + (p1['LON'] - p2['LON'])

#     # 4. Calculate Deviations (How far off is the current point?)
#     # We use absolute difference

#     lat_diff = abs(curr_pt['LAT'] - exp_lat)
#     lon_diff = abs(curr_pt['LON'] - exp_lon)

#     if lat_diff > lon_diff:
#         print(f"Index {index}: Fixed LAT based on {mode}")
#         print(f"Original LAT: {curr_pt['LAT']}, Expected LAT: {exp_lat}, Deviation: {lat_diff}")
#         df_rd_copy.at[index, 'LAT'] = exp_lat
#         print(df_rd_copy.at[index, 'LAT'])
#     else:
#         print(f"Index {index}: Fixed LON based on {mode}")
#         df_rd_copy.at[index, 'LON'] = exp_lon
#     return df_rd_copy

# for outlier in lrp_outliers:
#     row_pos_array = np.where(df_rd1['LRP'] == outlier)[0]
#     if len(row_pos_array) > 0:
#         row_pos = row_pos_array[0]
        
#         # 2. Get the "Real" Index Label (1348, 1356) for your reference
#         # We look up the label that sits at that integer position
#         real_index = df_rd1.index[row_pos]
        
#         print(f"LRP {outlier}: Row Pos {row_pos} | Original Index {real_index}")
        
#         # IMPORTANT: Pass 'row_pos' (0), not 'real_index' (1348)
#         # Your snap_point function uses .iloc, which expects 0, 1, 2...
#         df_rd1_copy = snap_point(outlier, df_rd1, row_pos)

# # df_rd1_copy.plot(x="LON", y="LAT", title="N1 Snapped")

# %%
import pandas as pd
#Pinda's

# %%
df_bridges = pd.read_excel('../data/raw/BMMS_overview.xlsx')
#df_bridges.head()

# %%
df_roads = pd.read_csv('../data/raw/_roads.tsv', sep='\t')
display(df_roads.head(10))

all_data = []

for rd in df_roads.itertuples(index=False):
    rd_name = rd[0]

    for i in range(1, len(rd)-2, 3):
        lrp = rd[i]
        lat = rd[i+1]
        lon = rd[i+2]

        if pd.isna(lrp) and pd.isna(lat) and pd.isna(lon):
            continue

        all_data.append((rd_name, lrp, lat, lon))

df_roads1 = pd.DataFrame(all_data, columns=["road", "LRP", "LAT", "LON"])

print(df_roads1.head(10))
# print(df_roads1[df_roads1['road'] == 'Z1102'])
# Out:
# C:\Users\lieke\AppData\Local\Temp\ipykernel_21224\1315536670.py:1: DtypeWarning: Columns (571,574,577,580,583,586,589,592,595,598,601,604,607,610,613,616,619,622,625,628,631,634,637,640,643,646,649,652,655,658,661,664,667,670,673,676,679,682,685,688,691,694,697,700,703,706,709,712,715,718,721,724,727,730,733,736,739,742,745,748,751,754,757,760,763,766,769,772,775,778,781,784,787,790,793,796,799,802,805,808,811,814,817,820,823,826,829,832,835,838,841,844,847,850,853,856,859,862,865,868,871,874,877,880,883,886,889,892,895,898,901,904,907,910,913,916,919,922,925,928,931,934,937,940,943,946,949,952,955,958,961,964,967,970,973,976,979,982,985,988,991,994,997,1000,1003,1006,1009,1012,1015,1018,1021,1024,1027,1030,1033,1036,1039,1042,1045,1048,1051,1054,1057,1060,1063,1066,1069,1072,1075,1078,1081,1084,1087,1090,1093,1096,1099,1102,1105,1108,1111,1114,1117,1120,1123,1126,1129,1132,1135,1138,1141,1144,1147,1150,1153,1156,1159,1162,1165,1168,1171,1174,1177,1180,1183,1186,1189,1192,1195,1198,1201,1204,1207,1210,1213,1216,1219,1222,1225,1228,1231,1234,1237,1240,1243,1246,1249,1252,1255,1258,1261,1264,1267,1270,1273,1276,1279,1282,1285,1288,1291,1294,1297,1300,1303,1306,1309,1312,1315,1318,1321,1324,1327,1330,1333,1336,1339,1342,1345,1348,1351,1354,1357,1360,1363,1366,1369,1372,1375,1378,1381,1384,1387,1390,1393,1396,1399,1402,1405,1408,1411,1414,1417,1420,1423,1426,1429,1432,1435,1438,1441,1444,1447,1450,1453,1456,1459,1462,1465,1468,1471,1474,1477,1480,1483,1486,1489,1492,1495,1498,1501,1504,1507,1510,1513,1516,1519,1522,1525,1528,1531,1534,1537,1540,1543,1546,1549,1552,1555,1558,1561,1564,1567,1570,1573,1576,1579,1582,1585,1588,1591,1594,1597,1600,1603,1606,1609,1612,1615,1618,1621,1624,1627,1630,1633,1636,1639,1642,1645,1648,1651,1654,1657,1660,1663,1666,1669,1672,1675,1678,1681,1684,1687,1690,1693,1696,1699,1702,1705,1708,1711,1714,1717,1720,1723,1726,1729,1732,1735,1738,1741,1744,1747,1750,1753,1756,1759,1762,1765,1768,1771,1774,1777,1780,1783,1786,1789,1792,1795,1798,1801,1804,1807,1810,1813,1816,1819,1822,1825,1828,1831,1834,1837,1840,1843,1846,1849,1852,1855,1858,1861,1864,1867,1870,1873,1876,1879,1882,1885,1888,1891,1894,1897,1900,1903,1906,1909,1912,1915,1918,1921,1924,1927,1930,1933,1936,1939,1942,1945,1948,1951,1954,1957,1960,1963,1966,1969,1972,1975,1978,1981,1984,1987,1990,1993,1996,1999,2002,2005,2008,2011,2014,2017,2020,2023,2026,2029,2032,2035,2038,2041,2044,2047,2050,2053,2056,2059,2062,2065,2068,2071,2074,2077,2080,2083,2086,2089,2092,2095,2098,2101,2104,2107,2110,2113,2116,2119,2122,2125,2128,2131,2134,2137,2140,2143,2146,2149,2152,2155,2158,2161,2164,2167,2170,2173,2176,2179,2182,2185,2188,2191,2194,2197,2200,2203,2206,2209,2212,2215,2218,2221,2224,2227,2230,2233,2236,2239,2242,2245,2248,2251,2254,2257,2260,2263,2266,2269,2272,2275,2278,2281,2284,2287,2290,2293,2296,2299,2302,2305,2308,2311,2314,2317,2320,2323,2326,2329,2332,2335,2338,2341,2344,2347,2350,2353,2356,2359,2362,2365,2368,2371,2374,2377,2380,2383,2386,2389,2392,2395,2398,2401,2404,2407,2410,2413,2416,2419,2422,2425,2428,2431,2434,2437,2440,2443,2446,2449,2452,2455,2458,2461,2464,2467,2470,2473,2476,2479,2482,2485,2488,2491,2494,2497,2500,2503,2506,2509,2512,2515,2518,2521,2524,2527,2530,2533,2536,2539,2542,2545,2548,2551,2554,2557,2560,2563,2566,2569,2572,2575,2578,2581,2584,2587,2590,2593,2596,2599,2602,2605,2608,2611,2614,2617,2620,2623,2626,2629,2632,2635,2638,2641,2644,2647,2650,2653,2656,2659,2662,2665,2668,2671,2674,2677,2680,2683,2686,2689,2692,2695,2698,2701,2704,2707,2710,2713,2716,2719,2722,2725,2728,2731,2734,2737,2740,2743,2746,2749,2752,2755,2758,2761,2764,2767,2770,2773,2776,2779,2782,2785,2788,2791,2794,2797,2800,2803,2806,2809,2812,2815,2818,2821,2824,2827,2830,2833,2836,2839,2842,2845,2848,2851,2854,2857,2860,2863,2866,2869,2872,2875,2878,2881,2884,2887,2890,2893,2896,2899,2902,2905,2908,2911,2914,2917,2920,2923,2926,2929,2932,2935,2938,2941,2944,2947,2950,2953,2956,2959,2962,2965,2968,2971,2974,2977,2980,2983,2986,2989,2992,2995,2998,300 ...
#   df_roads = pd.read_csv('../data/raw/_roads.tsv', sep='\t')
#    road LRP_1      LAT_1      LON_1   LRP_2      LAT_2      LON_2    LRP_3  \
# 0    N1  LRPS  23.706028  90.443333   LRPSa  23.702917  90.450417    LRPSb
# 1  N101  LRPS  23.454139  91.212861   LRPSa  23.461889  91.212000   LRP001
# 2  N102  LRPS  23.478972  91.118194   LRPSa  23.481583  91.116777    LRPSb
# 3  N103  LRPS  23.957028  91.115528  LRP001  23.961917  91.113611  LRP001a
# 4  N104  LRPS  23.009667  91.399416   LRPSa  23.009278  91.395250   LRP001
# 5  N105  LRPS  23.690416  90.546611  LRP001  23.698416  90.551056  LRP001a
# 6  N106  LRPS  22.393555  91.821583   LRPSa  22.397500  91.820027    LRPSb
# 7  N107  LRPS  22.394416  91.891833   LRPSa  22.392194  91.893166    LRPSb
# 8  N108  LRPS  22.102139  92.074083   LRPSa  22.103750  92.082416   LRP001
# 9  N109  LRPS  21.443361  92.101472   LRPSa  21.442305  92.101917    LRPSb
#
#        LAT_3      LON_3  ...  LON_1345  LRP_1346   LAT_1346   LON_1346  \
# 0  23.702778  90.450472  ...  92.29825   LRP466c  20.864667  92.298194
# 1  23.462944  91.211806  ...       NaN       NaN        NaN        NaN
# 2  23.486666  91.113361  ...       NaN       NaN        NaN        NaN
# 3  23.967666  91.111889  ...       NaN       NaN        NaN        NaN
# 4  23.009306  91.389805  ...       NaN       NaN        NaN        NaN
# 5  23.699305  90.551528  ...       NaN       NaN        NaN        NaN
# 6  22.399055  91.819805  ...       NaN       NaN        NaN        NaN
# 7  22.391889  91.893111  ...       NaN       NaN        NaN        NaN
# 8  22.103972  92.083611  ...       NaN       NaN        NaN        NaN
# 9  21.441889  92.101944  ...       NaN       NaN        NaN        NaN
#
#    LRP_1347   LAT_1347   LON_1347  LRP_1348   LAT_1348   LON_1348
# 0    LRP467  20.862972  92.298083      LRPE  20.862917  92.298083
# 1       NaN        NaN        NaN       NaN        NaN        NaN
# 2       NaN        NaN        NaN       NaN        NaN        NaN
# 3       NaN        NaN        NaN       NaN        NaN        NaN
# 4       NaN        NaN        NaN       NaN        NaN        NaN
# 5       NaN        NaN        NaN       NaN        NaN        NaN
# 6       NaN        NaN        NaN       NaN        NaN        NaN
# 7       NaN        NaN        NaN       NaN        NaN        NaN
# 8       NaN        NaN        NaN       NaN        NaN        NaN
# 9       NaN        NaN        NaN       NaN        NaN        NaN
#
# [10 rows x 4045 columns]
#   road      LRP        LAT        LON
# 0   N1     LRPS  23.706028  90.443333
# 1   N1    LRPSa  23.702917  90.450417
# 2   N1    LRPSb  23.702778  90.450472
# 3   N1   LRP001  23.702139  90.451972
# 4   N1   LRP002  23.697889  90.460583
# 5   N1  LRP002a  23.697361  90.461667
# 6   N1   LRP003  23.693833  90.469138
# 7   N1   LRP004  23.693611  90.478777
# 8   N1  LRP004a  23.693805  90.480527
# 9   N1   LRP005  23.694750  90.488500

# %%
df_error_bridges =df_bridges[df_bridges['EstimatedLoc'] == 'error']
# df_error_bridges.head(10)

df_error_bridges1 = df_error_bridges[['road', 'km','LRPName', 'chainage', 'lat', 'lon']]
df_error_bridges1.head(10)
# Out:
#         road      km  LRPName chainage  lat  lon
# 6277   Z1102   7.282  LRP007a    7.282  NaN  NaN
# 7227   Z1602  23.760  LRP024a    23.76  NaN  NaN
# 7228   Z1602  24.066  LRP024c   24.066  NaN  NaN
# 7231   Z1602  36.394  LRP036a   36.394  NaN  NaN
# 7976   Z2063   4.100  LRP005a      4.1  NaN  NaN
# 12020  Z1065  27.924  LRP027b   27.924  NaN  NaN
# 13115  Z6856  46.777  LRP047b   46.777  NaN  NaN
# 13169  Z7045  20.250  LRP019b    20.25  NaN  NaN
# 13375  Z8204   9.744  LRP009f    9.744  NaN  NaN
# 14693  Z8048   3.840  LRP003e     3.84  NaN  NaN

# %%
merged = df_error_bridges1.merge(
    df_roads1[['road', 'LRP', 'LAT', 'LON']],
    left_on=['road', 'LRPName'],
    right_on=['road', 'LRP'],
    how='left'
)

merged['lat'] = merged['LAT'].combine_first(merged['lat'])
merged['lon'] = merged['LON'].combine_first(merged['lon'])

df_error_bridges1 = merged.drop(columns=['LRP', 'LAT', 'LON'])
df_error_bridges1.head(10)

#Oke dit werkt niet want de LRP namen in de twee datasets komen niet overeen. We moeten dus een andere manier vinden om de locatie van de bruggen te bepalen.
# Out:
#     road      km  LRPName chainage  lat  lon
# 0  Z1102   7.282  LRP007a    7.282  NaN  NaN
# 1  Z1602  23.760  LRP024a    23.76  NaN  NaN
# 2  Z1602  24.066  LRP024c   24.066  NaN  NaN
# 3  Z1602  36.394  LRP036a   36.394  NaN  NaN
# 4  Z2063   4.100  LRP005a      4.1  NaN  NaN
# 5  Z1065  27.924  LRP027b   27.924  NaN  NaN
# 6  Z6856  46.777  LRP047b   46.777  NaN  NaN
# 7  Z7045  20.250  LRP019b    20.25  NaN  NaN
# 8  Z8204   9.744  LRP009f    9.744  NaN  NaN
# 9  Z8048   3.840  LRP003e     3.84  NaN  NaN

# %%
# #rounded geographical borders from Bangledesch, with small buffer
# LAT_MIN, LAT_MAX = 20.57 - 0.1, 26.63 + 0.1
# LON_MIN, LON_MAX = 88.02 - 0.1, 92.68 + 0.1

# #filter locations outside of Bangladesh
# outside_bounds = (
#     (df_bridges['lat'] < LAT_MIN) | (df_bridges['lat'] > LAT_MAX) |
#     (df_bridges['lon'] < LON_MIN) | (df_bridges['lon'] > LON_MAX)
# )

# #filter error locations in file 
# loc_error = df_bridges['EstimatedLoc'] == 'error'

# #define the briders that are outside Bangladesh or have an error 
# df_bridges['needs_repair'] = outside_bounds | loc_error

# bad_bridges_count = df_bridges['needs_repair'].sum()
# print(f"Number of bridges that need repair: {bad_bridges_count}")

# df_bridges[df_bridges['needs_repair'] == True].head(10)

# %%
import geopandas as gpd
from shapely.geometry import Point

# %%
world = gpd.read_file("../data/raw/ne_10m_admin_0_countries.shp")

bangladesh = world[world['ADMIN'] == 'Bangladesh'].copy()
bangladesh = bangladesh.set_crs("EPSG:4326", allow_override=True)

bd_geom = bangladesh.geometry.buffer(0).union_all()

gdf_points = gpd.GeoDataFrame(
    df_bridges,
    geometry=gpd.points_from_xy(df_bridges['lon'], df_bridges['lat']),
    crs="EPSG:4326"
)

utm_crs = "EPSG:32646"
bangladesh_m = bangladesh.to_crs(utm_crs)
gdf_points_m = gdf_points.to_crs(utm_crs)

bd_geom_m = bangladesh_m.geometry.buffer(0).union_all()

gdf_points_m["distance_to_bd_m"] = gdf_points_m.geometry.distance(bd_geom_m)

threshold_m = 5_000  # 50 km in meters
gdf_points_m["far_outside_bd"] = gdf_points_m["distance_to_bd_m"] > threshold_m

gdf_points["distance_to_bd_km"] = gdf_points_m["distance_to_bd_m"] / 1000
gdf_points["far_outside_bd"] = gdf_points_m["far_outside_bd"].values
# Out:
# c:\Users\lieke\anaconda3\Lib\site-packages\shapely\measurement.py:81: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 10))
bangladesh.plot(ax=ax, facecolor="none", edgecolor="black", linewidth=1)
gdf_points[gdf_points["far_outside_bd"]].plot(ax=ax, color="red", markersize=5, label=">50 km buiten")
gdf_points[~gdf_points["far_outside_bd"]].plot(ax=ax, color="green", markersize=5, label="binnen 50 km")
plt.legend()
plt.title("Punten > 5 km buiten Bangladesh")
plt.show()

# %%
gdf_points.head(10)
far_points = gdf_points[gdf_points["far_outside_bd"]]
far_points_selected = far_points[["road", "LRPName", "lat", "lon"]]
print(far_points_selected)
# Out:
#         road  LRPName        lat        lon
# 855       N2  LRP247a  25.963389  92.019083
# 2083    N108  LRP014b  20.155611  92.178889
# 2280    R151  LRP005d  21.924028  91.558611
# 2469    R164    LRPSa  22.503194  92.640028
# 2516    R170  LRP035b  20.067056  91.937722
# ...      ...      ...        ...        ...
# 21130  Z5452  LRP027b        NaN        NaN
# 21281  Z7602  LRP013b  15.869151  88.989909
# 21309  Z7718  LRP038a   0.000000   0.000000
# 21362  Z8203  LRP001a   0.000000   0.000000
# 21396  Z8708  LRP074a        NaN        NaN
#
# [197 rows x 4 columns]

# %%
merged = far_points_selected.merge(
    df_roads1[['road', 'LRP', 'LAT', 'LON']],
    left_on=['road', 'LRPName'],                
    right_on=['road', 'LRP'],                  
    how='left'
)

merged['lat'] = merged['LAT'].combine_first(merged['lat'])
merged['lon'] = merged['LON'].combine_first(merged['lon'])

merged['matched'] = merged['LAT'].notna() & merged['LON'].notna()
far_points_selected_updated = merged.drop(columns=['LRP', 'LAT', 'LON'])


far_points_selected_updated[far_points_selected_updated['matched'] == False]

mask = far_points_selected_updated['lat'] > 80

# Wissel lat en lon voor deze punten
far_points_selected_updated.loc[mask, ['lat', 'lon']] = \
    far_points_selected_updated.loc[mask, ['lon', 'lat']].values

# Controleer resultaat
far_points_selected_updated[mask].head()
# Out:
#      road  LRPName        lat        lon  matched
# 7    R241  LRP029a  24.805111  91.543889    False
# 12   R241  LRP036a  24.855083  91.514083    False
# 110  R241  LRP028c  24.796694  91.542083    False
# 121  R241  LRP035c  24.849861  91.516167    False

# %%
df_bridges_updated = df_bridges.copy()

df_bridges_updated = df_bridges_updated.merge(
    far_points_selected_updated[['road', 'LRPName', 'lat', 'lon', 'matched']],
    on=['road', 'LRPName'],
    how='left',
    suffixes=('', '_far')
)

df_bridges_updated['lat'] = df_bridges_updated['lat_far'].combine_first(df_bridges_updated['lat'])
df_bridges_updated['lon'] = df_bridges_updated['lon_far'].combine_first(df_bridges_updated['lon'])

df_bridges_updated['matched'] = df_bridges_updated['matched'].fillna(False)

df_bridges_updated = df_bridges_updated.drop(columns=['lat_far', 'lon_far'])

df_bridges_updated.head(10)
# Out:
# C:\Users\lieke\AppData\Local\Temp\ipykernel_21224\2456801155.py:13: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_bridges_updated['matched'] = df_bridges_updated['matched'].fillna(False)
#   road      km              type  LRPName                         name  \
# 0   N1   1.800       Box Culvert  LRP001a                            .
# 1   N1   4.925       Box Culvert  LRP004b                            .
# 2   N1   8.976  PC Girder Bridge  LRP008b            Kanch pur Bridge.
# 3   N1  10.880       Box Culvert  LRP010b             NOYAPARA CULVERT
# 4   N1  10.897       Box Culvert  LRP010c               ADUPUR CULVERT
# 5   N1  11.296       Box Culvert  LRP011a  NAYABARI KASPUR BOX CULVERT
# 6   N1  12.239       Box Culvert  LRP012a        KHAS PARA BOX CULVERT
# 7   N1  12.253       Box Culvert  LRP012b        DAWAN BAG BOX CULVERT
# 8   N1  12.660  PC Girder Bridge  LRP013a          Madanpur Bridge.(L)
# 9   N1  12.660  PC Girder Bridge  LRP013a                MADAN PUR (R)
#
#    length condition  structureNr  \
# 0   11.30         A       117861
# 1    6.60         A       117862
# 2  394.23         A       119889
# 3    6.30         A       112531
# 4    6.30         A       112532
# 5    8.30         A       101110
# 6    9.30         A       101117
# 7    6.10         A       101119
# 8   27.50         A       119897
# 9   26.30         A       109841
#
#                                             roadName chainage  ...  \
# 0  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...      1.8  ...
# 1  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...    4.925  ...
# 2  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...    8.976  ...
# 3  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...    10.88  ...
# 4  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...   10.897  ...
# 5  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...   11.296  ...
# 6  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...   12.239  ...
# 7  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...   12.253  ...
# 8  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...    12.66  ...
# 9  Dhaka (Jatrabari)-Comilla (Mainamati)-Chittago...    12.66  ...
#
#    constructionYear  spans   zone circle     division   sub-division  \
# 0            2005.0    2.0  Dhaka  Dhaka  Narayanganj  Narayanganj-1
# 1            2006.0    1.0  Dhaka  Dhaka  Narayanganj  Narayanganj-1
# 2               NaN    NaN  Dhaka  Dhaka  Narayanganj  Narayanganj-1
# 3            1992.0    2.0  Dhaka  Dhaka  Narayanganj      Vitikandi
# 4            1984.0    2.0  Dhaka  Dhaka  Narayanganj      Vitikandi
# 5            1986.0    2.0  Dhaka  Dhaka  Narayanganj      Vitikandi
# 6            1986.0    2.0  Dhaka  Dhaka  Narayanganj      Vitikandi
# 7            1987.0    2.0  Dhaka  Dhaka  Narayanganj      Vitikandi
# 8               NaN    NaN  Dhaka  Dhaka  Narayanganj      Vitikandi
# 9            2003.0    1.0  Dhaka  Dhaka  Narayanganj      Vitikandi
#
#          lat        lon  EstimatedLoc matched
# 0  23.702889  90.450389          bcs1   False
# 1  23.693611  90.478833          bcs1   False
# 2  23.704583  90.518833  road_precise   False
# 3  23.699833  90.530722          bcs1   False
# 4  23.699667  90.530722          bcs1   False
# 5  23.697361  90.533833          bcs1   False
# 6  23.692333  90.541000          bcs1   False
# 7  23.692556  90.541139          bcs1   False
# 8  23.685500  90.551278  road_precise   False
# 9  23.691111  90.544889          bcs1   False
#
# [10 rows x 21 columns]

# %%
import geopandas as gpd
import matplotlib.pyplot as plt


df_plot = df_bridges_updated[(df_bridges_updated['lat'] != 0.0) & (df_bridges_updated['lon'] != 0.0)]

gdf_bridges = gpd.GeoDataFrame(
    df_plot,
    geometry=gpd.points_from_xy(df_plot['lon'], df_plot['lat']),
    crs="EPSG:4326"
)


world = gpd.read_file("../data/raw/ne_10m_admin_0_countries.shp")
bangladesh = world[world['ADMIN'] == 'Bangladesh']

fig, ax = plt.subplots(figsize=(8, 10))
bangladesh.plot(ax=ax, facecolor='none', edgecolor='black', linewidth=1)
gdf_bridges.plot(ax=ax, color='blue', markersize=20, label='Bridges')

plt.title("Bruggen in Bangladesh (punten lat/lon != 0)")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.legend()
plt.show()

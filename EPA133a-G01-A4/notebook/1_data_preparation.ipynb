# %%
import pandas as pd
from itertools import combinations
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from matplotlib.lines import Line2D

# %%
#Loading in the roads data file
df1 = pd.read_csv('../data/data_with_AADT.csv')
#Filtering on the N1 and N2 roads
roads = ['N1', 'N2'] + [f'N{i}' for i in range(100, 300)]
dfN = df1[df1['road'].isin(roads)]

# %%
#Creating the source and sink for the new data frame, based on the minimal and maximal chainage
source_rows = dfN.loc[dfN.groupby('road')['chainage'].idxmin()]
sink_rows = dfN.loc[dfN.groupby('road')['chainage'].idxmax()]

df_proc = (
    pd.concat([source_rows, sink_rows])
    .drop_duplicates(subset=['road', 'chainage', 'lrp'])
    .sort_values(['road', 'chainage'])
    .reset_index(drop=True)
)

# %%
#Calculate the total lenght of a road based on it's chainage
df_proc['total_length'] = df_proc.groupby('road')['chainage'].transform('max')
#Filter out roads that have a length smaller then 25 km
df_filtered = (df_proc[df_proc['total_length'] > 25]).copy()
print(df_filtered.size + df_filtered.size)
# Out:
# 396

# %%
#Adjust dataframe for the resulting dataset
df_filtered['model_type'] = 'sourcesink'
df_filtered['length'] = 0
df_filtered['condition'] = ''

df_filtered = df_filtered[['road', 'lrp', 'model_type', 'name', 'lat', 'lon', 'length', 'condition', 'chainage', 'avg_truck_AADT']]
df_filtered.rename(columns={'lrp': 'id'}, inplace=True)
df_filtered[df_filtered["model_type"] == "sourcesink"]
# Out:
#     road      id  model_type  \
# 0     N1    LRPS  sourcesink
# 1     N1    LRPE  sourcesink
# 4   N102    LRPS  sourcesink
# 5   N102    LRPE  sourcesink
# 8   N104    LRPS  sourcesink
# 9   N104    LRPE  sourcesink
# 10  N105    LRPS  sourcesink
# 11  N105  LRP048  sourcesink
# 12  N106    LRPS  sourcesink
# 13  N106    LRPE  sourcesink
# 36    N2    LRPS  sourcesink
# 37    N2    LRPE  sourcesink
# 40  N204    LRPS  sourcesink
# 41  N204    LRPE  sourcesink
# 46  N207    LRPS  sourcesink
# 47  N207    LRPE  sourcesink
# 48  N208    LRPS  sourcesink
# 49  N208    LRPE  sourcesink
#
#                                                  name        lat        lon  \
# 0   Start of Road  after Jatrabari Flyover infront...  23.706028  90.443333
# 1   End of Road at Shapla Chattar ,Teknaf Meet wit...  20.862917  92.298083
# 4                     Start of road from N1 Mainamati  23.478972  91.118194
# 5                             Meet with N 2 at Sanail  24.050611  91.114667
# 8                             Intersection with Z1031  23.009667  91.399416
# 9                  Meet with Z1441& Z1405 at Sonapur.  22.825749  91.101444
# 10  Starts of road from N1,Dhaka teknaf road at Ma...  23.690416  90.546611
# 11  B.Bridge 83 km,Tangail 60 km / End of Road  In...  23.989527  90.358222
# 12                   Start of Road  from Oxygen  More  22.393555  91.821583
# 13                The road ends Infront of DC Bunglow  22.648527  92.201833
# 36                     Road Start from N1 at Katchpur  23.705917  90.521444
# 37                               Road End at Jaflong.  25.157056  92.017638
# 40               Road start from N2 at Jagannathganj.  24.147916  91.346611
# 41  Road End intersecting N2 at Shaistagonj Round ...  24.267388  91.477138
# 46                      Road start from N2 at Mirpur.  24.294861  91.510250
# 47  Road end with N2 at Mukti joddha Chattor Sherpur.  24.626333  91.677527
# 48                Road Start from N207 infront of RHD  24.471360  91.765556
# 49  Road end at Humayun Rashid Chattar, Intersecti...  24.877555  91.875360
#
#     length condition  chainage  avg_truck_AADT
# 0        0               0.000     2463.666667
# 1        0             462.254      205.333333
# 4        0               0.000      579.000000
# 5        0              82.682      867.333333
# 8        0               0.000      390.333333
# 9        0              49.630      396.666667
# 10       0               0.000     1666.333333
# 11       0              48.870     1738.666667
# 12       0               0.000     1131.000000
# 13       0              66.850       73.000000
# 36       0               0.000     2236.666667
# 37       0             286.516      677.000000
# 40       0               0.000      122.000000
# 41       0              34.421      122.000000
# 46       0               0.000      255.333333
# 47       0              67.985      255.333333
# 48       0               0.000      321.333333
# 49       0              57.495      730.333333

# %%
# Visual inspection of N1 and N2
df_plot = dfN[dfN['road'].isin(['N1', 'N2'])]

for road, data in df_plot.groupby('road'):
    plt.plot(data['lon'], data['lat'], label=road)

plt.legend()
plt.show()

# %%
#Function to calculate distances between locations on longitude and latitude, based on Haversine formula
def haversine(lat1, lon1, lat2, lon2):
    R = 6371

    lat1 = np.radians(lat1)
    lon1 = np.radians(lon1)
    lat2 = np.radians(lat2)
    lon2 = np.radians(lon2)

    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))

    return R * c

# %%
df_n1 = dfN[dfN['road'] == 'N1'].copy()
df_n2 = dfN[dfN['road'] == 'N2'].copy()
#Make dataframe with every possible combination of points on N1 and N2
df_cross = df_n1.merge(df_n2, how='cross', suffixes=('_n1', '_n2'))

#Calculate the distances between every point between N1 and N2
df_cross['distance'] = haversine(
    df_cross['lat_n1'],
    df_cross['lon_n1'],
    df_cross['lat_n2'],
    df_cross['lon_n2']
)
#Find intersections by setting a threshold distance of 0.05 km
intersections = df_cross[df_cross['distance'] < 0.05]

#Dataframe showing the intersections of N1 and N2 based on the threshold distance of 0.05 km
intersections[['road_n1','chainage_n1','lrp_n1',
               'road_n2','chainage_n2','lrp_n2',
               'distance']]
# Out:
#       road_n1  chainage_n1   lrp_n1 road_n2  chainage_n2 lrp_n2  distance
# 15062      N1        8.763  LRP009a      N2          0.0   LRPS  0.020374

# %%
#Find all possible combinations of roads
roads = df_filtered['road'].unique()
road_pairs = list(combinations(roads, 2))

# %%
#Find all intersections by checking the distances of every point between two roads, and calculate if this
#distance is smaller then the threshold of 0.05 km
all_intersections = []

for r1, r2 in road_pairs:

    df_r1 = dfN[dfN['road'] == r1]
    df_r2 = dfN[dfN['road'] == r2]

    df_cross = df_r1.merge(df_r2, how='cross', suffixes=('_1', '_2'))

    df_cross['distance'] = haversine(
        df_cross['lat_1'],
        df_cross['lon_1'],
        df_cross['lat_2'],
        df_cross['lon_2']
    )

    inter = df_cross[df_cross['distance'] < 0.05]

    all_intersections.append(inter)

intersections = pd.concat(all_intersections, ignore_index=True)

# %%
#Group points that are based on the same intersection
intersection_groups = {}
group_id = 0

for _, row in intersections.iterrows():

    a = (row['road_1'], row['lrp_1'])
    b = (row['road_2'], row['lrp_2'])

    if a in intersection_groups:
        intersection_groups[b] = intersection_groups[a]

    elif b in intersection_groups:
        intersection_groups[a] = intersection_groups[b]

    else:
        intersection_groups[a] = group_id
        intersection_groups[b] = group_id
        group_id += 1

# %%
#Extract the intersection point from side 1 of each road pair and of side 2
df_i1 = intersections[['road_1','lrp_1','chainage_1']].rename(columns={
    'road_1':'road',
    'lrp_1':'lrp',
    'chainage_1':'chainage'
})
df_i2 = intersections[['road_2','lrp_2','chainage_2']].rename(columns={
    'road_2':'road',
    'lrp_2':'lrp',
    'chainage_2':'chainage'
})
#Combine both sides into one intersection-node table
df_intersections = pd.concat([df_i1, df_i2])

#Merge with the original road dataset
df_intersections = df_intersections.merge(
    dfN,
    on=['road','lrp','chainage'],
    how='left'
)

#Adjust dataframe for the resulting dataset
df_intersections['model_type'] = 'intersection'
df_intersections['length'] = 0
df_intersections['condition'] = ''

#Map each node to its intersection group
df_intersections['intersection_group'] = df_intersections.apply(
    lambda r: intersection_groups.get((r['road'], r['lrp']), None),
    axis=1
)
#Finalise the dataframe
df_intersections = df_intersections[['road','lrp','model_type','name','lat','lon','length','condition','chainage', 'intersection_group', 'avg_truck_AADT']]
df_intersections = df_intersections.rename(columns={'lrp':'id'})

# %%
# Group nearby points within each road and assign them a shared ID
def sync_geographical_ids(df, threshold=0.05):
    final_groups = []

    #Group dataframe per road
    for road, group in df.groupby('road'):
        #Reset reference locations for the current road
        master_locations = []
        synced_ids = []

        #Work on a copy to avoid modifying the grouped slice directly
        group = group.copy()

        for index, row in group.iterrows():
            current_lat = row['lat']
            current_lon = row['lon']
            current_id = row['id']

            match_found = False
            #Compare current point to previously stored reference locations
            for master_lat, master_lon, master_id in master_locations:
                distance = haversine(current_lat, current_lon, master_lat, master_lon)

                if distance <= threshold:
                    #Reuse the existing ID if the point matches a known location
                    synced_ids.append(master_id)
                    match_found = True
                    break

            if not match_found:
                #No match, new unique location for this road
                master_locations.append((current_lat, current_lon, current_id))
                synced_ids.append(current_id)

        #Replace original IDs with synchronized IDs
        group['id'] = synced_ids

        #Remove duplicates
        group = group.drop_duplicates('id')

        final_groups.append(group)

    #Combine all processed roads into one dataframe
    return pd.concat(final_groups).reset_index(drop=True)

# %%
#Use the sync_geographical_ids on the dataframe
df_unique = sync_geographical_ids(df_intersections)

# %%
#Combine the filtered road points and the unique nodes into one dataframe and sort by road and chainage
df_final = pd.concat([df_filtered, df_unique], ignore_index=True)
df_final = df_final.sort_values(['road', 'chainage']).reset_index(drop=True)

# %%
#Make a function that deletes sourcesinks of sideroads of N1 and N2 that are on N1 and N2
def remove_overlapping_sourcesinks(df, threshold=0.05):
    indices_to_drop = []

    for road, group in df.groupby('road'):
        #Sort points within the road for more consistent pairwise comparison
        group = group.sort_values('chainage')
        indices = group.index.tolist()
        #Compare each node with all following nodes on the same road
        for i in range(len(indices)):
            for j in range(i + 1, len(indices)):
                idx_a = indices[i]
                idx_b = indices[j]

                dist = haversine(
                    df.at[idx_a, 'lat'], df.at[idx_a, 'lon'],
                    df.at[idx_b, 'lat'], df.at[idx_b, 'lon']
                )
                #If two nodes overlap geographically, one should be deleted
                if dist <= threshold:
                    type_a = df.at[idx_a, 'model_type']
                    type_b = df.at[idx_b, 'model_type']

                    #Delete sourcesink if the other point is of a different type
                    if type_a == 'sourcesink' and type_b != 'sourcesink':
                        indices_to_drop.append(idx_a)
                    elif type_b == 'sourcesink' and type_a != 'sourcesink':
                        indices_to_drop.append(idx_b)
                    #If both points are , delete the second one
                    elif type_a == 'sourcesink' and type_b == 'sourcesink':
                        indices_to_drop.append(idx_a)

    #Remove duplicates from the dataframe
    df_cleaned = df.drop(index=list(set(indices_to_drop))).reset_index(drop=True)
    return df_cleaned

#Final dataframe whereby the function is used
df_final = remove_overlapping_sourcesinks(df_final)
df_final[df_final["model_type"] == "sourcesink"]
# Out:
#     road      id  model_type  \
# 0     N1    LRPS  sourcesink
# 5     N1    LRPE  sourcesink
# 8   N104    LRPS  sourcesink
# 10  N104    LRPE  sourcesink
# 13  N105  LRP048  sourcesink
# 14  N106    LRPS  sourcesink
# 15  N106    LRPE  sourcesink
# 25    N2    LRPE  sourcesink
#
#                                                  name        lat        lon  \
# 0   Start of Road  after Jatrabari Flyover infront...  23.706028  90.443333
# 5   End of Road at Shapla Chattar ,Teknaf Meet wit...  20.862917  92.298083
# 8                             Intersection with Z1031  23.009667  91.399416
# 10                 Meet with Z1441& Z1405 at Sonapur.  22.825749  91.101444
# 13  B.Bridge 83 km,Tangail 60 km / End of Road  In...  23.989527  90.358222
# 14                   Start of Road  from Oxygen  More  22.393555  91.821583
# 15                The road ends Infront of DC Bunglow  22.648527  92.201833
# 25                               Road End at Jaflong.  25.157056  92.017638
#
#     length condition  chainage  avg_truck_AADT  intersection_group
# 0        0               0.000     2463.666667                 NaN
# 5        0             462.254      205.333333                 NaN
# 8        0               0.000      390.333333                 NaN
# 10       0              49.630      396.666667                 NaN
# 13       0              48.870     1738.666667                 NaN
# 14       0               0.000     1131.000000                 NaN
# 15       0              66.850       73.000000                 NaN
# 25       0             286.516      677.000000                 NaN

# %%
#Loading in the Bridges data
df_BMMS = pd.read_excel('../data/BMMS_overview.xlsx')

#Selecting the columns that we need
cols = [
    "road",
    "name",
    "LRPName",
    "length",
    "chainage",
    "lat",
    "lon",
    "condition",
]

bridges_BMMS = df_BMMS[cols].copy()

#Filter the dataframe on the roads that are needed and make it uniform
roads = df_filtered['road'].unique()
bridges_BMMS = bridges_BMMS[bridges_BMMS['road'].isin(roads)]
bridges_BMMS['name_clean'] = bridges_BMMS['name'].astype(str).str.replace(' ', '').str.upper()

# %%
#Dropping duplicates
df_unique = bridges_BMMS.drop_duplicates(
    subset=['chainage','lat','lon'],
    keep='first'
).reset_index(drop=True)

#Filtering on bridges only
df_unique['model_type'] = 'bridge'

#Filter the dataframe on what is needed
df_bridges = df_unique[['road','LRPName','model_type','name','lat','lon','length','condition','chainage']]
df_bridges = df_bridges.rename(columns={'LRPName':'id'})

# Bring avg_truck_AADT from dfN onto bridges by nearest chainage match per road
def assign_aadt_by_nearest_chainage(df_target, df_source):
    result = df_target.copy()
    aadt_values = []

    for _, row in result.iterrows():
        road_source = df_source[df_source['road'] == row['road']]
        if road_source.empty:
            aadt_values.append(np.nan)
        else:
            nearest_idx = (road_source['chainage'] - row['chainage']).abs().idxmin()
            aadt_values.append(road_source.loc[nearest_idx, 'avg_truck_AADT'])

    result['avg_truck_AADT'] = aadt_values
    return result

df_bridges = assign_aadt_by_nearest_chainage(df_bridges, dfN)

#Append bridges to the main dataframe
df_final = pd.concat([df_final, df_bridges], ignore_index=True)

#Sort dataframe on road and chainage
df_final = df_final.sort_values(['road','chainage']).reset_index(drop=True)

#Remove duplicate structures on the same road based on a cleaned name prefix
df_final = (
    df_final
    .assign(
        prefix=(
            df_final["name"]
            .str.replace('.', '')
            .str.lower()
            .str.strip()
            .str.extract(r"^([^(]+)", expand=False)
        )
    )
    .drop_duplicates(subset=['road','prefix'], keep='first')
    .drop(columns="prefix")
)

# %%
# Insert link records between consecutive points/nodes along each road
final_df_with_links = []

for road, road_df in df_final.groupby('road'):
    road_df = road_df.sort_values('chainage').reset_index(drop=True)

    for j in range(len(road_df)):
        row = road_df.iloc[j]

        if j == 0:
            final_df_with_links.append(row)
            continue

        prev = road_df.iloc[j-1]

        lat_link = (row['lat'] + prev['lat']) / 2
        lon_link = (row['lon'] + prev['lon']) / 2
        link_length = abs((row['chainage'] - prev['chainage']) * 1000)

        # Interpolate avg_truck_AADT from the two surrounding nodes
        aadt_prev = prev.get('avg_truck_AADT', np.nan)
        aadt_next = row.get('avg_truck_AADT', np.nan)
        if pd.isna(aadt_prev) and pd.isna(aadt_next):
            link_aadt = np.nan
        elif pd.isna(aadt_prev):
            link_aadt = aadt_next
        elif pd.isna(aadt_next):
            link_aadt = aadt_prev
        else:
            link_aadt = (aadt_prev + aadt_next) / 2

        link = {
            'road': road,
            'id': None,
            'model_type': 'link',
            'name': 'Link',
            'lat': lat_link,
            'lon': lon_link,
            'length': link_length,
            'condition': 'NaN',
            'chainage': (row['chainage'] + prev['chainage']) / 2,
            'avg_truck_AADT': link_aadt,
        }

        final_df_with_links.append(pd.Series(link))
        final_df_with_links.append(row)

final_df_with_links = pd.DataFrame(final_df_with_links).reset_index(drop=True)

# %%
#Assumption on the length of an intersection, based on the given data
intersection_length = 20

#Add intersection length to the dataframe
final_df_with_links.loc[
    final_df_with_links['model_type'] == 'intersection',
    'length'
] = intersection_length

# %%
#Adjust link lengths by subtracting half the length of the adjacent points/nodes
for i in range(1, len(final_df_with_links)-1):

    #Only update rows that represent links
    if final_df_with_links.loc[i, 'model_type'] == 'link':
        #Get the lengths of the previous and next point/node
        prev_len = final_df_with_links.loc[i-1, 'length']
        next_len = final_df_with_links.loc[i+1, 'length']

        #Correct the link length to avoid double counting neighboring node/point lengths
        final_df_with_links.loc[i, 'length'] = (
            final_df_with_links.loc[i, 'length']
            - prev_len/2
            - next_len/2
        )

# %%
#Visualisation of (dis)connection between N1 and N106
categories = final_df_with_links['model_type'].astype('category')
codes = categories.cat.codes
labels = categories.cat.categories

cmap = plt.cm.get_cmap('tab10', len(labels))

plt.figure(figsize=(12, 6))

scatter = plt.scatter(
    final_df_with_links['lon'],
    final_df_with_links['lat'],
    c=codes,
    cmap=cmap,
    s=50
)

plt.xlim(91.7, 91.9)
plt.ylim(22.2, 22.5)

plt.xlabel('Longitude', color='black')
plt.ylabel('Latitude', color='black')
plt.title('Road Network Nodes', color='black')

formatter = FuncFormatter(lambda x, _: f'{x:.3f}')
plt.gca().xaxis.set_major_formatter(formatter)
plt.gca().yaxis.set_major_formatter(formatter)

plt.tick_params(
    axis='both',
    which='both',
    direction='in',
    length=6,
    width=1.5,
    colors='black'
)

plt.gcf().set_facecolor('white')
plt.gca().set_facecolor('white')

plt.grid(True, color='gray', linestyle='--', linewidth=0.5)

legend_elements = [
    Line2D([0], [0], marker='o', color='w', label=label, markerfacecolor=cmap(i), markersize=8)
    for i, label in enumerate(labels)
]

legend = plt.legend(
    handles=legend_elements,
    title='Model type',
    loc='best',
    frameon=True,
    facecolor='white',
    edgecolor='black',
    fontsize=10,
    labelcolor='black',
)

legend.get_title().set_color('black')
legend.get_title().set_fontsize(12)
legend.get_title().set_fontweight('bold')

#Save image
plt.savefig('Disconnection first', facecolor='white', dpi=300)

plt.show()
# Out:
# /var/folders/gv/brj342r14hgcq9nk74qxt8jr0000gn/T/ipykernel_3939/3319007416.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab10', len(labels))

# %%
#Manually add links between N1 and N106, since they are not connected
link1 = {'road': 'N1', 'model_type': 'link', 'condition': 'NaN', 'name': '', 'lat': 22.366, 'lon': 91.79, 'length': 5000, 'chainage': 234}
link2 = {'road': 'N1', 'model_type': 'link', 'condition': 'NaN', 'name': '', 'lat': 22.362, 'lon': 91.83, 'length': 5000, 'chainage': 239}
added_links = pd.DataFrame([link1, link2])
added_links
final_df_with_links = pd.concat([final_df_with_links, added_links], ignore_index=True)
final_df_with_links
# Out:
#       road       id    model_type  \
# 0       N1     LRPS    sourcesink
# 1       N1     None          link
# 2       N1  LRP001a        bridge
# 3       N1     None          link
# 4       N1  LRP009a  intersection
# ...    ...      ...           ...
# 2922  N208  LRP057b        bridge
# 2923  N208     None          link
# 2924  N208     LRPE  intersection
# 2925    N1      NaN          link
# 2926    N1      NaN          link
#
#                                                    name        lat        lon  \
# 0     Start of Road  after Jatrabari Flyover infront...  23.706028  90.443333
# 1                                                  Link  23.702383  90.451097
# 2                                                     .  23.698739  90.458861
# 3                                                  Link  23.702411  90.490194
# 4                                   Road to Sylhet (N2)  23.706083  90.521527
# ...                                                 ...        ...        ...
# 2922                             KADAM TALI BOX CULVERT  24.878083  91.875333
# 2923                                               Link  24.877819  91.875347
# 2924  Road end at Humayun Rashid Chattar, Intersecti...  24.877555  91.875360
# 2925                                                     22.366000  91.790000
# 2926                                                     22.362000  91.830000
#
#        length condition  chainage  avg_truck_AADT  intersection_group
# 0        0.00              0.0000     2463.666667                 NaN
# 1     1794.35       NaN    0.9000     2626.666667                 NaN
# 2       11.30         A    1.8000     2789.666667                 NaN
# 3     6947.35       NaN    5.2815     2134.666667                 NaN
# 4       20.00              8.7630     1479.666667                 3.0
# ...       ...       ...       ...             ...                 ...
# 2922     5.60         B   57.0890      730.333333                 NaN
# 2923   393.20       NaN   57.2920      730.333333                 NaN
# 2924    20.00             57.4950      730.333333                10.0
# 2925  5000.00       NaN  234.0000             NaN                 NaN
# 2926  5000.00       NaN  239.0000             NaN                 NaN
#
# [2927 rows x 11 columns]

# %%
def aggregate_links_with_aadt(df):
    """
    Collapses consecutive link rows between non-link nodes into a single link.
    The new link's avg_truck_AADT is the chainage-weighted average of the
    replaced links. All other fields are taken from the midpoint link.

    Requires columns: road, model_type, chainage, avg_truck_AADT, length
    Must be called BEFORE chainage is dropped and before IDs are reassigned.
    """
    result_rows = []

    for road, group in df.groupby('road', sort=False):
        group = group.sort_values('chainage').reset_index(drop=True)
        i = 0

        while i < len(group):
            row = group.iloc[i]

            # Non-link nodes pass through unchanged
            if row['model_type'] != 'link':
                result_rows.append(row)
                i += 1
                continue

            # Collect this run of consecutive link rows
            link_run = []
            while i < len(group) and group.iloc[i]['model_type'] == 'link':
                link_run.append(group.iloc[i])
                i += 1

            if len(link_run) == 1:
                # Single link: pass through unchanged
                result_rows.append(link_run[0])
            else:
                # Multiple links: collapse into one with weighted average AADT
                lengths = [r['length'] for r in link_run]
                aadts  = [r['avg_truck_AADT'] for r in link_run]
                total_length = sum(lengths)

                if total_length > 0 and not all(pd.isna(a) for a in aadts):
                    weighted_aadt = sum(
                        l * a for l, a in zip(lengths, aadts)
                        if not pd.isna(a)
                    ) / sum(
                        l for l, a in zip(lengths, aadts)
                        if not pd.isna(a)
                    )
                else:
                    weighted_aadt = float('nan')

                # Build the aggregated link using the middle row as a template
                mid = link_run[len(link_run) // 2].copy()
                mid['length'] = total_length
                mid['avg_truck_AADT'] = weighted_aadt
                # Chainage: midpoint of the run
                mid['chainage'] = (link_run[0]['chainage'] + link_run[-1]['chainage']) / 2
                result_rows.append(mid)

    return pd.DataFrame(result_rows).reset_index(drop=True)

# Apply before IDs are reassigned and chainage is dropped
final_df_with_links = aggregate_links_with_aadt(final_df_with_links)

# %%
#Sort dataframe and reset the index
final_df_with_links.sort_values(['road', 'chainage'], inplace=True)
final_df_with_links.reset_index(drop=True, inplace=True)

#Assign IDs to each row
final_df_with_links['id'] = 100000 + (final_df_with_links.index + 1)

#Take roads that are intersections
mask = final_df_with_links['model_type'] == 'intersection'

#Assign the same IDs to all rows within the same intersection group
final_df_with_links.loc[mask, 'id'] = (
    final_df_with_links[mask]
    .groupby('intersection_group')['id']
    .transform('first')
)
#Remove the temporary grouping column (not needed anymore)
final_df_with_links.drop('intersection_group', axis=1, inplace=True)

# %%
# Check how many intersection IDs are shared across roads
from collections import defaultdict
intersection_roads = defaultdict(set)
for road, group in final_df_with_links.groupby('road'):
    for _, row in group.iterrows():
        if row['model_type'] == 'intersection':
            intersection_roads[row['id']].add(road)

shared = {id_: roads for id_, roads in intersection_roads.items() if len(roads) > 1}
print(f"Total intersection nodes: {len(intersection_roads)}")
print(f"Intersection nodes shared across roads: {len(shared)}")
for id_, roads in shared.items():
    print(f"  ID {id_}: {roads}")
# Out:
# Total intersection nodes: 12
# Intersection nodes shared across roads: 12
#   ID 100005: {'N2', 'N1'}
#   ID 100019: {'N105', 'N1'}
#   ID 100127: {'N102', 'N1'}
#   ID 100237: {'N104', 'N1'}
#   ID 101358: {'N2', 'N102'}
#   ID 101458: {'N2', 'N105'}
#   ID 102016: {'N2', 'N204'}
#   ID 102118: {'N2', 'N204'}
#   ID 102130: {'N207', 'N2'}
#   ID 102372: {'N207', 'N2'}
#   ID 102460: {'N208', 'N2'}
#   ID 102740: {'N208', 'N207'}

# %%
#check if everything is connected:
G = nx.Graph()

for road, group in final_df_with_links.groupby('road'):
    nodes = group['id'].tolist()
    for i in range(len(nodes) - 1):
        G.add_edge(nodes[i], nodes[i+1])

num_components = nx.number_connected_components(G)
print(f"seperate island-networks: {num_components}")
# Out:
# seperate island-networks: 2

# %%
#check how big the islands are
components = list(nx.connected_components(G))
for i, c in enumerate(components):
    print(f"Island {i+1} has {len(c)} components.")

#which roads are at which islands?
for i, c in enumerate(components):
    roads_in_component = final_df_with_links[final_df_with_links['id'].isin(c)]['road'].unique()
    print(f"Island {i+1} has roads: {roads_in_component}")
# Out:
# Island 1 has 2709 components.
# Island 2 has 203 components.
# Island 1 has roads: ['N1' 'N102' 'N104' 'N105' 'N2' 'N204' 'N207' 'N208']
# Island 2 has roads: ['N106']

# %%
#Identify the nearest N1 or N2 nodes to the start and end of road N106
def get_nearest(point, search_df):
    #Compute distances from the input point to all candidate points and return the minimum distance and the
    #Matching row
    dists = haversine(point['lat'], point['lon'], search_df['lat'], search_df['lon'])
    idx = dists.idxmin()
    return dists[idx], search_df.loc[idx]

#Find the nearest point to N106 for road N1 and N2
n106 = final_df_with_links[final_df_with_links.road == 'N106'].sort_values('chainage')
n1_n2 = final_df_with_links[final_df_with_links.road.isin(['N1', 'N2'])]
d_start, r_start = get_nearest(n106.iloc[0], n1_n2)
d_end, r_end = get_nearest(n106.iloc[-1], n1_n2)

print(f"Start N106: {d_start:.3f} km from {r_start['road']} (Ch {r_start['chainage']})")
print(f"End N106: {d_end:.3f} km from {r_end['road']} (Ch {r_end['chainage']})")
# Out:
# Start N106: 3.315 km from N1 (Ch 236.5)
# End N106: 45.638 km from N1 (Ch 263.2425)

# %%
#Make sure that per road we only have one intersection ID and sort on chainage to keep the most
#Logical point (the first one encountered)
final_df_clean = final_df_with_links.sort_values(['road', 'chainage']).drop_duplicates(subset=['road', 'id'], keep='first')

#Update final dataframe
final_df_with_links = final_df_clean.reset_index(drop=True)

final_df_with_links.head(20)
final_df_with_links[final_df_with_links["road"] == "N106"]
# Out:
#       road      id  model_type                                 name  \
# 1522  N106  101523  sourcesink     Start of Road  from Oxygen  More
# 1523  N106  101524        link                                 Link
# 1524  N106  101525      bridge               TANARI BOTTOLA CULVERT
# 1525  N106  101526        link                                 Link
# 1526  N106  101527      bridge                   TANARI BOX CULVERT
# ...    ...     ...         ...                                  ...
# 1720  N106  101721      bridge              MANIK CHARI BOX CULVERT
# 1721  N106  101722        link                                 Link
# 1722  N106  101723      bridge        MONIK CHAR I RCC GIDER BRIDGE
# 1723  N106  101724        link                                 Link
# 1724  N106  101725  sourcesink  The road ends Infront of DC Bunglow
#
#             lat        lon    length condition  chainage  avg_truck_AADT
# 1522  22.393555  91.821583      0.00              0.0000          1131.0
# 1523  22.395515  91.820810    475.95       NaN    0.2385          1131.0
# 1524  22.397475  91.820037      2.10         C    0.4770          1131.0
# 1525  22.398957  91.819704    338.90       NaN    0.6475          1131.0
# 1526  22.400440  91.819371      2.10         C    0.8180          1131.0
# ...         ...        ...       ...       ...       ...             ...
# 1720  22.640833  92.121688      1.00         A   54.6620            73.0
# 1721  22.642824  92.125651   1228.50       NaN   55.2955            73.0
# 1722  22.644816  92.129615     76.00         A   55.9290            73.0
# 1723  22.646671  92.165724  10883.00       NaN   61.3895            73.0
# 1724  22.648527  92.201833      0.00             66.8500            73.0
#
# [203 rows x 10 columns]

# %%
# Connect N106 start to nearest N1 node geographically
n106_start = final_df_with_links[
    (final_df_with_links['road'] == 'N106') &
    (final_df_with_links['chainage'] == final_df_with_links[final_df_with_links['road'] == 'N106']['chainage'].min())
].iloc[0]

n1_nodes = final_df_with_links[final_df_with_links['road'] == 'N1'].copy()
dists = haversine(n106_start['lat'], n106_start['lon'], n1_nodes['lat'], n1_nodes['lon'])
nearest_n1_idx = dists.idxmin()
shared_id = final_df_with_links.loc[nearest_n1_idx, 'id']

# Assign the nearest N1 node's ID to the N106 start node
n106_start_mask = (
    (final_df_with_links['road'] == 'N106') &
    (final_df_with_links['chainage'] == n106_start['chainage'])
)
final_df_with_links.loc[n106_start_mask, 'id'] = shared_id
final_df_with_links.loc[n106_start_mask, 'model_type'] = 'intersection'
final_df_with_links.loc[nearest_n1_idx, 'model_type'] = 'intersection'

# %%
#Visualisation of the road network points/nodes
plt.figure(figsize=(12,6))

colors = final_df_with_links['model_type'].astype('category').cat.codes

plt.scatter(
    final_df_with_links['lon'],
    final_df_with_links['lat'],
    c=colors,
    cmap='tab10',
    s=50
)


plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Road Network Nodes')
plt.xlim(91.7, 91.9)
plt.ylim(22.2, 22.5)
plt.show()

# %%
#Visualisation of connection between N1 and N106
categories = final_df_with_links['model_type'].astype('category')
codes = categories.cat.codes
labels = categories.cat.categories

cmap = plt.cm.get_cmap('tab10', len(labels))

plt.figure(figsize=(12, 6))

scatter = plt.scatter(
    final_df_with_links['lon'],
    final_df_with_links['lat'],
    c=codes,
    cmap=cmap,
    s=50
)

plt.xlim(91.7, 91.9)
plt.ylim(22.2, 22.5)

plt.xlabel('Longitude', color='black')
plt.ylabel('Latitude', color='black')
plt.title('Road Network Nodes', color='black')

formatter = FuncFormatter(lambda x, _: f'{x:.3f}')
plt.gca().xaxis.set_major_formatter(formatter)
plt.gca().yaxis.set_major_formatter(formatter)

plt.tick_params(
    axis='both',
    which='both',
    direction='in',
    length=6,
    width=1.5,
    colors='black'
)

plt.gcf().set_facecolor('white')
plt.gca().set_facecolor('white')

plt.grid(True, color='gray', linestyle='--', linewidth=0.5)

legend_elements = [
    Line2D([0], [0], marker='o', color='w', label=label, markerfacecolor=cmap(i), markersize=8)
    for i, label in enumerate(labels)
]

legend = plt.legend(
    handles=legend_elements,
    title='Model type',
    loc='best',
    frameon=True,
    facecolor='white',
    edgecolor='black',
    fontsize=10,
    labelcolor='black',
)

legend.get_title().set_color('black')
legend.get_title().set_fontsize(12)
legend.get_title().set_fontweight('bold')

#Save image
plt.savefig('Disconnection fixed final.png', facecolor='white', dpi=300)

plt.show()
# Out:
# /var/folders/gv/brj342r14hgcq9nk74qxt8jr0000gn/T/ipykernel_3939/437148648.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab10', len(labels))

# %%
#Identify sourcesink
mask = final_df_with_links["model_type"] == "sourcesink"

#Add new name column and assign unique names to sourcesink rows
final_df_with_links["name"] = ""
final_df_with_links.loc[mask, "name"] = "SoSi" + (mask.cumsum()).astype(str)

#Drop chainage column
final_df_with_links.drop('chainage', axis=1, inplace=True)

#Reorder columns
final_df_with_links = final_df_with_links[['road','id','model_type','condition','name','lat','lon','length', 'avg_truck_AADT']]

# %%
#Check details of dataframe
final_df_with_links.value_counts('model_type')
# Out:
# model_type
# link            1457
# bridge          1434
# intersection      26
# sourcesink         7
# Name: count, dtype: int64

# %%
#Check if lenght is negative
final_df_with_links[final_df_with_links['length'] < 0]
# Out:
#       road      id model_type condition name        lat        lon   length  \
# 31      N1  100032       link       NaN       23.654199  90.577070   -1.985
# 871     N1  100872       link       NaN       21.273949  92.104450   -4.750
# 1581  N106  101582       link       NaN       22.528273  91.875834   -0.345
# 1730    N2  101731       link       NaN       23.785361  90.568738   -0.750
# 1851    N2  101853       link       NaN       24.047121  90.862425 -114.005
# 1885    N2  101887       link       NaN       24.056942  90.970290   -9.950
# 1895    N2  101897       link       NaN       24.049894  90.990867 -238.000
# 2117    N2  102119       link       NaN       24.267978  91.477068  -44.075
# 2896  N208  102898       link       NaN       24.693557  91.933473  -85.850
#
#       avg_truck_AADT
# 31       2597.666667
# 871       205.333333
# 1581      379.333333
# 1730     2185.333333
# 1851     1101.000000
# 1885     1101.000000
# 1895     1101.000000
# 2117     1015.333333
# 2896      306.666667

# %%
#Save final dataframe as CSV
final_df_with_links.drop(1734, inplace=True)
final_df_with_links['length'] = abs(final_df_with_links['length'])
final_df_with_links.to_csv('../data/data_final_with_aadt.csv')

# %%
#Final check if everything is connected
G = nx.Graph()
pos = {}

for road, group in final_df_with_links.groupby('road'):
    nodes = group['id'].tolist()
    lon = group['lon'].tolist()
    lat = group['lat'].tolist()
    for i in range(len(nodes) - 1):
        G.add_edge(nodes[i], nodes[i+1])
        pos[nodes[i]] = (lon[i], lat[i])

num_components = nx.number_connected_components(G)
print(f"seperate island-networks: {num_components}")
print(nx.is_connected(G))
# Out:
# seperate island-networks: 1
# True

# %%
import os
print(os.getcwd())
# Out:
# /Users/eli/PycharmProjects/EPA133A-Advanced-Simulation-Group-1/EPA133a-G01-A4/notebook

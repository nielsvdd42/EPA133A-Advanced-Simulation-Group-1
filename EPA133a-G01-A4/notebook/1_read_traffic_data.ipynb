# %%
import pandas as pd
import os

# %%
data_folder = '../data/road_traffic/'
all_dataframes = []

#create the good colum names
column_names = [
    'Link no', 'Name',
    'Start_LRP', 'Start_Offset', 'Start_Chainage',
    'End_LRP', 'End_Offset', 'End_Chainage',
    'Length_Km', 'Heavy_Truck', 'Medium_Truck', 'Small_Truck',
    'Large_Bus', 'Medium_Bus', 'Micro_Bus', 'Utility',
    'Car', 'Auto_Rickshaw', 'Motor_Cycle', 'Bi_Cycle',
    'Cycle_Rickshaw', 'Cart', 'Motorized', 'Non_Motorized', 'Total_AADT'
]

for filename in os.listdir(data_folder):
    if filename.endswith(".traffic.htm"):
        file_path = os.path.join(data_folder, filename)
        tables = pd.read_html(file_path, encoding='ISO-8859-1')
        if len(tables) > 0:
            #get the last table, and we only need the first 25 columns.
            df = tables[-1].iloc[:, :25]

            #skip the first three lines with html, and get the real data
            df = df.iloc[3:].copy()

            #make it the right column names
            df.columns = column_names

            #add the road
            df['Road'] = filename.split('.')[0]

            all_dataframes.append(df)

#put all together
final_df = pd.concat(all_dataframes, ignore_index=True)

#road is final column
cols = ['Road'] + [c for c in final_df.columns if c != 'Road']
final_df = final_df[cols]

# Toon het resultaat
display(final_df.head(30))
# Out:
#    Road Link no                                               Name Start_LRP  \
# 0    N1   N1-1L           Jatrabari - Int.with Z1101 (Left) (Left)      LRPS
# 1    N1   N1-1R          Jatrabari - Int.with Z1101 (Left) (Right)      LRPS
# 2    N1   N1-2L      Int.with Z1101 - Signboard (Left) R111 (Left)      LRPS
# 3    N1   N1-2R     Int.with Z1101 - Signboard (Left) R111 (Right)      LRPS
# 4    N1   N1-3L             Signboard - Shimrail (Left)R110 (Left)      LRPS
# 5    N1   N1-3R            Signboard - Shimrail (Left)R110 (Right)      LRPS
# 6    N1   N1-4L                Shimrail - Katchpur (Left)N2 (Left)      LRPS
# 7    N1   N1-4R               Shimrail - Katchpur (Left)N2 (Right)      LRPS
# 8    N1   N1-5L              Katchpur - Madanpur (Left)N105 (Left)    LRP009
# 9    N1   N1-5R             Katchpur - Madanpur (Left)N105 (Right)    LRP009
# 10   N1   N1-6L           Madanpur - Langalband (Left)Z1061 (Left)    LRP012
# 11   N1   N1-6R          Madanpur - Langalband (Left)Z1061 (Right)    LRP012
# 12   N1   N1-7L  Langalband - Mograpara Chowrasta (Left)Z1089 (...    LRP013
# 13   N1   N1-7R  Langalband - Mograpara Chowrasta (Left)Z1089 (...    LRP013
# 14   N1   N1-8L  Mograpara(Int.with Z1089)-Meghna Bridge West E...    LRP013
# 15   N1   N1-8R  Mograpara(Int.with Z1089)-Meghna Bridge West E...    LRP013
# 16   N1   N1-9L  Meghna Bridge Satrt-Bhaberchar (Left) z1063 (L...    LRP022
# 17   N1   N1-9R  Meghna Bridge Satrt-Bhaberchar (Left) z1063 (R...    LRP022
# 18   N1  N1-10L  Bhaberchar(Int.with Z1063)-Daudkandi Bridge (L...    LRP031
# 19   N1  N1-10R  Bhaberchar(Int.with Z1063)-Daudkandi Bridge (L...    LRP031
# 20   N1  N1-11L           Daudkandi Bridge- Daudkandi Z1062 (Left)    LRP033
# 21   N1  N1-11R          Daudkandi Bridge- Daudkandi Z1062 (Right)    LRP033
# 22   N1  N1-12L              Daudkandi Z1062 - Pennai Z1053 (Left)    LRP033
# 23   N1  N1-12R             Daudkandi Z1062 - Pennai Z1053 (Right)    LRP033
# 24   N1  N1-13L     Pennai Z1053- Gouripur (Int.with Z1044) (Left)    LRP043
# 25   N1  N1-13R    Pennai Z1053- Gouripur (Int.with Z1044) (Right)    LRP043
# 26   N1  N1-14L  Gouripur (Int.with Z1044) - Eliotganj Z1042 (L...    LRP043
# 27   N1  N1-14R  Gouripur (Int.with Z1044) - Eliotganj Z1042 (R...    LRP043
# 28   N1  N1-15L              Eliotganj Z1042- Madhaya Z1017 (Left)    LRP043
# 29   N1  N1-15R             Eliotganj Z1042- Madhaya Z1017 (Right)    LRP043
#
#    Start_Offset Start_Chainage End_LRP End_Offset End_Chainage Length_Km  ...  \
# 0             0              0    LRPS        822        0.822     0.822  ...
# 1             0              0    LRPS        822        0.822     0.822  ...
# 2           822          0.822    LRPS       4175        4.175     3.353  ...
# 3           822          0.822    LRPS       4175        4.175     3.353  ...
# 4          4175          4.175    LRPS       7181        7.181     3.006  ...
# 5          4175          4.175    LRPS       7181        7.181     3.006  ...
# 6          7181          7.181  LRP009        260        8.763     1.582  ...
# 7          7181          7.181  LRP009        260        8.763     1.582  ...
# 8           260          8.763  LRP012        439       11.936     3.173  ...
# 9           260          8.763  LRP012        439       11.936     3.173  ...
# 10          439         11.936  LRP013       3411       15.935     3.999  ...
# 11          439         11.936  LRP013       3411       15.935     3.999  ...
# 12         3411         15.935  LRP013       7520       20.044     4.109  ...
# 13         3411         15.935  LRP013       7520       20.044     4.109  ...
# 14         7520         20.044  LRP022       1935       23.564     3.520  ...
# 15         7520         20.044  LRP022       1935       23.564     3.520  ...
# 16         1935         23.564  LRP031        162       30.936     7.372  ...
# 17         1935         23.564  LRP031        162       30.936     7.372  ...
# 18          162         30.936  LRP033       3664       36.271     5.335  ...
# 19          162         30.936  LRP033       3664       36.271     5.335  ...
# 20         3664         36.271  LRP033       5859       38.466     2.195  ...
# 21         3664         36.271  LRP033       5859       38.466     2.195  ...
# 22         5859         38.466  LRP043       3119       45.388     6.922  ...
# 23         5859         38.466  LRP043       3119       45.388     6.922  ...
# 24         3119         45.388  LRP043       4955       47.224     1.836  ...
# 25         3119         45.388  LRP043       4955       47.224     1.836  ...
# 26         4955         47.224  LRP043      13208       55.477     8.253  ...
# 27         4955         47.224  LRP043      13208       55.477     8.253  ...
# 28        13208         55.477  LRP043      20009       62.278     6.801  ...
# 29        13208         55.477  LRP043      20009       62.278     6.801  ...
#
#    Utility     Car Auto_Rickshaw Motor_Cycle Bi_Cycle Cycle_Rickshaw Cart  \
# 0    238.0  1851.0        2980.0       398.0    232.0          889.0  0.0
# 1    480.0  2608.0        2508.0       436.0    213.0         1088.0  0.0
# 2    480.0  2608.0        2508.0       436.0    213.0         1088.0  0.0
# 3    238.0  1851.0        2980.0       398.0    232.0          889.0  0.0
# 4    314.0  1690.0        2266.0      1087.0     75.0         1198.0  0.0
# 5    298.0  1609.0        2157.0      1035.0     72.0         1140.0  0.0
# 6    320.0  1579.0        3154.0      1162.0    211.0         1077.0  0.0
# 7    345.0  1948.0        2693.0      1143.0    517.0         1531.0  0.0
# 8    249.0  1579.0        3154.0      1154.0    211.0         1077.0  0.0
# 9    345.0  2105.0        3080.0      1143.0    517.0         1531.0  0.0
# 10   345.0  2105.0        3080.0      1143.0    517.0         1531.0  0.0
# 11   249.0  1579.0        3154.0      1154.0    211.0         1077.0  0.0
# 12   345.0  2105.0        3080.0      1143.0    517.0         1531.0  0.0
# 13   249.0  1579.0        3154.0      1154.0    211.0         1077.0  0.0
# 14   403.0  2137.0        1364.0       110.0     37.0          196.0  0.0
# 15   396.0  1961.0        1120.0       314.0     31.0          131.0  0.0
# 16   396.0  1961.0        1120.0       314.0     31.0          131.0  0.0
# 17   403.0  2137.0        1364.0       110.0     37.0          196.0  0.0
# 18   403.0  2137.0        1364.0       110.0     37.0          196.0  0.0
# 19   396.0  1961.0        1120.0       314.0     31.0          131.0  0.0
# 20   403.0  2137.0        1364.0       110.0     37.0          196.0  0.0
# 21   396.0  1961.0        1120.0       314.0     31.0          131.0  0.0
# 22   397.0  1049.0         800.0       132.0     26.0          106.0  0.0
# 23   398.0  1126.0         786.0       198.0     44.0          147.0  0.0
# 24   397.0  1049.0         800.0       132.0     26.0          106.0  0.0
# 25   398.0  1126.0         786.0       198.0     44.0          147.0  0.0
# 26   398.0  1126.0         786.0       198.0     44.0          147.0  0.0
# 27   397.0  1049.0         800.0       132.0     26.0          106.0  0.0
# 28   397.0  1049.0         800.0       132.0     26.0          106.0  0.0
# 29   398.0  1126.0         786.0       198.0     44.0          147.0  0.0
#
#    Motorized Non_Motorized Total_AADT
# 0    18236.0        1121.0    19357.0
# 1    20236.0        1301.0    21537.0
# 2    20236.0        1301.0    21537.0
# 3    18236.0        1121.0    19357.0
# 4    16288.0        1273.0    17561.0
# 5    15445.0        1212.0    16657.0
# 6    16001.0        1288.0    17289.0
# 7    15996.0        2048.0    18044.0
# 8    22591.0        1288.0    23879.0
# 9    22541.0        2048.0    24589.0
# 10   22541.0        2048.0    24589.0
# 11   22591.0        1288.0    23879.0
# 12   22541.0        2048.0    24589.0
# 13   22591.0        1288.0    23879.0
# 14   14589.0         233.0    14822.0
# 15   14389.0         162.0    14551.0
# 16   14389.0         162.0    14551.0
# 17   14589.0         233.0    14822.0
# 18   14589.0         233.0    14822.0
# 19   14389.0         162.0    14551.0
# 20   14589.0         233.0    14822.0
# 21   14389.0         162.0    14551.0
# 22   11549.0         132.0    11681.0
# 23   11392.0         191.0    11583.0
# 24   11549.0         132.0    11681.0
# 25   11392.0         191.0    11583.0
# 26   11392.0         191.0    11583.0
# 27   11549.0         132.0    11681.0
# 28   11549.0         132.0    11681.0
# 29   11392.0         191.0    11583.0
#
# [30 rows x 26 columns]

# %%
display(final_df.tail())
# Out:
#      Road Link no                                               Name  \
# 177  N208  N208-1                         Moulvibazar-Int.with Z2002
# 178  N208  N208-2            Int.with Z2002-Rajnagar (Int.with R281)
# 179  N208  N208-3  Rajnagar(Int.with R281)-Daudabad (Int.with Z2832)
# 180  N208  N208-4  Daudabad (Int.with Z2832)-Royal City Chottor(i...
# 181  N208  N208-5      Royal City Chottor(int.with N210)-Int.with N2
#
#     Start_LRP Start_Offset Start_Chainage End_LRP End_Offset End_Chainage  \
# 177      LRPS            0              0    LRPS       3190         3.19
# 178      LRPS         3190           3.19  LRP012       1661       13.461
# 179    LRP012         1661         13.461  LRP052        385        51.05
# 180    LRP052          385          51.05  LRP054        677       53.342
# 181    LRP054          677         53.342  LRP058        900       57.495
#
#     Length_Km  ... Utility    Car Auto_Rickshaw Motor_Cycle Bi_Cycle  \
# 177     3.190  ...   149.0  741.0        3194.0      1123.0    147.0
# 178    10.271  ...   149.0  741.0        3194.0      1123.0    147.0
# 179    37.589  ...    78.0  811.0        2233.0       582.0     88.0
# 180     2.292  ...    78.0  811.0        2233.0       582.0     88.0
# 181     4.153  ...    77.0  778.0        2974.0      1231.0    695.0
#
#     Cycle_Rickshaw  Cart Motorized Non_Motorized Total_AADT
# 177          486.0   0.0    7514.0         633.0     8147.0
# 178          486.0   0.0    7514.0         633.0     8147.0
# 179           73.0   0.0    5328.0         161.0     5489.0
# 180           73.0   0.0    5328.0         161.0     5489.0
# 181          822.0  47.0    9488.0        1564.0    11052.0
#
# [5 rows x 26 columns]

# %%
#check for example the N106
n106_data = final_df[final_df['Road'] == 'N106']
display(n106_data)
# Out:
#      Road Link no                                               Name  \
# 133  N106  N106-1  Chittagong (Oxygen More)-Hathazari (Int. with ...
# 134  N106  N106-2  Hathazari (Int. with R160)-Gohira(Int.with Z1619)
# 135  N106  N106-3  Gohira(Int.with Z1619)-Munshihat (Int.with Z1629)
# 136  N106  N106-4  Munshihat (Int.with Z1629)-Raozan (Int.with Z1...
# 137  N106  N106-5  Raozan (Int.with Z1012)-Ranirhat (Int.with Z1613)
# 138  N106  N106-6  Ranirhat (Int.with Z1613)-Gabtoli (Int.with Z1...
# 139  N106  N106-7   Gabtoli (Int.with Z1617)-Ghagra (Int. with R161)
# 140  N106  N106-8  Ghagra (Int. with R161)-Manikchhari(Int. with ...
# 141  N106  N106-9              Manikchhari(Int. with R162)-Rangamati
#
#     Start_LRP Start_Offset Start_Chainage End_LRP End_Offset End_Chainage  \
# 133      LRPS            0              0  LRP010       2084       12.192
# 134    LRP010         2084         12.192  LRP018       1533       19.321
# 135    LRP018         1533         19.321  LRP024        828       24.297
# 136    LRP024          828         24.297  LRP025        820       25.278
# 137    LRP025          820         25.278  LRP039        690        37.25
# 138    LRP039          690          37.25  LRP044        296       41.825
# 139    LRP044          296         41.825  LRP051        147       48.879
# 140    LRP051          147         48.879  LRP059        566       57.303
# 141    LRP059          566         57.303    LRPE          0        66.85
#
#     Length_Km  ... Utility     Car Auto_Rickshaw Motor_Cycle Bi_Cycle  \
# 133    12.192  ...   289.0  1063.0        8817.0      1355.0    234.0
# 134     7.129  ...   217.0   296.0        5481.0      1078.0    576.0
# 135     4.976  ...   217.0   296.0        5481.0      1078.0    576.0
# 136     0.981  ...   217.0   296.0        5481.0      1078.0    576.0
# 137    11.972  ...   418.0   103.0         520.0       372.0      0.0
# 138     4.575  ...   418.0   103.0         520.0       372.0      0.0
# 139     7.054  ...   418.0   103.0         520.0       372.0      0.0
# 140     8.424  ...    83.0    35.0         904.0       471.0      0.0
# 141     9.547  ...    83.0    35.0         904.0       471.0      0.0
#
#     Cycle_Rickshaw Cart Motorized Non_Motorized Total_AADT
# 133          393.0  0.0   17165.0         627.0    17792.0
# 134          943.0  0.0    8908.0        1519.0    10427.0
# 135          943.0  0.0    8908.0        1519.0    10427.0
# 136          943.0  0.0    8908.0        1519.0    10427.0
# 137            0.0  0.0    2443.0           0.0     2443.0
# 138            0.0  0.0    2443.0           0.0     2443.0
# 139            0.0  0.0    2443.0           0.0     2443.0
# 140            0.0  0.0    1975.0           0.0     1975.0
# 141            0.0  0.0    1975.0           0.0     1975.0
#
# [9 rows x 26 columns]

# %%
final_df.columns
# Out:
# Index(['Road', 'Link no', 'Name', 'Start_LRP', 'Start_Offset',
#        'Start_Chainage', 'End_LRP', 'End_Offset', 'End_Chainage', 'Length_Km',
#        'Heavy_Truck', 'Medium_Truck', 'Small_Truck', 'Large_Bus', 'Medium_Bus',
#        'Micro_Bus', 'Utility', 'Car', 'Auto_Rickshaw', 'Motor_Cycle',
#        'Bi_Cycle', 'Cycle_Rickshaw', 'Cart', 'Motorized', 'Non_Motorized',
#        'Total_AADT'],
#       dtype='object')

# %%
df1 = pd.read_csv("../data/_roads3.csv")

# %%
def merge_lrp_datasets(df_points: pd.DataFrame, df_links: pd.DataFrame) -> pd.DataFrame:
    """
    Merges LRP point data with link-level traffic data.

    For each point in df_points, finds which link range it falls into
    (based on chainage) and appends the average of Small_truck, Medium_truck,
    Heavy_truck from that link as a new column 'avg_truck_AADT'.

    Assumes:
    - df_points has columns: 'road', 'chainage'
    - df_links has columns: 'Road', 'Start_Chainage', 'End_Chainage',
                            'Small_truck', 'Medium_truck', 'Heavy_truck'
    """

    # Compute average truck AADT per link
    df_links = df_links.copy()
    df_links['Small_Truck'] = pd.to_numeric(df_links['Small_Truck'], errors='coerce')
    df_links['Medium_Truck'] = pd.to_numeric(df_links['Medium_Truck'], errors='coerce')
    df_links['Heavy_Truck'] = pd.to_numeric(df_links['Heavy_Truck'], errors='coerce')
    df_links['Start_Chainage'] = pd.to_numeric(df_links['Start_Chainage'], errors='coerce')
    df_links['End_Chainage'] = pd.to_numeric(df_links['End_Chainage'], errors='coerce')
    df_links['avg_truck_AADT'] = df_links[['Small_Truck', 'Medium_Truck', 'Heavy_Truck']].mean(axis=1)


    def get_avg_truck(row):
        road = row['road']
        chainage = row['chainage']

        # Filter links for the same road
        road_links = df_links[df_links['Road'] == road]

        # Find the link whose range contains this chainage
        # A point belongs to a link if: Start_Chainage <= chainage <= End_Chainage
        match = road_links[
            (road_links['Start_Chainage'] <= chainage) &
            (road_links['End_Chainage'] >= chainage)
        ]

        if not match.empty:
            return match.iloc[0]['avg_truck_AADT']

        # Edge case: chainage is beyond all link ranges (e.g. very last point)
        # Assign to the last link of the road
        if not road_links.empty and chainage > road_links['End_Chainage'].max():
            return road_links.loc[road_links['End_Chainage'].idxmax(), 'avg_truck_AADT']

        return None  # No matching link found

    df_points = df_points.copy()
    df_points['avg_truck_AADT'] = df_points.apply(get_avg_truck, axis=1)

    return df_points

# %%
df_result = merge_lrp_datasets(df1, final_df)

# %%
df_result.head(30)
# Out:
#    road  chainage      lrp        lat        lon  gap            type  \
# 0    N1     0.000     LRPS  23.706028  90.443333  NaN          Others
# 1    N1     0.814    LRPSa  23.702917  90.450417  NaN         Culvert
# 2    N1     0.822    LRPSb  23.702778  90.450472  NaN       CrossRoad
# 3    N1     1.000   LRP001  23.702139  90.451972  NaN          KmPost
# 4    N1     2.000   LRP002  23.697889  90.460583  NaN          KmPost
# 5    N1     2.130  LRP002a  23.697361  90.461667  NaN         Culvert
# 6    N1     3.000   LRP003  23.693833  90.469138  NaN          KmPost
# 7    N1     4.000   LRP004  23.693611  90.478777  NaN          KmPost
# 8    N1     4.175  LRP004a  23.693805  90.480527  NaN  SideRoad,Right
# 9    N1     5.000   LRP005  23.694750  90.488500  NaN          KmPost
# 10   N1     6.000   LRP006  23.695916  90.498194  NaN          KmPost
# 11   N1     7.000   LRP007  23.697333  90.507750  NaN          KmPost
# 12   N1     7.181  LRP007a  23.697916  90.509278  NaN       CrossRoad
# 13   N1     8.000   LRP008  23.702056  90.515722  NaN          KmPost
# 14   N1     8.011  LRP008a  23.702111  90.515778   BS          Bridge
# 15   N1     8.429  LRP008b  23.704583  90.518833   BE          Bridge
# 16   N1     8.503   LRP009  23.705028  90.519333  NaN          KmPost
# 17   N1     8.763  LRP009a  23.706083  90.521527  NaN   SideRoad,Left
# 18   N1     9.503   LRP010  23.702528  90.527388  NaN          KmPost
# 19   N1     9.615  LRP010a  23.701528  90.528194  NaN         Culvert
# 20   N1     9.963  LRP010b  23.699861  90.530722  NaN         Culvert
# 21   N1    10.377  LRP010c  23.697416  90.533777  NaN         Culvert
# 22   N1    10.503   LRP011  23.696639  90.534805  NaN          KmPost
# 23   N1    10.885  LRP011a  23.694361  90.537611  NaN         Culvert
# 24   N1    11.313  LRP011b  23.692277  90.541055  NaN         Culvert
# 25   N1    11.497   LRP012  23.691805  90.542611  NaN          KmPost
# 26   N1    11.745  LRP012a  23.691111  90.544889   BS          Bridge
# 27   N1    11.771  LRP012b  23.691055  90.545139   BE          Bridge
# 28   N1    11.936  LRP012c  23.690416  90.546583  NaN  SideRoad,Right
# 29   N1    12.524   LRP013  23.686527  90.550417  NaN          KmPost
#
#                                                  name  avg_truck_AADT
# 0   Start of Road  after Jatrabari Flyover infront...     2463.666667
# 1                                         Box Culvert     2463.666667
# 2                             Intersection with Z1101     2463.666667
# 3                                     Km post missing     2789.666667
# 4                                     Km post missing     2789.666667
# 5                                         Box culvert     2789.666667
# 6                                     Km post missing     2789.666667
# 7                                     Km post missing     2789.666667
# 8                           Road to Narayanganj(R111)     2789.666667
# 9                                     Km post missing     1660.333333
# 10                                    Km post missing     1660.333333
# 11                                    Km post missing     1660.333333
# 12           R110,Left to Demra, Right to Narayanganj     1660.333333
# 13                                    Km post missing     1479.666667
# 14                                     Kachpur bridge     1479.666667
# 15                                         Bridge end     1479.666667
# 16                    Chittagong 251 km,Comilla 84 km     1479.666667
# 17                                Road to Sylhet (N2)     1479.666667
# 18                                    Km post missing     2872.333333
# 19                                        Box culvert     2872.333333
# 20                                        Box culvert     2872.333333
# 21                                        Box culvert     2872.333333
# 22                                    Km post missing     2872.333333
# 23                                        Box culvert     2872.333333
# 24                                        Box culvert     2872.333333
# 25                    Chittagong 248 km,Comilla 81 km     2872.333333
# 26                                       Bridge start     2872.333333
# 27                                         Bridge end     2872.333333
# 28    Right to Syedpur (R113) left to Joydebpur N105)     2872.333333
# 29                           Ctg 247 km,Comilla 80 km     2597.666667

# %%
df_result.to_csv('../data/data_with_AADT.csv')
